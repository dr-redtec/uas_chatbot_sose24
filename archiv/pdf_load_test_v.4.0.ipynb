# %%
import os
import pdfplumber
from collections import defaultdict

def detect_columns(text_blocks, page_width):
    """Gruppiere Textblöcke basierend auf ihrer horizontalen Position (Spalten)."""
    columns = defaultdict(list)
    threshold = page_width * 0.15  # Threshold, um Spalten zu erkennen

    for block in text_blocks:
        x_center = (block['x0'] + block['x1']) / 2

        assigned = False
        for col_x in columns:
            if abs(col_x - x_center) < threshold:
                columns[col_x].append(block)
                assigned = True
                break
        
        if not assigned:
            columns[x_center].append(block)

    return columns

def extract_text_from_column(column_blocks):
    """Sortiere die Blöcke innerhalb einer Spalte und extrahiere den Text."""
    sorted_blocks = sorted(column_blocks, key=lambda block: (block['top'], block['x0']))
    return ' '.join([block['text'] for block in sorted_blocks])

def extract_text_from_page_g1(page):
    """Extrahiere den Text aus einer Seite für PDFs in g1, behalte dabei das Layout."""
    text_blocks = page.extract_words()
    if not text_blocks:
        return ""

    columns = detect_columns(text_blocks, page.width)
    full_text = []

    for col_x, blocks in sorted(columns.items()):
        column_text = extract_text_from_column(blocks)
        full_text.append(column_text)

    return "\n\n".join(full_text)

def extract_text_from_page_g2(page):
    """Alternative Methode zur Textextraktion für PDFs in g2."""
    # Beispielhafte einfache Extraktion, die besser auf das Layout abgestimmt ist
    # Dies kann durch Methoden wie pdfminer.six, die textorientierter sind, ergänzt werden.
    text_blocks = page.extract_words()
    if not text_blocks:
        return ""
    
    full_text = [block['text'] for block in sorted(text_blocks, key=lambda block: (block['top'], block['x0']))]
    
    return ' '.join(full_text)

def extract_text_from_pdfs(pdf_folder_path, extraction_function):
    documents = []

    for filename in os.listdir(pdf_folder_path):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder_path, filename)

            with pdfplumber.open(pdf_path) as pdf:
                full_text = []

                for page in pdf.pages:
                    page_text = extraction_function(page)
                    full_text.append(page_text)

                documents.append("\n\n".join(full_text))

    return documents

# Pfade zu den PDF-Ordnern
pdf_folder_path_g1 = os.path.join('data', 'pdf', 'g1')
pdf_folder_path_g2 = os.path.join('data', 'pdf', 'g2')

# Extrahiere die Texte aus den PDFs in g1
documents_g1 = extract_text_from_pdfs(pdf_folder_path_g1, extract_text_from_page_g1)

# Extrahiere die Texte aus den PDFs in g2
documents_g2 = extract_text_from_pdfs(pdf_folder_path_g2, extract_text_from_page_g2)

# Kombiniere alle Dokumente
documents = documents_g1 + documents_g2

# Beispielhafte Ausgabe des ersten Dokuments
# print(documents[2] if documents else "Keine Dokumente gefunden")
for i, doc in enumerate(documents):
    print(f"Document {i}:\n")
    print(doc)
    print("\n" + "="*50 + "\n")
# Out:
# Document 0:
#
# Der blaue Altglascontainer. Das kommt hinein Saubere Flaschen und Deckelgläser nach den Farben Weiß, Grün und Braun getrennt; blaues oder buntes Glas bitte zum Grünglas geben.  Glasfl aschen  Konservengläser Das kommt nicht hinein  Flachglas wie Spiegel und Scheiben (Restmüll oder  Trinkgläser und Blumenvasen (Restmüll)  Porzellan und Keramik (Restmüll)  Glühbirnen (Restmüll), Energiesparlampen (Schadstoffmobil oder Wertstoffhöfe)  Stark verschmutzte Gläser (Restmüll) Standort: auf öffentlichen
#
# immer Sperrmüll) Plätzen
#
# Was kommt wo hinein? FES Frankfurter Entsorgungs- Abfall richtig trennen – und Service GmbH Weidenbornstraße 40 60389 Frankfurt am Main Servicetelefon 0800 2008007-0 Servicetelefax 069 212-31323 services@fes-frankfurt.de www.fes-frankfurt.de FES-Servicecenter Liebfrauenberg 52–54 (Ecke Töngesgasse/Schärfengässchen) 60313 Frankfurt am Main Mo. – Fr. 10.00 – 18.00 Uhr Sa. 10.00 – 16.00 Uhr rgungsfachbetrie Entso b rtschafte.V.-EdDn oE El -öK tsn 0 gla3 sn1 we4 rgergemeinschaftZ dE efüR rrT DEI niF dI uK tmA chT en s a m hae enl nn e, ElB ne vf tö sr od rAe gr bn uf, L eg r in u B se d o n ä l n n
#
# Richtig trennen leicht gemacht. Zu jedem Haus in Frankfurt gehören 4 Abfallbehälter: 3 Tonnen, Inhalt als wertvoller Rohstoff zu neuen Produkten weiterverarbeitet und die graue Restmülltonne:  die gelbe Tonne für Verpackungen  die grüne Tonne für Papier und Pappe  die braune Tonne für Bioabfälle  die graue Tonne für den restlichen Abfall: den Restmüll Darüber hinaus gibt es folgende Entsorgungsangebote: Wertstoffe sichern. Altglas Altglascontainer für Flaschen und Deckelgläser fi nden Sie an öffentlichen Plätzen. Altkleider Container für Altkleider und Schuhe fi nden Sie in jedem Stadtteil öffentlichen Plätzen sowie auf den FES-Wertstoffhöfen. Schadstoffe Abfälle aus oder mit gefährlichen Stoffen wie Farben, Spraydosen, mitteln etc. können Sie am FES-Schadstoffmobil abgeben: Alle und Termine fi nden Sie auf www.fes-frankfurt.de oder im OSKAR, das dreimal im Jahr an alle Haushalte verteilt wird. Sperrmüllabholung m3 Bis zu 10 holt die FES kostenlos bei Ihnen ab.* Einen Termin Sie am Servicetelefon 0800 2008007-10 oder unter In manchen Wohnsiedlungen wird Sperrmüll automatisch alle abgeholt – die Termine fi nden Sie am schwarzen Brett in Ihrem Sperrmüll und Wertstoffe selbst entsorgen so3 E Ai ln pe an K ieo rf ,f e Vr er ra pu am v uo nl gl e( n1 m w) ia en S lep ke tr rr om sü chll r, G ttrü kn ös nc nh en nit t S, eA l at um fe t p ck E o i AF wE bS w- fW afe llr st b-s et ro hnff äkh lö tf ee rn ea b og ne wb tie an ii. M Fe rEh Sr I en saf go erm la et i no Sn Ke An fi nden Sie w . e f a f u r t .d s o e nm b- M ta z li n O R . / C e Sollten Ihre Abfalltonnen am Haus auf Dauer nicht ausreichen, Sie als Hausbesitzer weitere/größere bestellen: im Internet www.fes-frankfurt.de oder per Service-Fax (069 212-32723). über Spezialbehälter für besondere Abfälle (z. B. Baustellenabfälle erfahren Sie unter unserer Servicetelefonnummer 0800 * Die Kosten für den Sperrmüll sind in Ihrer Abfallgebühr enthalten.
#
# deren wird, auf Löse- Standorte FES-Magazin erhalten www.fes-frankfurt.de. 4 Wochen Haus. dt ea nll , auf können auf Näheres u. Ä.) 2008007-70.
#
# Die gelbe Verpackungstonne. Das kommt hinein Alle Verpackungen mit oder ohne Symbol wie den Grünen die nicht ausschließlich aus Papier, Pappe oder Glas bestehen. Die Verpackungen müssen nicht gespült, aber leer sein.  Verpackungen aus Kunststoff wie Folien, Becher und  Verbundverpackungen aus Materialmix (z. B. Alu + Papier) wie Getränkekartons und Milchtüten  Verpackungen aus Metall wie Konserven- und Getränkedosen  Geschäumte Kunststoffe, z. B. Obst- und Gemüseverpackungen Das kommt nicht hinein  Verpackungen aus Papier und Pappe (Altpapiertonne)  Verpackungen aus Glas (Altglascontainer)  Stark verschmutzte Fast-Food-Verpackungen wie Pizzakartons (Restmüll) Ist zu viel Restmüll in der gelben Tonne, können die nicht mehr aussortiert und weiterverarbeitet werden. Standort: am Wohnhaus Leerung: 14-täglich
#
# Die grüne Altpapiertonne. Das kommt hinein Punkt, In die grüne Altpapiertonne gehören Papier und Pappe – ohne Beschichtung und unverschmutzt.  Pappen und Kartonagen  Styropor Zeitungen, Illustrierte, Kataloge  Bücher und Hefte Das kommt nicht hinein  Stark verschmutztes Papier (Restmüll)  Beschichtetes Papier (Restmüll)  Pergament- und Hygienepapiere, Windeln (Restmüll) Näheres über sichere Aktenvernichtung erfahren Sie unter der Servicetelefonnummer 0800 2008007-70. Wertstoffe Standort: am Wohnhaus Leerung: 14-täglich
#
# Die braune Biotonne. Das kommt hinein Alle biologisch abbaubaren Abfälle aus privaten Haushalten. Feuchte Bioabfälle wie Salat- oder Obst- und Gemüsereste Sie in Zeitungs- oder Küchenpapier wickeln. So schützen Sie Tonne vor starker Verschmutzung und Geruch.  Obst- und Gemüseabfälle (auch Zitrusfrüchte, Bananen- und Nussschalen)  Rohe und gekochte Speise- und Lebensmittelreste  Kaffee- und Teesatz, Filtertüten, Eierschalen  Grünschnitt und Laub Das kommt nicht hinein  Plastiktüten, Verpackungen aus Kunststoff und Metall (gelbe Verpackungstonne)  Kehricht und Staubsaugerbeutel (Restmüll)  Zigarettenkippen (Restmüll)  Windeln und andere gebrauchte Hygieneartikel (Restmüll) Standort: am Wohnhaus Leerung: 14-täglich
#
# Die graue Restmülltonne. Das kommt hinein Alle Abfälle, die aufgrund von Verunreinigung oder Vermischung in keine der anderen 3 Tonnen entsorgt werden können (z. können schmutzte Lebensmittelverpackungen), sowie Ihre  Hygieneartikel (z. B. Taschentücher, Damenbinden,  Babywindeln  Staub, Asche, Kehricht  Zigarettenkippen  Küchentücher, Spül- und Putzlappen  Staubsaugerbeutel  Trinkgläser, Porzellan, Keramik, alle Scherben (auch Das kommt nicht hinein  Elektrogeräte/-schrott (Wertstoffhöfe, Großgeräte auch Sperrmüll)  Batterien (spezielle Sammelbehälter in Supermärkten und öffentlichen Gebäuden)  Sonderabfall/Schadstoffe wie Farben, Lacke, Sprays (Schadstoffmobil) Standort: am Wohnhaus Leerung: wöchentlich
#
# B. ver- Wattebäusche) Spiegel) etc.
#
# ==================================================
#
# Document 1:
#
# Was gehört wo Bioabfall Das gehört in die Biotonne ✔ Obst- u. Gemüsereste ✔ Kaffeesatz, Filter, Tee, Teebeutel ✔ Essensreste (auch gekochte) ✔ Alte Lebensmittel (ohne Verpackung) ✔ Eierschalen ✔ Blumen ✔ Gartenabfälle ✔ Laub ✔ Einwickelpapier, z. B. Zeitungs- und Küchenpapier Das bitte nicht in die Biotonne ✘ Kleintierstreu, Katzenstreu, Hundekot ✘ kompostierbare Plastiktüten ✘ Erde, Holz, Grassoden, Sand, Kies, Steine QR-Code scannen! Hier erhalten Sie Informationen in weiteren Sprachen. � يبرع български
#
# rein? - So trenne Restmüll Das gehört in die Restmülltonne ✔ Zigarettenkippen ✔ Asche, Kehricht ✔ Keramik, Porzellan ✔ Tonteller und Töpfe ✔ Putzlappen und Schwämme ✔ Kleintierstreu, Katzenstreu ✔ Staubsaugerbeutel ✔ Wegwerfwindeln ✔ Hygieneartikel Das bitte nicht in die Restmülltonne ✘ Schadstoffe ✘ Batterien, Elektrogeräte ✘ Bauschutt Entsorgungsbetriebe Lübeck Malmöstraße 22 | 23560 Lübeck 中国人 english
#
# ich meinen Müll Altpapier Das gehört in die ✔ Zeitungen und Zeitschriften ✔ Kataloge ✔ Pappe und Kartons ✔ Prospekte ✔ Hefte und Bücher ✔ Packpapier ✔ Pizzakartons (sauber und unbeschichtet) ✔ Eierkartons aus Pappe ✔ Telefonbücher Das bitte nicht in die Papiertonne ✘ Holz ✘ Schmutziges oder ✘ Fotos, Plastiktüten 0451 70760-0 | -710 سیراف français
#
# richtig im Privathaushalt! Gelber Sack Papiertonne Das gehört in den ✔ Joghurt- und Margarinebecher ✔ Verpackungsstyropor ✔ Kunststofftuben ✔ Einweg Kunststoffflaschen ✔ Plastiktüten ✔ Konservendosen ✔ Milch- und Safttüten ✔ Vakuumverpackungen Das bitte nicht in den gelben ✘ Plastikschüsseln ✘ beschichtetes Papier Kleiderbügel ✘ Kunststoffrohre Mo. bis Do. 8 Uhr bis Fr. 8 Uhr bis Română Kurdî Polski
#
# Altglas gelben Sack Das gehört in den Glascontainer ✔ Weißglas ✔ Buntglas ✔ Einwegglasflaschen ✔ Sonstiges Hohlglas Nutzen Sie auch unsere Wertstoffhöfe. Noch Fragen zur Mülltrennung? Wir beraten Sie gerne! Sack Das bitte nicht in den Glascontainer ✘ Fensterscheiben ✘ Porzellan, Keramik, Steingut ✘ Glühbirnen www.entsorgung.luebeck.de 17 Uhr entsorgungsbetriebe@ebhl.de 16 Uhr Türk український русский
#
# ==================================================
#
# Document 2:
#
# In die Glascontainer gehören: ausschließlich restentleerte Glasverpackungen. Die Glasverpackungen sind nach den Farben Weiß, Braun und Grün zu sortieren und in die dafür vorgesehenen Container zu werfen. Nicht zuordenbare Farben, wie z. B. blaues Glas, kommen zum Grünglas. Deckel müssen nicht abgeschraubt werden. Zum Beispiel: · alle nicht bepfandeten Glasflaschen z. B. für Wein, Sekt, Spirituosen, Essig, Öl, Milch, Frucht- und Gemüse- säfte sowie Fruchtnektare · F lakons aus Glas, z. B. Parfümflaschen · Marmeladen-, Gurken- und Senfgläser · sonstiges Verpackungsglas für Obst, Soßen, Suppen, Gemüse GRÜN- GLAS WEISS- BRAUN- GLAS GLAS Nicht in die Glascontainer gehören: sämtliche Abfälle, auch aus Glas, die keine Verpackungen sind. Zum Beispiel: · Auflaufformen · hitzebeständiges Glas · Steingutflaschen · Autolampen · Isolierglas · Teller, Tassen · Autoscheiben · Kaffeekannen · Trinkgläser · Batterien · K amin- und Ofenglas · Bio- und Restabfall · Keramik · Bleiglas · Leuchtstoffröhren · Blumentöpfe · Mikrowellengeschirr · Blumenvasen · Monitorglas · Ceran-Kochfelder · Porzellangeschirr · Flachglas · Produkte und · Getränkekartons Verpackungsbestandteile · Glaskeramik aus Kunststoff · Glaskochplatten · Spiegelglas · Glühbirnen · Spritzen Regionale Ausnahmen sind möglich. Nähere Infos erhältst du bei deiner Kommune. QR-Code scannen oder HIER klicken für deine*n zuständige*n Ansprechpartner*in.
#
# ==================================================
#
# Document 3:
#
# In die Papiertonne gehören: alle Verpackungen und Nicht-Verpackungen aus Papier, Pappe oder Karton, jedoch ohne Anhaftung von Speiseresten. Verpackungen sollten zerkleinert, zusammengelegt oder gefaltet werden. Zum Beispiel Zum Beispiel Nicht-Verpackungen wie: Verpackungen wie: · Briefe · Brötchen-, Metzger- · Briefumschläge und Obsttüten · Bücher · Eierschachteln · Geschenkpapier · Faltschachteln jeglicher Form · Kataloge · Füllmaterial von Versandkartons · Postkarten aus Papier, Pappe und Karton · Schulhefte · Mehl- und Zuckertüten · Werbeprospekte · Nudelkartons · Zeitschriften · Papiertragetaschen · Zeitungen · Pappummantelung von Joghurtbechern u. Ä. · Pizzakartons · Pralinenschachteln Nicht in die Papiertonne gehören: sämtliche Abfälle und Verpackungen, die nicht aus Papier, Pappe und Karton sind. Zum Beispiel: · Batterien · Luftpolster · Bioabfall · Metalle · Butterfolie · Milch- oder Getränkekartons · Dosen · Suppen- und Soßentüten · Fotos · S pezialpapiere, z. B. Backpapier, · Glas Thermopapier, Fotopapier · Holzschachteln · Styropor · Holzwolle · Tapeten · K assenbons und Kontoauszüge · v erschmutzte oder volle (Thermopapiere) Verpackungen · Küchenabfälle · Wein- und Sektkorken · Küchen- und Papiertaschentücher · Kunststoffe Regionale Ausnahmen sind möglich. Nähere Infos erhältst du bei deiner Kommune. QR-Code scannen oder HIER klicken für deine*n zuständige*n Ansprechpartner*in.
#
# ==================================================
#
# Document 4:
#
# I n die Wertstofftonne gehören: Ausschließlich gebrauchte und restlentleerte Verpackungen, die nicht aus Papier, Pappe, Karton oder Glas sind, sowie Gegenstände aus Kunststoff und Metall. Verpackungsbestand- teile bitte voneinander trennen, Ausspülen ist nicht notwendig. Zum Beispiel: · A luminiumfolie, -deckel · Saftflaschen und -schalen · Schaumstoffe · Arzneimittelblister (leer) · Schrauben · B esteck · Spielzeug · Flaschenverschlüsse · Töpfe · Folien · Werkzeuge · G ebrauchsgegenstände wie z. B. Gießkannen, Blumentöpfe und Plastikschüsseln · Getränkedosen · Getränkekartons · Joghurt- und Margarinebecher · Konservendosen · K unststoffflaschen wie z. B. Pflegemittel-, Spül- und Waschmittelflaschen N icht in die Wertstofftonne gehören: Verpackungen aus Papier, Pappe, Karton und Glas sowie sämtliche Restabfälle. Zum Beispiel: · Verpackte bzw. „alte“ · Keramik · Akkus abgelagerte Lebensmittel · K leiderbügel aus Holz · Batterien · Windeln · Kfz-Kleinteile · Bauabfälle · Zigarettenkippen · Medikamentenreste · Datenträger · Mund- und Nasenschutz · Elektrogeräte · Porzellan · Energiesparlampen · Schuhe · Gummi · Spritzen · Holz und Holzreste · Strumpfhosen · Hygieneartikel wie Windeln, · Styroporreste von Dämmplatten Binden, Wattereste · Tapetenreste und Kondome · Textilien · Kabel · Video- und Audiokassetten · Kanülen Regionale Ausnahmen sind möglich. Nähere Infos erhältst du bei deiner Kommune. QR-Code scannen oder HIER klicken für deine*n zuständige*n Ansprechpartner*in.
#
# ==================================================
#
# Document 5:
#
# In die Gelbe Tonne/den Gelben Sack gehören: ausschließlich gebrauchte und restentleerte Verpackungen, die nicht aus Papier, Pappe, Karton oder Glas sind. Verpackungsbestandteile bitte voneinander trennen. Ausspülen ist nicht notwendig. Zum Beispiel: · A lu-, Blech- und · Menüschalen von Kunststoffdeckel Fertiggerichten · Arzneimittelblister · Milch- und · Butterfolie Getränkekartons · Buttermilch- und · Müsliriegelfolie Joghurtbecher · Nudeltüten · Einkaufstüten sowie · Putz- und Reinigungsmittelflaschen Obst- und Gemüsebeutel · Q uetsch- oder Nachfüllbeutel aus Kunststoff z. B. für Waschmittel, Flüssigseife · Eisverpackungen oder Fruchtpüree · F üllmaterial von Versand- · Senftuben verpackungen aus Kunststoff, · Shampooflaschen wie z. B. Luftpolsterfolie · Spraydosen oder Schaumstoff · Suppen- und Soßentüten · Konservendosen · Tierfutterdosen und -schalen · Kronkorken · Zahnpastatuben · Kunststoffschalen und -folien für Lebensmittel Nicht in die Gelbe Tonne/den Gelben Sack gehören: Verpackungen aus Papier, Pappe, Karton und Glas sowie sämtliche Abfälle, die keine Verpackungen sind. Zum Beispiel: · Schuhe · Altkleider · Gummi · Strumpfhosen · Batterien und Akkus · Holzwolle · Styroporreste von · Behälterglas · Hygieneartikel Dämmplatten · Blechgeschirr · Katzenstreu · Tapetenreste · CDs und Disketten · Keramikprodukte · Windeln · Druckerpatronen · Kinderspielzeug · Zahnbürsten · Einwegrasierer · Klarsichthüllen · Zigarettenkippen · Elektrogeräte · Kugelschreiber · Essensreste · nicht restentleerte Verpackungen · Faltschachteln · Papier und Pappe · Feuerzeuge · Papiertaschentücher · F ilme, DVDs und · Pflaster, Verbandsmaterial Videokassetten · Porzellan · Glüh- und Energiesparlampen · Rest- und Bioabfälle Regionale Ausnahmen sind möglich (z. B. Wertstofftonne). Nähere Infos erhältst du bei deiner Kommune. QR-Code scannen oder HIER klicken für deine*n zuständige*n Ansprechpartner*in.
#
# ==================================================

# %%
import os
import pickle

def save_new_documents(documents, filename="documents.pkl"):
    # Sicherstellen, dass der Ordner, in dem die Datei gespeichert wird, existiert
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    
    # Speichern der Dokumente im angegebenen Pfad
    with open(filename, "wb") as file:
        pickle.dump(documents, file)
    
    print(f"Die Datei '{filename}' wurde erfolgreich gespeichert.")

# Beispielnutzung:
save_new_documents(documents, filename="data/pickle/documents.pkl")
# Out:
# Die Datei 'data/pickle/documents.pkl' wurde erfolgreich gespeichert.

# %%
import re

def normalize_text(documents):
    """Normalisiert die Dokumente und entfernt unnötige Zeichen."""
    normalized_documents = []

    for document in documents:
        text = document.lower()
        text = re.sub(r'\b(?:[\w\-]+\.)+[\w]{2,4}(?:/[\w\-.?%&=]*)?\b', '', text)
        text = re.sub(r'\b[\w\.\-]+@[\w\.\-]+\.\w{2,4}\b', '', text)
        text = re.sub(r'\b(?:www|servicetelefon|servicetelefax|services|frankfurt|main|weidenbornstraße|liebfrauenberg)\b', '', text)
        text = re.sub(r'[^a-zäöüß\s]', '', text)
        normalized_documents.append(text.strip())

    return normalized_documents

# Beispielnutzung:
normalized_documents = normalize_text(documents)
# Ausgabe der normalisierten Dokumente
for i, doc in enumerate(normalized_documents):
    print(f"Normalized Document {i}:\n")
    print(doc)
    print("\n" + "="*50 + "\n")
# Out:
# Normalized Document 0:
#
# der blaue altglascontainer das kommt hinein saubere flaschen und deckelgläser nach den farben weiß grün und braun getrennt blaues oder buntes glas bitte zum grünglas geben  glasfl aschen  konservengläser das kommt nicht hinein  flachglas wie spiegel und scheiben restmüll oder  trinkgläser und blumenvasen restmüll  porzellan und keramik restmüll  glühbirnen restmüll energiesparlampen schadstoffmobil oder wertstoffhöfe  stark verschmutzte gläser restmüll standort auf öffentlichen
#
# immer sperrmüll plätzen
#
# was kommt wo hinein fes frankfurter entsorgungs abfall richtig trennen  und service gmbh     am          fesservicecenter   ecke töngesgasseschärfengässchen   am  mo  fr    uhr sa    uhr rgungsfachbetrie entso b rtschafteveddn oe el ök tsn  gla sn we rgergemeinschaftz de efür rrt dei nif di uk tma cht en s a m hae enl nn e elb ne vf tö sr od rae gr bn uf l eg r in u b se d o n ä l n n
#
# richtig trennen leicht gemacht zu jedem haus in  gehören  abfallbehälter  tonnen inhalt als wertvoller rohstoff zu neuen produkten weiterverarbeitet und die graue restmülltonne  die gelbe tonne für verpackungen  die grüne tonne für papier und pappe  die braune tonne für bioabfälle  die graue tonne für den restlichen abfall den restmüll darüber hinaus gibt es folgende entsorgungsangebote wertstoffe sichern altglas altglascontainer für flaschen und deckelgläser fi nden sie an öffentlichen plätzen altkleider container für altkleider und schuhe fi nden sie in jedem stadtteil öffentlichen plätzen sowie auf den feswertstoffhöfen schadstoffe abfälle aus oder mit gefährlichen stoffen wie farben spraydosen mitteln etc können sie am fesschadstoffmobil abgeben alle und termine fi nden sie auf  oder im oskar das dreimal im jahr an alle haushalte verteilt wird sperrmüllabholung m bis zu  holt die fes kostenlos bei ihnen ab einen termin sie am    oder unter in manchen wohnsiedlungen wird sperrmüll automatisch alle abgeholt  die termine fi nden sie am schwarzen brett in ihrem sperrmüll und wertstoffe selbst entsorgen so e ai ln pe an k ieo rf f e vr er ra pu am v uo nl gl e n m w ia en s lep ke tr rr om sü chll r g ttrü kn ös nc nh en nit t s ea l at um fe t p ck e o i af we bs w fw afe llr st bs et ro hnff äkh lö tf ee rn ea b og ne wb tie an ii m fe reh sr i en saf go erm la et i no sn ke an fi nden sie w  e f a f u r t d s o e nm b m ta z li n o r   c e sollten ihre abfalltonnen am haus auf dauer nicht ausreichen sie als hausbesitzer weiteregrößere bestellen im internet  oder per servicefax   über spezialbehälter für besondere abfälle z b baustellenabfälle erfahren sie unter unserer servicetelefonnummer   die kosten für den sperrmüll sind in ihrer abfallgebühr enthalten
#
# deren wird auf löse standorte fesmagazin erhalten   wochen haus dt ea nll  auf können auf näheres u ä
#
# die gelbe verpackungstonne das kommt hinein alle verpackungen mit oder ohne symbol wie den grünen die nicht ausschließlich aus papier pappe oder glas bestehen die verpackungen müssen nicht gespült aber leer sein  verpackungen aus kunststoff wie folien becher und  verbundverpackungen aus materialmix z b alu  papier wie getränkekartons und milchtüten  verpackungen aus metall wie konserven und getränkedosen  geschäumte kunststoffe z b obst und gemüseverpackungen das kommt nicht hinein  verpackungen aus papier und pappe altpapiertonne  verpackungen aus glas altglascontainer  stark verschmutzte fastfoodverpackungen wie pizzakartons restmüll ist zu viel restmüll in der gelben tonne können die nicht mehr aussortiert und weiterverarbeitet werden standort am wohnhaus leerung täglich
#
# die grüne altpapiertonne das kommt hinein punkt in die grüne altpapiertonne gehören papier und pappe  ohne beschichtung und unverschmutzt  pappen und kartonagen  styropor zeitungen illustrierte kataloge  bücher und hefte das kommt nicht hinein  stark verschmutztes papier restmüll  beschichtetes papier restmüll  pergament und hygienepapiere windeln restmüll näheres über sichere aktenvernichtung erfahren sie unter der servicetelefonnummer   wertstoffe standort am wohnhaus leerung täglich
#
# die braune biotonne das kommt hinein alle biologisch abbaubaren abfälle aus privaten haushalten feuchte bioabfälle wie salat oder obst und gemüsereste sie in zeitungs oder küchenpapier wickeln so schützen sie tonne vor starker verschmutzung und geruch  obst und gemüseabfälle auch zitrusfrüchte bananen und nussschalen  rohe und gekochte speise und lebensmittelreste  kaffee und teesatz filtertüten eierschalen  grünschnitt und laub das kommt nicht hinein  plastiktüten verpackungen aus kunststoff und metall gelbe verpackungstonne  kehricht und staubsaugerbeutel restmüll  zigarettenkippen restmüll  windeln und andere gebrauchte hygieneartikel restmüll standort am wohnhaus leerung täglich
#
# die graue restmülltonne das kommt hinein alle abfälle die aufgrund von verunreinigung oder vermischung in keine der anderen  tonnen entsorgt werden können z können schmutzte lebensmittelverpackungen sowie ihre  hygieneartikel z b taschentücher damenbinden  babywindeln  staub asche kehricht  zigarettenkippen  küchentücher spül und putzlappen  staubsaugerbeutel  trinkgläser porzellan keramik alle scherben auch das kommt nicht hinein  elektrogeräteschrott wertstoffhöfe großgeräte auch sperrmüll  batterien spezielle sammelbehälter in supermärkten und öffentlichen gebäuden  sonderabfallschadstoffe wie farben lacke sprays schadstoffmobil standort am wohnhaus leerung wöchentlich
#
# b ver wattebäusche spiegel etc
#
# ==================================================
#
# Normalized Document 1:
#
# was gehört wo bioabfall das gehört in die biotonne  obst u gemüsereste  kaffeesatz filter tee teebeutel  essensreste auch gekochte  alte lebensmittel ohne verpackung  eierschalen  blumen  gartenabfälle  laub  einwickelpapier z b zeitungs und küchenpapier das bitte nicht in die biotonne  kleintierstreu katzenstreu hundekot  kompostierbare plastiktüten  erde holz grassoden sand kies steine qrcode scannen hier erhalten sie informationen in weiteren sprachen
#
# rein  so trenne restmüll das gehört in die restmülltonne  zigarettenkippen  asche kehricht  keramik porzellan  tonteller und töpfe  putzlappen und schwämme  kleintierstreu katzenstreu  staubsaugerbeutel  wegwerfwindeln  hygieneartikel das bitte nicht in die restmülltonne  schadstoffe  batterien elektrogeräte  bauschutt entsorgungsbetriebe lübeck malmöstraße    lübeck  english
#
# ich meinen müll altpapier das gehört in die  zeitungen und zeitschriften  kataloge  pappe und kartons  prospekte  hefte und bücher  packpapier  pizzakartons sauber und unbeschichtet  eierkartons aus pappe  telefonbücher das bitte nicht in die papiertonne  holz  schmutziges oder  fotos plastiktüten      franais
#
# richtig im privathaushalt gelber sack papiertonne das gehört in den  joghurt und margarinebecher  verpackungsstyropor  kunststofftuben  einweg kunststoffflaschen  plastiktüten  konservendosen  milch und safttüten  vakuumverpackungen das bitte nicht in den gelben  plastikschüsseln  beschichtetes papier kleiderbügel  kunststoffrohre mo bis do  uhr bis fr  uhr bis romn kurd polski
#
# altglas gelben sack das gehört in den glascontainer  weißglas  buntglas  einwegglasflaschen  sonstiges hohlglas nutzen sie auch unsere wertstoffhöfe noch fragen zur mülltrennung wir beraten sie gerne sack das bitte nicht in den glascontainer  fensterscheiben  porzellan keramik steingut  glühbirnen   uhr entsorgungsbetriebe  uhr türk
#
# ==================================================
#
# Normalized Document 2:
#
# in die glascontainer gehören ausschließlich restentleerte glasverpackungen die glasverpackungen sind nach den farben weiß braun und grün zu sortieren und in die dafür vorgesehenen container zu werfen nicht zuordenbare farben wie z b blaues glas kommen zum grünglas deckel müssen nicht abgeschraubt werden zum beispiel  alle nicht bepfandeten glasflaschen z b für wein sekt spirituosen essig öl milch frucht und gemüse säfte sowie fruchtnektare  f lakons aus glas z b parfümflaschen  marmeladen gurken und senfgläser  sonstiges verpackungsglas für obst soßen suppen gemüse grün glas weiss braun glas glas nicht in die glascontainer gehören sämtliche abfälle auch aus glas die keine verpackungen sind zum beispiel  auflaufformen  hitzebeständiges glas  steingutflaschen  autolampen  isolierglas  teller tassen  autoscheiben  kaffeekannen  trinkgläser  batterien  k amin und ofenglas  bio und restabfall  keramik  bleiglas  leuchtstoffröhren  blumentöpfe  mikrowellengeschirr  blumenvasen  monitorglas  cerankochfelder  porzellangeschirr  flachglas  produkte und  getränkekartons verpackungsbestandteile  glaskeramik aus kunststoff  glaskochplatten  spiegelglas  glühbirnen  spritzen regionale ausnahmen sind möglich nähere infos erhältst du bei deiner kommune qrcode scannen oder hier klicken für deinen zuständigen ansprechpartnerin
#
# ==================================================
#
# Normalized Document 3:
#
# in die papiertonne gehören alle verpackungen und nichtverpackungen aus papier pappe oder karton jedoch ohne anhaftung von speiseresten verpackungen sollten zerkleinert zusammengelegt oder gefaltet werden zum beispiel zum beispiel nichtverpackungen wie verpackungen wie  briefe  brötchen metzger  briefumschläge und obsttüten  bücher  eierschachteln  geschenkpapier  faltschachteln jeglicher form  kataloge  füllmaterial von versandkartons  postkarten aus papier pappe und karton  schulhefte  mehl und zuckertüten  werbeprospekte  nudelkartons  zeitschriften  papiertragetaschen  zeitungen  pappummantelung von joghurtbechern u ä  pizzakartons  pralinenschachteln nicht in die papiertonne gehören sämtliche abfälle und verpackungen die nicht aus papier pappe und karton sind zum beispiel  batterien  luftpolster  bioabfall  metalle  butterfolie  milch oder getränkekartons  dosen  suppen und soßentüten  fotos  s pezialpapiere z b backpapier  glas thermopapier fotopapier  holzschachteln  styropor  holzwolle  tapeten  k assenbons und kontoauszüge  v erschmutzte oder volle thermopapiere verpackungen  küchenabfälle  wein und sektkorken  küchen und papiertaschentücher  kunststoffe regionale ausnahmen sind möglich nähere infos erhältst du bei deiner kommune qrcode scannen oder hier klicken für deinen zuständigen ansprechpartnerin
#
# ==================================================
#
# Normalized Document 4:
#
# i n die wertstofftonne gehören ausschließlich gebrauchte und restlentleerte verpackungen die nicht aus papier pappe karton oder glas sind sowie gegenstände aus kunststoff und metall verpackungsbestand teile bitte voneinander trennen ausspülen ist nicht notwendig zum beispiel  a luminiumfolie deckel  saftflaschen und schalen  schaumstoffe  arzneimittelblister leer  schrauben  b esteck  spielzeug  flaschenverschlüsse  töpfe  folien  werkzeuge  g ebrauchsgegenstände wie z b gießkannen blumentöpfe und plastikschüsseln  getränkedosen  getränkekartons  joghurt und margarinebecher  konservendosen  k unststoffflaschen wie z b pflegemittel spül und waschmittelflaschen n icht in die wertstofftonne gehören verpackungen aus papier pappe karton und glas sowie sämtliche restabfälle zum beispiel  verpackte bzw alte  keramik  akkus abgelagerte lebensmittel  k leiderbügel aus holz  batterien  windeln  kfzkleinteile  bauabfälle  zigarettenkippen  medikamentenreste  datenträger  mund und nasenschutz  elektrogeräte  porzellan  energiesparlampen  schuhe  gummi  spritzen  holz und holzreste  strumpfhosen  hygieneartikel wie windeln  styroporreste von dämmplatten binden wattereste  tapetenreste und kondome  textilien  kabel  video und audiokassetten  kanülen regionale ausnahmen sind möglich nähere infos erhältst du bei deiner kommune qrcode scannen oder hier klicken für deinen zuständigen ansprechpartnerin
#
# ==================================================
#
# Normalized Document 5:
#
# in die gelbe tonneden gelben sack gehören ausschließlich gebrauchte und restentleerte verpackungen die nicht aus papier pappe karton oder glas sind verpackungsbestandteile bitte voneinander trennen ausspülen ist nicht notwendig zum beispiel  a lu blech und  menüschalen von kunststoffdeckel fertiggerichten  arzneimittelblister  milch und  butterfolie getränkekartons  buttermilch und  müsliriegelfolie joghurtbecher  nudeltüten  einkaufstüten sowie  putz und reinigungsmittelflaschen obst und gemüsebeutel  q uetsch oder nachfüllbeutel aus kunststoff z b für waschmittel flüssigseife  eisverpackungen oder fruchtpüree  f üllmaterial von versand  senftuben verpackungen aus kunststoff  shampooflaschen wie z b luftpolsterfolie  spraydosen oder schaumstoff  suppen und soßentüten  konservendosen  tierfutterdosen und schalen  kronkorken  zahnpastatuben  kunststoffschalen und folien für lebensmittel nicht in die gelbe tonneden gelben sack gehören verpackungen aus papier pappe karton und glas sowie sämtliche abfälle die keine verpackungen sind zum beispiel  schuhe  altkleider  gummi  strumpfhosen  batterien und akkus  holzwolle  styroporreste von  behälterglas  hygieneartikel dämmplatten  blechgeschirr  katzenstreu  tapetenreste  cds und disketten  keramikprodukte  windeln  druckerpatronen  kinderspielzeug  zahnbürsten  einwegrasierer  klarsichthüllen  zigarettenkippen  elektrogeräte  kugelschreiber  essensreste  nicht restentleerte verpackungen  faltschachteln  papier und pappe  feuerzeuge  papiertaschentücher  f ilme dvds und  pflaster verbandsmaterial videokassetten  porzellan  glüh und energiesparlampen  rest und bioabfälle regionale ausnahmen sind möglich z b wertstofftonne nähere infos erhältst du bei deiner kommune qrcode scannen oder hier klicken für deinen zuständigen ansprechpartnerin
#
# ==================================================

# %%
import spacy

# Lade das deutsche Sprachmodell
nlp = spacy.load('de_core_news_sm')

# Wörterbuch zur Korrektur von Lemmata und POS-Tags
manual_corrections = {
    "deckelgläser": ("NOUN", "Deckelglas"),
    "konservengläser": ("NOUN", "Konservenglas"),
    "keramik": ("NOUN", "Keramik"),
    "glühbirnen": ("NOUN", "Glühbirne"),
    "energiesparlampen": ("NOUN", "Energiesparlampe"),
    "weiß": ("ADJ", "weiß"),
    "lacke": ("NOUN", "Lack"),
    "wertstoffhöfe": ("NOUN", "Wertstoffhof"),
}

def correct_token(token):
    if token.text.lower() in manual_corrections:
        return manual_corrections[token.text.lower()]
    else:
        lemma = token.lemma_
        pos = token.pos_
        return pos, lemma

def pos_tagging(documents):
    """Führt POS-Tagging und Lemmatisierung durch."""
    processed_documents = []

    for doc in documents:
        spacy_doc = nlp(doc)
        processed_tokens = []

        for token in spacy_doc:
            pos, lemma = correct_token(token)
            if pos in {"NOUN", "VERB", "ADJ"}:
                processed_tokens.append((token.text, pos, lemma))
        
        processed_documents.append(processed_tokens)

    return processed_documents

# Beispielnutzung:
pos_tagged_documents = pos_tagging(normalized_documents)

# Ausgabe der POS-getaggten Dokumente
for i, doc in enumerate(pos_tagged_documents):
    print(f"POS-Tagged Document {i}:\n")
    for token_info in doc:
        print(token_info)
    print("\n" + "="*50 + "\n")
# Out:
# POS-Tagged Document 0:
#
# ('blaue', 'ADJ', 'blau')
# ('altglascontainer', 'NOUN', 'Altglascontainer')
# ('kommt', 'VERB', 'kommen')
# ('saubere', 'ADJ', 'sauber')
# ('flaschen', 'NOUN', 'Flasche')
# ('deckelgläser', 'NOUN', 'Deckelglas')
# ('farben', 'NOUN', 'Farbe')
# ('weiß', 'ADJ', 'weiß')
# ('blaues', 'ADJ', 'blau')
# ('buntes', 'ADJ', 'bunt')
# ('glas', 'NOUN', 'Glas')
# ('grünglas', 'NOUN', 'Grünglas')
# ('geben', 'VERB', 'geben')
# ('aschen', 'ADJ', 'asch')
# ('konservengläser', 'NOUN', 'Konservenglas')
# ('kommt', 'VERB', 'kommen')
# ('scheiben', 'VERB', 'Scheiben')
# ('restmüll', 'NOUN', 'Restmüll')
# ('trinkgläser', 'NOUN', 'Trinkgläser')
# ('porzellan', 'NOUN', 'Porzellan')
# ('keramik', 'NOUN', 'Keramik')
# ('glühbirnen', 'NOUN', 'Glühbirne')
# ('restmüll', 'NOUN', 'Restmüll')
# ('energiesparlampen', 'NOUN', 'Energiesparlampe')
# ('wertstoffhöfe', 'NOUN', 'Wertstoffhof')
# ('verschmutzte', 'ADJ', 'verschmutzt')
# ('gläser', 'ADJ', 'Gläser')
# ('restmüll', 'ADJ', 'Restmüll')
# ('standort', 'NOUN', 'Standort')
# ('öffentlichen', 'ADJ', 'öffentlich')
# ('sperrmüll', 'VERB', 'Sperrmüll')
# ('plätzen', 'VERB', 'plätzen')
# ('kommt', 'VERB', 'kommen')
# ('fes', 'ADJ', 'f')
# ('frankfurter', 'ADJ', 'Frankfurter')
# ('entsorgungs', 'NOUN', 'Entsorgung')
# ('abfall', 'NOUN', 'Abfall')
# ('trennen', 'VERB', 'trennen')
# ('service', 'NOUN', 'Service')
# ('gmbh', 'VERB', 'Gmbh')
# ('fesservicecenter', 'NOUN', 'Fesservicecenter')
# ('ecke', 'NOUN', 'Ecke')
# ('töngesgasseschärfengässchen', 'VERB', 'töngesgasseschärfengässchen')
# ('uhr', 'NOUN', 'Uhr')
# ('uhr', 'NOUN', 'Uhr')
# ('rgungsfachbetrie', 'NOUN', 'Rgungsfachbetrie')
# ('rrt', 'VERB', 'rren')
# ('trennen', 'VERB', 'trennen')
# ('gemacht', 'VERB', 'machen')
# ('haus', 'NOUN', 'Haus')
# ('gehören', 'VERB', 'gehören')
# ('abfallbehälter', 'NOUN', 'Abfallbehälter')
# ('tonnen', 'NOUN', 'Tonne')
# ('inhalt', 'NOUN', 'Inhalt')
# ('wertvoller', 'ADJ', 'Wertvoller')
# ('rohstoff', 'NOUN', 'Rohstoff')
# ('neuen', 'ADJ', 'neu')
# ('produkten', 'NOUN', 'Produkt')
# ('weiterverarbeitet', 'VERB', 'weiterverarbeiten')
# ('graue', 'ADJ', 'grau')
# ('restmülltonne', 'NOUN', 'Restmülltonne')
# ('gelbe', 'ADJ', 'gelb')
# ('tonne', 'NOUN', 'Tonne')
# ('verpackungen', 'NOUN', 'verpackunger')
# ('grüne', 'ADJ', 'grün')
# ('tonne', 'NOUN', 'Tonne')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('braune', 'ADJ', 'braun')
# ('tonne', 'NOUN', 'Tonne')
# ('bioabfälle', 'ADJ', 'bioabfälle')
# ('graue', 'ADJ', 'grau')
# ('tonne', 'NOUN', 'Tonne')
# ('restlichen', 'ADJ', 'restlich')
# ('abfall', 'NOUN', 'Abfall')
# ('restmüll', 'NOUN', 'Restmüll')
# ('gibt', 'VERB', 'geben')
# ('folgende', 'ADJ', 'folgend')
# ('entsorgungsangebote', 'ADJ', 'entsorgungsangebot')
# ('wertstoffe', 'NOUN', 'wertstoffe')
# ('sichern', 'VERB', 'sichern')
# ('altglascontainer', 'NOUN', 'Altglascontainer')
# ('flaschen', 'NOUN', 'Flasche')
# ('deckelgläser', 'NOUN', 'Deckelglas')
# ('nden', 'VERB', 'nden')
# ('öffentlichen', 'ADJ', 'öffentlich')
# ('plätzen', 'NOUN', 'Plätz')
# ('altkleider', 'NOUN', 'altkleid')
# ('container', 'NOUN', 'Container')
# ('altkleider', 'NOUN', 'altkleider')
# ('schuhe', 'NOUN', 'schuhen')
# ('nden', 'VERB', 'nden')
# ('stadtteil', 'NOUN', 'Stadtteil')
# ('öffentlichen', 'ADJ', 'öffentlich')
# ('plätzen', 'NOUN', 'Plätz')
# ('feswertstoffhöfen', 'NOUN', 'Feswertstoffhöf')
# ('schadstoffe', 'NOUN', 'Schadstoff')
# ('abfälle', 'NOUN', 'Abfäll')
# ('gefährlichen', 'ADJ', 'gefährlich')
# ('stoffen', 'NOUN', 'Stoff')
# ('farben', 'NOUN', 'farbe')
# ('spraydosen', 'NOUN', 'Spraydos')
# ('mitteln', 'VERB', 'mitteln')
# ('fesschadstoffmobil', 'NOUN', 'Fesschadstoffmobil')
# ('abgeben', 'VERB', 'abgeben')
# ('termine', 'NOUN', 'terminen')
# ('nden', 'VERB', 'nden')
# ('jahr', 'NOUN', 'Jahr')
# ('haushalte', 'NOUN', 'Haushalt')
# ('verteilt', 'VERB', 'verteilen')
# ('sperrmüllabholung', 'NOUN', 'Sperrmüllabholung')
# ('holt', 'VERB', 'holen')
# ('fes', 'NOUN', 'fes')
# ('termin', 'NOUN', 'Termin')
# ('wohnsiedlungen', 'NOUN', 'Wohnsiedlung')
# ('abgeholt', 'VERB', 'abholen')
# ('termine', 'NOUN', 'termin')
# ('nden', 'VERB', 'nden')
# ('schwarzen', 'ADJ', 'schwarz')
# ('brett', 'NOUN', 'Brett')
# ('sperrmüll', 'NOUN', 'Sperrmüll')
# ('wertstoffe', 'VERB', 'Wertstoff')
# ('entsorgen', 'VERB', 'entsorgen')
# ('v', 'ADJ', 'v')
# ('uo', 'NOUN', 'uo')
# ('hnff', 'VERB', 'Hnff')
# ('tie', 'NOUN', 'tie')
# ('nden', 'VERB', 'nd')
# ('abfalltonnen', 'NOUN', 'Abfalltonn')
# ('haus', 'NOUN', 'Haus')
# ('dauer', 'NOUN', 'Dauer')
# ('ausreichen', 'VERB', 'ausreichen')
# ('hausbesitzer', 'NOUN', 'hausbesitz')
# ('weiteregrößere', 'ADJ', 'Weiteregrößere')
# ('bestellen', 'VERB', 'bestellen')
# ('internet', 'NOUN', 'Internet')
# ('spezialbehälter', 'NOUN', 'Spezialbehälter')
# ('besondere', 'ADJ', 'besonderer')
# ('abfälle', 'NOUN', 'abfäll')
# ('z', 'NOUN', 'z')
# ('baustellenabfälle', 'VERB', 'baustellenabfälle')
# ('erfahren', 'VERB', 'erfahren')
# ('servicetelefonnummer', 'NOUN', 'Servicetelefonnummer')
# ('kosten', 'NOUN', 'Kosten')
# ('sperrmüll', 'NOUN', 'Sperrmüll')
# ('abfallgebühr', 'NOUN', 'Abfallgebühr')
# ('enthalten', 'VERB', 'enthalten')
# ('löse', 'ADJ', 'lös')
# ('standorte', 'ADJ', 'standort')
# ('fesmagazin', 'NOUN', 'Fesmagazin')
# ('erhalten', 'VERB', 'erhalten')
# ('wochen', 'NOUN', 'Woche')
# ('haus', 'NOUN', 'Haus')
# ('näheres', 'NOUN', 'Näheres')
# ('gelbe', 'ADJ', 'gelb')
# ('verpackungstonne', 'NOUN', 'Verpackungstonne')
# ('kommt', 'VERB', 'kommen')
# ('verpackungen', 'NOUN', 'Verpackunge')
# ('symbol', 'NOUN', 'Symbol')
# ('grünen', 'NOUN', 'grüne')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('glas', 'NOUN', 'Glas')
# ('bestehen', 'VERB', 'bestehen')
# ('verpackungen', 'NOUN', 'verpackunge')
# ('gespült', 'VERB', 'spülen')
# ('verpackungen', 'NOUN', 'verpackungen')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('folien', 'NOUN', 'folien')
# ('becher', 'ADJ', 'bech')
# ('verbundverpackungen', 'NOUN', 'Verbundverpackung')
# ('materialmix', 'NOUN', 'Materialmix')
# ('papier', 'NOUN', 'Papier')
# ('getränkekartons', 'NOUN', 'Getränkekarton')
# ('milchtüten', 'VERB', 'milchtüen')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('metall', 'NOUN', 'Metall')
# ('konserven', 'NOUN', 'Konserve')
# ('getränkedosen', 'ADJ', 'getränkedosen')
# ('geschäumte', 'ADJ', 'geschäumt')
# ('kunststoffe', 'NOUN', 'kunststoff')
# ('gemüseverpackungen', 'VERB', 'gemüseverpackungen')
# ('kommt', 'VERB', 'kommen')
# ('verpackungen', 'NOUN', 'verpackungen')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('verpackungen', 'NOUN', 'verpackungen')
# ('glas', 'NOUN', 'Glas')
# ('altglascontainer', 'ADJ', 'altglascontain')
# ('verschmutzte', 'ADJ', 'verschmutzt')
# ('fastfoodverpackungen', 'NOUN', 'Fastfoodverpackung')
# ('restmüll', 'NOUN', 'Restmüll')
# ('restmüll', 'NOUN', 'Restmüll')
# ('gelben', 'ADJ', 'gelb')
# ('tonne', 'NOUN', 'Tonne')
# ('aussortiert', 'VERB', 'aussortieren')
# ('weiterverarbeitet', 'VERB', 'weiterverarbeitet')
# ('standort', 'NOUN', 'Standort')
# ('wohnhaus', 'NOUN', 'Wohnhaus')
# ('leerung', 'NOUN', 'Leerung')
# ('grüne', 'ADJ', 'grün')
# ('altpapiertonne', 'NOUN', 'Altpapiertonne')
# ('kommt', 'VERB', 'kommen')
# ('punkt', 'NOUN', 'Punkt')
# ('grüne', 'ADJ', 'grün')
# ('altpapiertonne', 'NOUN', 'altpapiertonn')
# ('gehören', 'VERB', 'gehören')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('beschichtung', 'NOUN', 'Beschichtung')
# ('pappen', 'NOUN', 'Pappe')
# ('kartonagen', 'ADJ', 'kartonag')
# ('styropor', 'NOUN', 'Styropor')
# ('zeitungen', 'NOUN', 'Zeitung')
# ('illustrierte', 'ADJ', 'illustriert')
# ('kataloge', 'NOUN', 'Kataloge')
# ('bücher', 'NOUN', 'büch')
# ('hefte', 'VERB', 'hefen')
# ('kommt', 'VERB', 'kommen')
# ('verschmutztes', 'ADJ', 'verschmutzt')
# ('papier', 'NOUN', 'Papier')
# ('restmüll', 'NOUN', 'Restmüll')
# ('beschichtetes', 'ADJ', 'beschichtet')
# ('papier', 'NOUN', 'Papier')
# ('restmüll', 'NOUN', 'Restmüll')
# ('hygienepapiere', 'ADJ', 'hygienepapi')
# ('windeln', 'NOUN', 'windeln')
# ('restmüll', 'NOUN', 'Restmüll')
# ('näheres', 'NOUN', 'Näheres')
# ('sichere', 'ADJ', 'sicher')
# ('aktenvernichtung', 'NOUN', 'Aktenvernichtung')
# ('erfahren', 'VERB', 'erfahren')
# ('servicetelefonnummer', 'NOUN', 'Servicetelefonnummer')
# ('wertstoffe', 'ADJ', 'wertstoff')
# ('standort', 'NOUN', 'Standort')
# ('wohnhaus', 'NOUN', 'Wohnhaus')
# ('leerung', 'NOUN', 'Leerung')
# ('braune', 'ADJ', 'braun')
# ('biotonne', 'VERB', 'biotonnen')
# ('kommt', 'VERB', 'kommen')
# ('abbaubaren', 'ADJ', 'abbaubar')
# ('abfälle', 'NOUN', 'Abfall')
# ('privaten', 'ADJ', 'privat')
# ('haushalten', 'NOUN', 'Haushalt')
# ('feuchte', 'ADJ', 'feucht')
# ('bioabfälle', 'NOUN', 'Bioabfäll')
# ('salat', 'NOUN', 'Salat')
# ('obst', 'NOUN', 'Obst')
# ('gemüsereste', 'VERB', 'gemüseresen')
# ('zeitungs', 'NOUN', 'Zeitungs')
# ('wickeln', 'VERB', 'wickeln')
# ('schützen', 'VERB', 'schützen')
# ('tonne', 'VERB', 'tonnen')
# ('starker', 'ADJ', 'stark')
# ('verschmutzung', 'NOUN', 'Verschmutzung')
# ('gemüseabfälle', 'NOUN', 'Gemüseabfälle')
# ('zitrusfrüchte', 'ADJ', 'zitrusfrücht')
# ('bananen', 'NOUN', 'Banane')
# ('nussschalen', 'VERB', 'nussschalen')
# ('rohe', 'ADJ', 'roh')
# ('gekochte', 'ADJ', 'gekocht')
# ('speise', 'NOUN', 'Speise')
# ('lebensmittelreste', 'ADJ', 'lebensmittelr')
# ('kaffee', 'NOUN', 'Kaffee')
# ('teesatz', 'NOUN', 'Teesatz')
# ('filtertüten', 'VERB', 'filtertüt')
# ('eierschalen', 'ADJ', 'Eierschale')
# ('grünschnitt', 'NOUN', 'Grünschnitt')
# ('kommt', 'VERB', 'kommen')
# ('plastiktüten', 'VERB', 'plastiktüt')
# ('verpackungen', 'NOUN', 'Verpackunge')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('metall', 'NOUN', 'Metall')
# ('gelbe', 'ADJ', 'gelb')
# ('verpackungstonne', 'NOUN', 'Verpackungstonne')
# ('kehricht', 'VERB', 'Kehricht')
# ('windeln', 'VERB', 'windeln')
# ('andere', 'ADJ', 'anderer')
# ('gebrauchte', 'NOUN', 'Gebraucht')
# ('restmüll', 'ADJ', 'Restmüll')
# ('standort', 'NOUN', 'Standort')
# ('wohnhaus', 'NOUN', 'Wohnhaus')
# ('leerung', 'NOUN', 'Leerung')
# ('graue', 'ADJ', 'grau')
# ('restmülltonne', 'NOUN', 'Restmülltonne')
# ('kommt', 'VERB', 'kommen')
# ('abfälle', 'NOUN', 'Abfall')
# ('verunreinigung', 'NOUN', 'Verunreinigung')
# ('vermischung', 'NOUN', 'Vermischung')
# ('anderen', 'ADJ', 'anderer')
# ('tonnen', 'NOUN', 'Tonne')
# ('entsorgt', 'VERB', 'entsorgen')
# ('z', 'NOUN', 'z')
# ('schmutzte', 'NOUN', 'schmutzt')
# ('lebensmittelverpackungen', 'NOUN', 'lebensmittelverpackungen')
# ('taschentücher', 'NOUN', 'Taschentücher')
# ('damenbinden', 'ADJ', 'Damenbinden')
# ('babywindeln', 'NOUN', 'babywindeln')
# ('staub', 'NOUN', 'Staub')
# ('asche', 'ADJ', 'asch')
# ('kehricht', 'NOUN', 'Kehricht')
# ('zigarettenkippen', 'NOUN', 'zigarettenkippen')
# ('küchentücher', 'ADJ', 'küchentüch')
# ('putzlappen', 'ADJ', 'Putzlapp')
# ('trinkgläser', 'ADJ', 'Trinkgläser')
# ('porzellan', 'NOUN', 'Porzellan')
# ('keramik', 'NOUN', 'Keramik')
# ('scherben', 'VERB', 'scherben')
# ('kommt', 'VERB', 'kommen')
# ('elektrogeräteschrott', 'NOUN', 'Elektrogeräteschrott')
# ('wertstoffhöfe', 'NOUN', 'Wertstoffhof')
# ('großgeräte', 'NOUN', 'großgeräte')
# ('sperrmüll', 'NOUN', 'Sperrmüll')
# ('batterien', 'VERB', 'batterien')
# ('spezielle', 'ADJ', 'speziell')
# ('sammelbehälter', 'NOUN', 'Sammelbehälter')
# ('supermärkten', 'NOUN', 'Supermärkt')
# ('öffentlichen', 'ADJ', 'öffentlich')
# ('gebäuden', 'NOUN', 'Gebäud')
# ('sonderabfallschadstoffe', 'NOUN', 'Sonderabfallschadstoffe')
# ('farben', 'NOUN', 'Farbe')
# ('lacke', 'NOUN', 'Lack')
# ('standort', 'NOUN', 'Standort')
# ('wohnhaus', 'NOUN', 'Wohnhaus')
# ('leerung', 'NOUN', 'Leerung')
# ('ver', 'ADJ', 'ver')
# ('wattebäusche', 'ADJ', 'wattebäusch')
# ('spiegel', 'NOUN', 'Spiegel')
#
# ==================================================
#
# POS-Tagged Document 1:
#
# ('gehört', 'VERB', 'gehören')
# ('bioabfall', 'NOUN', 'Bioabfall')
# ('gehört', 'VERB', 'gehören')
# ('biotonne', 'NOUN', 'Biotonne')
# ('obst', 'NOUN', 'Obst')
# ('gemüsereste', 'ADJ', 'gemüser')
# ('kaffeesatz', 'NOUN', 'Kaffeesatz')
# ('filter', 'ADJ', 'filt')
# ('tee', 'NOUN', 'Tee')
# ('essensreste', 'ADJ', 'essensreste')
# ('gekochte', 'ADJ', 'gekocht')
# ('alte', 'ADJ', 'alt')
# ('lebensmittel', 'NOUN', 'Lebensmittel')
# ('verpackung', 'NOUN', 'Verpackung')
# ('eierschalen', 'ADJ', 'eierschalen')
# ('blumen', 'NOUN', 'blum')
# ('gartenabfälle', 'ADJ', 'Gartenabfäll')
# ('laub', 'NOUN', 'Laub')
# ('einwickelpapier', 'NOUN', 'Einwickelpapier')
# ('z', 'NOUN', 'z')
# ('biotonne', 'NOUN', 'Biotonne')
# ('plastiktüten', 'ADJ', 'plastiktüt')
# ('erde', 'NOUN', 'Erde')
# ('holz', 'NOUN', 'Holz')
# ('grassoden', 'ADJ', 'grassod')
# ('sand', 'NOUN', 'Sand')
# ('steine', 'ADJ', 'stein')
# ('qrcode', 'NOUN', 'Qrcode')
# ('scannen', 'VERB', 'scannen')
# ('erhalten', 'VERB', 'erhalten')
# ('informationen', 'NOUN', 'Information')
# ('weiteren', 'ADJ', 'weit')
# ('sprachen', 'NOUN', 'Sprache')
# ('trenne', 'VERB', 'trennen')
# ('gehört', 'VERB', 'gehören')
# ('restmülltonne', 'ADJ', 'restmülltonn')
# ('zigarettenkippen', 'NOUN', 'Zigarettenkipp')
# ('asche', 'ADJ', 'asch')
# ('kehricht', 'NOUN', 'Kehricht')
# ('keramik', 'NOUN', 'Keramik')
# ('tonteller', 'NOUN', 'Tonteller')
# ('töpfe', 'NOUN', 'Töpf')
# ('putzlappen', 'NOUN', 'Putzlapp')
# ('schwämme', 'ADJ', 'schwämm')
# ('wegwerfwindeln', 'NOUN', 'wegwerfwindeln')
# ('hygieneartikel', 'NOUN', 'Hygieneartikel')
# ('restmülltonne', 'ADJ', 'restmülltonn')
# ('schadstoffe', 'NOUN', 'Schadstoff')
# ('batterien', 'NOUN', 'Batteri')
# ('elektrogeräte', 'VERB', 'elektrogeräten')
# ('bauschutt', 'NOUN', 'Bauschutt')
# ('entsorgungsbetriebe', 'VERB', 'entsorgungsbetrieb')
# ('meinen', 'VERB', 'meinen')
# ('gehört', 'VERB', 'gehören')
# ('zeitungen', 'NOUN', 'Zeitung')
# ('zeitschriften', 'NOUN', 'Zeitschrift')
# ('kataloge', 'NOUN', 'Kataloge')
# ('pappe', 'NOUN', 'Pappe')
# ('prospekte', 'ADJ', 'prospekt')
# ('hefte', 'ADJ', 'heft')
# ('bücher', 'ADJ', 'büch')
# ('packpapier', 'NOUN', 'Packpapier')
# ('unbeschichtet', 'VERB', 'unbeschichten')
# ('pappe', 'NOUN', 'Pappe')
# ('telefonbücher', 'NOUN', 'Telefonbücher')
# ('papiertonne', 'ADJ', 'papiertonn')
# ('holz', 'NOUN', 'Holz')
# ('schmutziges', 'ADJ', 'schmutzig')
# ('fotos', 'NOUN', 'Foto')
# ('plastiktüten', 'VERB', 'plastiktüten')
# ('privathaushalt', 'NOUN', 'Privathaushalt')
# ('gelber', 'ADJ', 'Gelber')
# ('sack', 'NOUN', 'Sack')
# ('papiertonne', 'VERB', 'papiertonnen')
# ('gehört', 'VERB', 'gehören')
# ('verpackungsstyropor', 'NOUN', 'Verpackungsstyropor')
# ('kunststoffflaschen', 'ADJ', 'kunststoffflasch')
# ('plastiktüten', 'ADJ', 'plastiktüt')
# ('konservendosen', 'NOUN', 'Konservendosen')
# ('milch', 'NOUN', 'Milch')
# ('safttüten', 'VERB', 'safttüen')
# ('vakuumverpackungen', 'NOUN', 'Vakuumverpackung')
# ('gelben', 'ADJ', 'gelb')
# ('plastikschüsseln', 'VERB', 'plastikschüsseln')
# ('beschichtetes', 'ADJ', 'beschichtet')
# ('papier', 'NOUN', 'Papier')
# ('kleiderbügel', 'NOUN', 'Kleiderbügel')
# ('kunststoffrohre', 'VERB', 'kunststoffrohren')
# ('uhr', 'NOUN', 'Uhr')
# ('uhr', 'NOUN', 'Uhr')
# ('romn', 'ADJ', 'romn')
# ('kurd', 'NOUN', 'Kurd')
# ('gelben', 'ADJ', 'gelben')
# ('sack', 'NOUN', 'Sack')
# ('gehört', 'VERB', 'gehören')
# ('glascontainer', 'ADJ', 'glascontainer')
# ('weißglas', 'ADJ', 'weißglas')
# ('buntglas', 'NOUN', 'Buntglas')
# ('einwegglasflaschen', 'ADJ', 'einwegglasflasch')
# ('sonstiges', 'ADJ', 'sonstig')
# ('hohlglas', 'NOUN', 'Hohlglas')
# ('nutzen', 'VERB', 'nutzen')
# ('wertstoffhöfe', 'NOUN', 'Wertstoffhof')
# ('fragen', 'NOUN', 'Frage')
# ('mülltrennung', 'NOUN', 'Mülltrennung')
# ('beraten', 'VERB', 'beraten')
# ('sack', 'NOUN', 'Sack')
# ('glascontainer', 'ADJ', 'Glascontainer')
# ('fensterscheiben', 'VERB', 'fensterscheiben')
# ('porzellan', 'NOUN', 'Porzellan')
# ('keramik', 'NOUN', 'Keramik')
# ('glühbirnen', 'NOUN', 'Glühbirne')
# ('uhr', 'NOUN', 'Uhr')
# ('entsorgungsbetriebe', 'VERB', 'entsorgungsbetrieben')
# ('uhr', 'NOUN', 'Uhr')
#
# ==================================================
#
# POS-Tagged Document 2:
#
# ('glascontainer', 'NOUN', 'Glascontainer')
# ('gehören', 'VERB', 'gehören')
# ('restentleerte', 'ADJ', 'restentleert')
# ('glasverpackungen', 'NOUN', 'Glasverpackung')
# ('glasverpackungen', 'NOUN', 'Glasverpackung')
# ('farben', 'NOUN', 'Farbe')
# ('weiß', 'ADJ', 'weiß')
# ('sortieren', 'VERB', 'sortieren')
# ('vorgesehenen', 'ADJ', 'vorgesehen')
# ('container', 'NOUN', 'Container')
# ('werfen', 'VERB', 'werfen')
# ('farben', 'NOUN', 'Farbe')
# ('blaues', 'ADJ', 'blau')
# ('glas', 'NOUN', 'Glas')
# ('kommen', 'VERB', 'kommen')
# ('grünglas', 'NOUN', 'Grünglas')
# ('deckel', 'NOUN', 'Deckel')
# ('abgeschraubt', 'VERB', 'abgeschrauben')
# ('beispiel', 'NOUN', 'Beispiel')
# ('bepfandeten', 'ADJ', 'bepfandet')
# ('glasflaschen', 'ADJ', 'glasflasch')
# ('wein', 'NOUN', 'Wein')
# ('frucht', 'NOUN', 'fruchen')
# ('gemüse', 'NOUN', 'Gemüse')
# ('säfte', 'NOUN', 'säfen')
# ('fruchtnektare', 'ADJ', 'fruchtnektar')
# ('glas', 'NOUN', 'Glas')
# ('parfümflaschen', 'ADJ', 'parfümflasch')
# ('marmeladen', 'ADJ', 'marmelad')
# ('gurken', 'VERB', 'Gurk')
# ('senfgläser', 'NOUN', 'senfgläs')
# ('sonstiges', 'ADJ', 'sonstig')
# ('verpackungsglas', 'NOUN', 'Verpackungsglas')
# ('obst', 'NOUN', 'Obst')
# ('soßen', 'NOUN', 'Soße')
# ('suppen', 'NOUN', 'suppen')
# ('gemüse', 'NOUN', 'Gemüse')
# ('glas', 'NOUN', 'Glas')
# ('glas', 'NOUN', 'Glas')
# ('glascontainer', 'NOUN', 'Glascontainer')
# ('gehören', 'VERB', 'gehören')
# ('abfälle', 'NOUN', 'Abfall')
# ('glas', 'NOUN', 'Glas')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('beispiel', 'NOUN', 'Beispiel')
# ('auflaufformen', 'VERB', 'auflaufform')
# ('hitzebeständiges', 'ADJ', 'hitzebeständig')
# ('glas', 'NOUN', 'Glas')
# ('steingutflaschen', 'NOUN', 'steingutflaschen')
# ('autolampen', 'NOUN', 'Autolamp')
# ('teller', 'NOUN', 'Teller')
# ('tassen', 'VERB', 'tassen')
# ('autoscheiben', 'VERB', 'Autoscheib')
# ('kaffeekannen', 'VERB', 'kaffeekannen')
# ('trinkgläser', 'NOUN', 'Trinkgläser')
# ('batterien', 'NOUN', 'batteri')
# ('bio', 'NOUN', 'Bio')
# ('restabfall', 'NOUN', 'Restabfall')
# ('keramik', 'NOUN', 'Keramik')
# ('bleiglas', 'NOUN', 'Bleiglas')
# ('leuchtstoffröhren', 'NOUN', 'leuchtstoffröhren')
# ('blumentöpfe', 'ADJ', 'blumentöpf')
# ('mikrowellengeschirr', 'NOUN', 'Mikrowellengeschirr')
# ('flachglas', 'NOUN', 'Flachgla')
# ('produkte', 'NOUN', 'Produkt')
# ('verpackungsbestandteile', 'NOUN', 'verpackungsbestandteil')
# ('glaskeramik', 'NOUN', 'Glaskeramik')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('glaskochplatten', 'NOUN', 'Glaskochplatt')
# ('glühbirnen', 'NOUN', 'Glühbirne')
# ('spritzen', 'VERB', 'spritzen')
# ('regionale', 'ADJ', 'regional')
# ('ausnahmen', 'NOUN', 'Ausnahme')
# ('nähere', 'ADJ', 'nähern')
# ('infos', 'NOUN', 'infos')
# ('kommune', 'NOUN', 'kommun')
# ('qrcode', 'NOUN', 'Qrcode')
# ('scannen', 'VERB', 'scann')
# ('klicken', 'VERB', 'klicken')
# ('deinen', 'ADJ', 'dein')
# ('zuständigen', 'ADJ', 'zuständig')
# ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')
#
# ==================================================
#
# POS-Tagged Document 3:
#
# ('papiertonne', 'NOUN', 'Papiertonne')
# ('gehören', 'VERB', 'gehören')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('nichtverpackungen', 'NOUN', 'nichtverpackungen')
# ('papier', 'NOUN', 'Papier')
# ('anhaftung', 'NOUN', 'Anhaftung')
# ('speiseresten', 'NOUN', 'Speiserest')
# ('verpackungen', 'VERB', 'verpackungen')
# ('zerkleinert', 'VERB', 'zerkleinert')
# ('zusammengelegt', 'VERB', 'zusammenlegen')
# ('gefaltet', 'VERB', 'falten')
# ('beispiel', 'NOUN', 'Beispiel')
# ('beispiel', 'NOUN', 'Beispiel')
# ('nichtverpackungen', 'NOUN', 'Nichtverpackung')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('briefe', 'NOUN', 'Brief')
# ('brötchen', 'ADJ', 'brötch')
# ('metzger', 'NOUN', 'Metzger')
# ('briefumschläge', 'NOUN', 'briefumschlägen')
# ('obsttüten', 'ADJ', 'obsttüt')
# ('bücher', 'ADJ', 'büch')
# ('eierschachteln', 'NOUN', 'Eierschachtel')
# ('geschenkpapier', 'NOUN', 'Geschenkpapier')
# ('faltschachteln', 'VERB', 'faltschachteln')
# ('form', 'NOUN', 'Form')
# ('kataloge', 'VERB', 'Kataloge')
# ('füllmaterial', 'NOUN', 'Füllmaterial')
# ('postkarten', 'NOUN', 'Postkart')
# ('papier', 'NOUN', 'Papier')
# ('schulhefte', 'NOUN', 'schulheft')
# ('mehl', 'NOUN', 'Mehl')
# ('zuckertüten', 'VERB', 'Zuckertüte')
# ('werbeprospekte', 'NOUN', 'werbeprospekt')
# ('zeitschriften', 'NOUN', 'zeitschrift')
# ('papiertragetaschen', 'ADJ', 'papiertragetasch')
# ('zeitungen', 'NOUN', 'Zeitung')
# ('pappummantelung', 'NOUN', 'Pappummantelung')
# ('joghurtbechern', 'NOUN', 'joghurtbechern')
# ('pralinenschachteln', 'VERB', 'Pralinenschachtel')
# ('papiertonne', 'NOUN', 'Papiertonne')
# ('gehören', 'VERB', 'gehören')
# ('abfälle', 'NOUN', 'Abfall')
# ('verpackungen', 'VERB', 'verpackungen')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('beispiel', 'NOUN', 'Beispiel')
# ('batterien', 'NOUN', 'Batteri')
# ('bioabfall', 'NOUN', 'Bioabfall')
# ('metalle', 'ADJ', 'metall')
# ('butterfolie', 'NOUN', 'Butterfolie')
# ('milch', 'NOUN', 'Milch')
# ('dosen', 'VERB', 'dosen')
# ('suppen', 'VERB', 'suppen')
# ('soßentüten', 'NOUN', 'Soßentüte')
# ('fotos', 'NOUN', 'Foto')
# ('glas', 'NOUN', 'Glas')
# ('thermopapier', 'NOUN', 'Thermopapier')
# ('holzschachteln', 'VERB', 'holzschachteln')
# ('holzwolle', 'ADJ', 'holzwoll')
# ('tapeten', 'NOUN', 'tapeten')
# ('kontoauszüge', 'ADJ', 'kontoauszüge')
# ('v', 'NOUN', 'v')
# ('erschmutzte', 'ADJ', 'erschmutzen')
# ('volle', 'ADJ', 'voll')
# ('thermopapiere', 'ADJ', 'thermopapierer')
# ('verpackungen', 'ADJ', 'verpackungen')
# ('küchenabfälle', 'NOUN', 'küchenabfällen')
# ('wein', 'NOUN', 'Wein')
# ('sektkorken', 'VERB', 'sektkorken')
# ('küchen', 'ADJ', 'küch')
# ('papiertaschentücher', 'NOUN', 'Papiertaschentücher')
# ('kunststoffe', 'ADJ', 'kunststoff')
# ('regionale', 'ADJ', 'regional')
# ('ausnahmen', 'NOUN', 'Ausnahme')
# ('nähere', 'ADJ', 'nähern')
# ('infos', 'NOUN', 'infos')
# ('kommune', 'NOUN', 'kommun')
# ('qrcode', 'NOUN', 'Qrcode')
# ('scannen', 'VERB', 'scann')
# ('klicken', 'VERB', 'klicken')
# ('deinen', 'ADJ', 'dein')
# ('zuständigen', 'ADJ', 'zuständig')
# ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')
#
# ==================================================
#
# POS-Tagged Document 4:
#
# ('wertstofftonne', 'NOUN', 'Wertstofftonne')
# ('gehören', 'VERB', 'gehören')
# ('gebrauchte', 'ADJ', 'gebraucht')
# ('restlentleerte', 'VERB', 'restlentleeren')
# ('verpackungen', 'VERB', 'verpackungen')
# ('papier', 'NOUN', 'Papier')
# ('glas', 'NOUN', 'Glas')
# ('gegenstände', 'NOUN', 'Gegenstand')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('metall', 'NOUN', 'Metall')
# ('verpackungsbestand', 'VERB', 'Verpackungsbestand')
# ('teile', 'NOUN', 'Teil')
# ('trennen', 'VERB', 'trennen')
# ('ausspülen', 'VERB', 'Ausspül')
# ('beispiel', 'NOUN', 'Beispiel')
# ('saftflaschen', 'ADJ', 'saftflasch')
# ('schalen', 'ADJ', 'schal')
# ('schaumstoffe', 'NOUN', 'Schaumstoff')
# ('arzneimittelblister', 'NOUN', 'arzneimittelblist')
# ('schrauben', 'NOUN', 'Schraube')
# ('b', 'ADJ', 'b')
# ('esteck', 'NOUN', 'Esteck')
# ('spielzeug', 'NOUN', 'Spielzeug')
# ('flaschenverschlüsse', 'ADJ', 'flaschenverschlüsse')
# ('töpfe', 'NOUN', 'Töpf')
# ('folien', 'NOUN', 'Folie')
# ('werkzeuge', 'NOUN', 'werkzeug')
# ('g', 'NOUN', 'G')
# ('ebrauchsgegenstände', 'ADJ', 'ebrauchsgegenständen')
# ('gießkannen', 'ADJ', 'gießkann')
# ('blumentöpfe', 'NOUN', 'Blumentöpfe')
# ('plastikschüsseln', 'VERB', 'plastikschüsseln')
# ('getränkedosen', 'NOUN', 'Getränkedose')
# ('margarinebecher', 'ADJ', 'margarinebech')
# ('unststoffflaschen', 'VERB', 'unststoffflaschen')
# ('waschmittelflaschen', 'ADJ', 'waschmittelflasch')
# ('icht', 'NOUN', 'Icht')
# ('wertstofftonne', 'NOUN', 'Wertstofftonne')
# ('gehören', 'VERB', 'gehören')
# ('verpackungen', 'NOUN', 'verpackunge')
# ('papier', 'NOUN', 'Papier')
# ('glas', 'NOUN', 'Glas')
# ('restabfälle', 'NOUN', 'Restabfälle')
# ('beispiel', 'NOUN', 'Beispiel')
# ('verpackte', 'ADJ', 'verpackt')
# ('bzw', 'NOUN', 'Bzw')
# ('alte', 'ADJ', 'alt')
# ('keramik', 'NOUN', 'Keramik')
# ('akkus', 'NOUN', 'Akkus')
# ('abgelagerte', 'ADJ', 'abgelagert')
# ('lebensmittel', 'NOUN', 'Lebensmittel')
# ('holz', 'NOUN', 'Holz')
# ('batterien', 'NOUN', 'Batteri')
# ('windeln', 'NOUN', 'windeln')
# ('kfzkleinteile', 'NOUN', 'Kfzkleinteil')
# ('bauabfälle', 'ADJ', 'Bauabfälle')
# ('zigarettenkippen', 'NOUN', 'zigarettenkippen')
# ('medikamentenreste', 'ADJ', 'medikamentenr')
# ('datenträger', 'ADJ', 'Datenträger')
# ('mund', 'NOUN', 'Mund')
# ('nasenschutz', 'NOUN', 'Nasenschutz')
# ('elektrogeräte', 'VERB', 'elektrogeräten')
# ('porzellan', 'NOUN', 'Porzellan')
# ('energiesparlampen', 'NOUN', 'Energiesparlampe')
# ('schuhe', 'VERB', 'schuhen')
# ('gummi', 'NOUN', 'Gummi')
# ('spritzen', 'VERB', 'spritzen')
# ('holz', 'NOUN', 'Holz')
# ('holzreste', 'ADJ', 'holzrester')
# ('strumpfhosen', 'NOUN', 'Strumpfhosen')
# ('hygieneartikel', 'NOUN', 'Hygieneartikel')
# ('windeln', 'VERB', 'windeln')
# ('styroporreste', 'NOUN', 'Styroporrest')
# ('dämmplatten', 'ADJ', 'dämmplatt')
# ('binden', 'NOUN', 'Bind')
# ('wattereste', 'NOUN', 'wattereste')
# ('tapetenreste', 'ADJ', 'tapetenrest')
# ('kondome', 'NOUN', 'kondom')
# ('textilien', 'NOUN', 'Textilie')
# ('video', 'NOUN', 'Video')
# ('audiokassetten', 'ADJ', 'audiokassett')
# ('kanülen', 'NOUN', 'Kanül')
# ('regionale', 'ADJ', 'regional')
# ('ausnahmen', 'NOUN', 'Ausnahme')
# ('nähere', 'ADJ', 'nähern')
# ('infos', 'NOUN', 'infos')
# ('kommune', 'NOUN', 'kommun')
# ('qrcode', 'NOUN', 'Qrcode')
# ('scannen', 'VERB', 'scann')
# ('klicken', 'VERB', 'klicken')
# ('deinen', 'ADJ', 'dein')
# ('zuständigen', 'ADJ', 'zuständig')
# ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')
#
# ==================================================
#
# POS-Tagged Document 5:
#
# ('gelbe', 'ADJ', 'gelb')
# ('tonneden', 'NOUN', 'Tonnede')
# ('gelben', 'ADJ', 'gelb')
# ('sack', 'NOUN', 'Sack')
# ('gehören', 'VERB', 'gehören')
# ('gebrauchte', 'ADJ', 'gebraucht')
# ('restentleerte', 'VERB', 'restentleert')
# ('verpackungen', 'NOUN', 'verpackungen')
# ('papier', 'NOUN', 'Papier')
# ('glas', 'NOUN', 'Glas')
# ('verpackungsbestandteile', 'NOUN', 'verpackungsbestandteil')
# ('trennen', 'VERB', 'trennen')
# ('ausspülen', 'VERB', 'Ausspül')
# ('beispiel', 'NOUN', 'Beispiel')
# ('menüschalen', 'NOUN', 'Menüschal')
# ('kunststoffdeckel', 'NOUN', 'Kunststoffdeckel')
# ('fertiggerichten', 'VERB', 'fertiggericht')
# ('arzneimittelblister', 'NOUN', 'Arzneimittelblister')
# ('milch', 'NOUN', 'Milch')
# ('müsliriegelfolie', 'NOUN', 'Müsliriegelfolie')
# ('joghurtbecher', 'ADJ', 'joghurtbech')
# ('nudeltüten', 'NOUN', 'nudeltüter')
# ('einkaufstüten', 'VERB', 'Einkaufstüt')
# ('putz', 'NOUN', 'Putz')
# ('reinigungsmittelflaschen', 'ADJ', 'reinigungsmittelflasch')
# ('obst', 'NOUN', 'Obst')
# ('gemüsebeutel', 'NOUN', 'Gemüsebeutel')
# ('nachfüllbeutel', 'NOUN', 'Nachfüllbeutel')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('waschmittel', 'NOUN', 'Waschmittel')
# ('flüssigseife', 'NOUN', 'flüssigseife')
# ('eisverpackungen', 'VERB', 'eisverpackungen')
# ('üllmaterial', 'NOUN', 'Üllmaterial')
# ('verpackungen', 'NOUN', 'verpackungen')
# ('kunststoff', 'NOUN', 'Kunststoff')
# ('shampooflaschen', 'ADJ', 'shampooflasch')
# ('luftpolsterfolie', 'NOUN', 'Luftpolsterfolie')
# ('spraydosen', 'NOUN', 'Spraydose')
# ('soßentüten', 'NOUN', 'soßentüen')
# ('konservendosen', 'NOUN', 'Konservendosen')
# ('tierfutterdosen', 'VERB', 'tierfutterdosen')
# ('schalen', 'ADJ', 'schal')
# ('kronkorken', 'NOUN', 'kronkork')
# ('zahnpastatuben', 'NOUN', 'Zahnpastatuben')
# ('kunststoffschalen', 'NOUN', 'kunststoffschalen')
# ('folien', 'NOUN', 'folien')
# ('lebensmittel', 'NOUN', 'Lebensmittel')
# ('gelbe', 'ADJ', 'gelb')
# ('tonneden', 'NOUN', 'Tonnede')
# ('gelben', 'ADJ', 'gelb')
# ('sack', 'NOUN', 'Sack')
# ('gehören', 'VERB', 'gehören')
# ('verpackungen', 'NOUN', 'verpackunge')
# ('papier', 'NOUN', 'Papier')
# ('glas', 'NOUN', 'Glas')
# ('abfälle', 'NOUN', 'Abfall')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('beispiel', 'NOUN', 'Beispiel')
# ('schuhe', 'VERB', 'schuhen')
# ('altkleider', 'NOUN', 'altkleid')
# ('gummi', 'ADJ', 'Gummi')
# ('strumpfhosen', 'NOUN', 'strumpfhosen')
# ('batterien', 'NOUN', 'Batterien')
# ('akkus', 'NOUN', 'Akkus')
# ('holzwolle', 'ADJ', 'holzwoll')
# ('styroporreste', 'NOUN', 'Styroporrest')
# ('behälterglas', 'ADJ', 'Behälterglas')
# ('dämmplatten', 'ADJ', 'dämmplatt')
# ('tapetenreste', 'ADJ', 'tapetenrest')
# ('cds', 'NOUN', 'cds')
# ('keramikprodukte', 'NOUN', 'Keramikprodukt')
# ('windeln', 'NOUN', 'windeln')
# ('druckerpatronen', 'ADJ', 'druckerpatron')
# ('kinderspielzeug', 'NOUN', 'Kinderspielzeug')
# ('zahnbürsten', 'VERB', 'zahnbürsen')
# ('klarsichthüllen', 'NOUN', 'Klarsichthüll')
# ('zigarettenkippen', 'NOUN', 'zigarettenkippen')
# ('elektrogeräte', 'VERB', 'elektrogeräten')
# ('kugelschreiber', 'NOUN', 'Kugelschreiber')
# ('essensreste', 'ADJ', 'essensreste')
# ('restentleerte', 'VERB', 'restentleert')
# ('verpackungen', 'NOUN', 'Verpackung')
# ('faltschachteln', 'VERB', 'faltschachteln')
# ('papier', 'NOUN', 'Papier')
# ('pappe', 'NOUN', 'Pappe')
# ('feuerzeuge', 'VERB', 'feuerzeug')
# ('ilme', 'ADJ', 'ilm')
# ('dvds', 'NOUN', 'dvds')
# ('pflaster', 'NOUN', 'Pflaster')
# ('videokassetten', 'VERB', 'videokassett')
# ('glüh', 'NOUN', 'Glüh')
# ('energiesparlampen', 'NOUN', 'Energiesparlampe')
# ('rest', 'NOUN', 'Rest')
# ('bioabfälle', 'ADJ', 'bioabfäll')
# ('regionale', 'ADJ', 'regional')
# ('ausnahmen', 'NOUN', 'Ausnahme')
# ('nähere', 'ADJ', 'nähere')
# ('infos', 'NOUN', 'infos')
# ('kommune', 'NOUN', 'kommun')
# ('qrcode', 'NOUN', 'Qrcode')
# ('scannen', 'VERB', 'scann')
# ('klicken', 'VERB', 'klicken')
# ('deinen', 'ADJ', 'dein')
# ('zuständigen', 'ADJ', 'zuständig')
# ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')
#
# ==================================================

# %%
import spacy

def remove_stopwords(processed_documents):
    """Entfernt unnötige Stopwörter aus den Dokumenten."""
    custom_stopwords = nlp.Defaults.stop_words.difference({'nicht', 'kein', 'wichtig', 'ohne', 'gehört', 'getrennt', 'hinein'})

    cleaned_documents = []

    for doc in processed_documents:
        filtered_tokens = [token_info for token_info in doc if token_info[2] not in custom_stopwords and len(token_info[2]) > 2]

        # Entferne unzusammenhängende Zeichenfolgen und extrem kurze Wörter
        cleaned_text = ' '.join([token_info[2] for token_info in filtered_tokens])
        cleaned_text = re.sub(r'\b\w{1,3}\b', '', cleaned_text)

        # Entferne mehrfach aufeinanderfolgende gleiche Wörter
        cleaned_text = re.sub(r'\b(\w+)\s+\1\b', r'\1', cleaned_text)

        # Entferne weiterhin sinnlose Textfragmente
        cleaned_text = re.sub(r'\b[a-zäöüß]{2,3}\b\s+\b[a-zäöüß]{2,3}\b', '', cleaned_text)

        cleaned_documents.append(cleaned_text.strip())

    return cleaned_documents

# Verwende die POS-getaggten Dokumente als Input für das Entfernen von Stopwörtern
cleaned_documents = remove_stopwords(pos_tagged_documents)

# Ausgabe der bereinigten Dokumente
for i, doc in enumerate(cleaned_documents):
    print(f"Cleaned Document {i}:\n")
    print(doc)
    print("\n" + "="*50 + "\n")
# Out:
# Cleaned Document 0:
#
# blau Altglascontainer sauber Flasche Deckelglas Farbe weiß blau bunt Glas Grünglas geben asch Konservenglas Scheiben Restmüll Trinkgläser Porzellan Keramik Glühbirne Restmüll Energiesparlampe Wertstoffhof verschmutzt Gläser Restmüll Standort öffentlich Sperrmüll plätzen Frankfurter Entsorgung Abfall trennen Service Gmbh Fesservicecenter Ecke töngesgasseschärfengässchen   Rgungsfachbetrie rren trennen Haus gehören Abfallbehälter Tonne Inhalt Wertvoller Rohstoff  Produkt weiterverarbeiten grau Restmülltonne gelb Tonne verpackunger grün Tonne Papier Pappe braun Tonne bioabfälle grau Tonne restlich Abfall Restmüll geben folgend entsorgungsangebot wertstoffe sichern Altglascontainer Flasche Deckelglas nden öffentlich Plätz altkleid Container altkleider schuhen nden Stadtteil öffentlich Plätz Feswertstoffhöf Schadstoff Abfäll gefährlich Stoff farbe Spraydos mitteln Fesschadstoffmobil abgeben terminen nden Jahr Haushalt verteilen Sperrmüllabholung holen  Termin Wohnsiedlung abholen termin nden schwarz Brett Sperrmüll Wertstoff entsorgen Hnff  Abfalltonn Haus Dauer ausreichen hausbesitz Weiteregrößere bestellen Internet Spezialbehälter besonderer abfäll baustellenabfälle erfahren Servicetelefonnummer Kosten Sperrmüll Abfallgebühr enthalten  standort Fesmagazin erhalten Woche Haus Näheres gelb Verpackungstonne Verpackunge Symbol grüne Papier Pappe Glas bestehen verpackunge spülen verpackungen Kunststoff folien bech Verbundverpackung Materialmix Papier Getränkekarton milchtüen Verpackung Metall Konserve getränkedosen geschäumt kunststoff gemüseverpackungen verpackungen Papier Pappe verpackungen Glas altglascontain verschmutzt Fastfoodverpackung Restmüll gelb Tonne aussortieren weiterverarbeitet Standort Wohnhaus Leerung grün Altpapiertonne Punkt grün altpapiertonn gehören Papier Pappe Beschichtung Pappe kartonag Styropor Zeitung illustriert Kataloge büch hefen verschmutzt Papier Restmüll beschichtet Papier Restmüll hygienepapi windeln Restmüll Näheres sicher Aktenvernichtung erfahren Servicetelefonnummer wertstoff Standort Wohnhaus Leerung braun biotonnen abbaubar Abfall privat Haushalt feucht Bioabfäll Salat Obst gemüseresen Zeitungs wickeln schützen tonnen stark Verschmutzung Gemüseabfälle zitrusfrücht Banane nussschalen  gekocht Speise lebensmittelr Kaffee Teesatz filtertüt Eierschale Grünschnitt plastiktüt Verpackunge Kunststoff Metall gelb Verpackungstonne Kehricht windeln anderer Gebraucht Restmüll Standort Wohnhaus Leerung grau Restmülltonne Abfall Verunreinigung Vermischung anderer Tonne entsorgen schmutzt lebensmittelverpackungen Taschentücher Damenbinden babywindeln Staub asch Kehricht zigarettenkippen küchentüch Putzlapp Trinkgläser Porzellan Keramik scherben Elektrogeräteschrott Wertstoffhof großgeräte Sperrmüll batterien speziell Sammelbehälter Supermärkt öffentlich Gebäud Sonderabfallschadstoffe Farbe Lack Standort Wohnhaus Leerung  wattebäusch Spiegel
#
# ==================================================
#
# Cleaned Document 1:
#
# gehören Bioabfall gehören Biotonne Obst gemüser Kaffeesatz filt  essensreste gekocht  Lebensmittel Verpackung eierschalen blum Gartenabfäll Laub Einwickelpapier Biotonne plastiktüt Erde Holz grassod Sand stein Qrcode scannen erhalten Information Sprache trennen gehören restmülltonn Zigarettenkipp asch Kehricht Keramik Tonteller Töpf Putzlapp schwämm wegwerfwindeln Hygieneartikel restmülltonn Schadstoff Batteri elektrogeräten Bauschutt entsorgungsbetrieb gehören Zeitung Zeitschrift Kataloge Pappe prospekt heft büch Packpapier unbeschichten Pappe Telefonbücher papiertonn Holz schmutzig Foto plastiktüten Privathaushalt Gelber Sack papiertonnen gehören Verpackungsstyropor kunststoffflasch plastiktüt Konservendosen Milch safttüen Vakuumverpackung gelb plastikschüsseln beschichtet Papier Kleiderbügel kunststoffrohren   romn Kurd gelben Sack gehören glascontainer weißglas Buntglas einwegglasflasch sonstig Hohlglas nutzen Wertstoffhof Frage Mülltrennung beraten Sack Glascontainer fensterscheiben Porzellan Keramik Glühbirne  entsorgungsbetrieben
#
# ==================================================
#
# Cleaned Document 2:
#
# Glascontainer gehören restentleert Glasverpackung Farbe weiß sortieren vorgesehen Container werfen Farbe blau Glas Grünglas Deckel abgeschrauben Beispiel bepfandet glasflasch Wein fruchen Gemüse säfen fruchtnektar Glas parfümflasch marmelad Gurk senfgläs sonstig Verpackungsglas Obst Soße suppen Gemüse Glas Glascontainer gehören Abfall Glas Verpackung Beispiel auflaufform hitzebeständig Glas steingutflaschen Autolamp Teller tassen Autoscheib kaffeekannen Trinkgläser batteri  Restabfall Keramik Bleiglas leuchtstoffröhren blumentöpf Mikrowellengeschirr Flachgla Produkt verpackungsbestandteil Glaskeramik Kunststoff Glaskochplatt Glühbirne spritzen regional Ausnahme nähern infos kommun Qrcode scann klicken zuständig Ansprechpartnerin
#
# ==================================================
#
# Cleaned Document 3:
#
# Papiertonne gehören Verpackung nichtverpackungen Papier Anhaftung Speiserest verpackungen zerkleinert zusammenlegen falten Beispiel Nichtverpackung Verpackung Brief brötch Metzger briefumschlägen obsttüt büch Eierschachtel Geschenkpapier faltschachteln Form Kataloge Füllmaterial Postkart Papier schulheft Mehl Zuckertüte werbeprospekt zeitschrift papiertragetasch Zeitung Pappummantelung joghurtbechern Pralinenschachtel Papiertonne gehören Abfall verpackungen Papier Pappe Beispiel Batteri Bioabfall metall Butterfolie Milch dosen suppen Soßentüte Foto Glas Thermopapier holzschachteln holzwoll tapeten kontoauszüge erschmutzen voll thermopapierer verpackungen küchenabfällen Wein sektkorken küch Papiertaschentücher kunststoff regional Ausnahme nähern infos kommun Qrcode scann klicken zuständig Ansprechpartnerin
#
# ==================================================
#
# Cleaned Document 4:
#
# Wertstofftonne gehören gebraucht restlentleeren verpackungen Papier Glas Gegenstand Kunststoff Metall Verpackungsbestand Teil trennen Ausspül Beispiel saftflasch schal Schaumstoff arzneimittelblist Schraube Esteck Spielzeug flaschenverschlüsse Töpf Folie werkzeug ebrauchsgegenständen gießkann Blumentöpfe plastikschüsseln Getränkedose margarinebech unststoffflaschen waschmittelflasch Icht Wertstofftonne gehören verpackunge Papier Glas Restabfälle Beispiel verpackt   Keramik Akkus abgelagert Lebensmittel Holz Batteri windeln Kfzkleinteil Bauabfälle zigarettenkippen medikamentenr Datenträger Mund Nasenschutz elektrogeräten Porzellan Energiesparlampe schuhen Gummi spritzen Holz holzrester Strumpfhosen Hygieneartikel windeln Styroporrest dämmplatt Bind wattereste tapetenrest kondom Textilie Video audiokassett Kanül regional Ausnahme nähern infos kommun Qrcode scann klicken zuständig Ansprechpartnerin
#
# ==================================================
#
# Cleaned Document 5:
#
# gelb Tonnede gelb Sack gehören gebraucht restentleert verpackungen Papier Glas verpackungsbestandteil trennen Ausspül Beispiel Menüschal Kunststoffdeckel fertiggericht Arzneimittelblister Milch Müsliriegelfolie joghurtbech nudeltüter Einkaufstüt Putz reinigungsmittelflasch Obst Gemüsebeutel Nachfüllbeutel Kunststoff Waschmittel flüssigseife eisverpackungen Üllmaterial verpackungen Kunststoff shampooflasch Luftpolsterfolie Spraydose soßentüen Konservendosen tierfutterdosen schal kronkork Zahnpastatuben kunststoffschalen folien Lebensmittel gelb Tonnede gelb Sack gehören verpackunge Papier Glas Abfall Verpackung Beispiel schuhen altkleid Gummi strumpfhosen Batterien Akkus holzwoll Styroporrest Behälterglas dämmplatt tapetenrest  Keramikprodukt windeln druckerpatron Kinderspielzeug zahnbürsen Klarsichthüll zigarettenkippen elektrogeräten Kugelschreiber essensreste restentleert Verpackung faltschachteln Papier Pappe feuerzeug  dvds Pflaster videokassett Glüh Energiesparlampe Rest bioabfäll regional Ausnahme nähere infos kommun Qrcode scann klicken zuständig Ansprechpartnerin
#
# ==================================================

# %%
import re
import spacy

def remove_stopwords_and_clean(processed_documents):
    """Entfernt Stopwörter und bereinigt die Token-Informationen weiter."""
    custom_stopwords = nlp.Defaults.stop_words.difference({'nicht', 'kein', 'wichtig', 'ohne'})
    
    cleaned_documents = []

    for doc in processed_documents:
        # Filtere die Tokens, indem du Stopwörter entfernst und unnötige Zeichenbereinigungen durchführst
        filtered_tokens = []
        for token_info in doc:
            lemma = token_info[2]
            if lemma not in custom_stopwords and len(lemma) > 2:
                cleaned_lemma = re.sub(r'\b\w{1,3}\b', '', lemma)
                cleaned_lemma = re.sub(r'\b(\w+)\s+\1\b', r'\1', cleaned_lemma)
                cleaned_lemma = re.sub(r'\b[a-zäöüß]{2,3}\b\s+\b[a-zäöüß]{2,3}\b', '', cleaned_lemma)
                filtered_tokens.append((token_info[0], token_info[1], cleaned_lemma))
        
        cleaned_documents.append(filtered_tokens)

    return cleaned_documents

# Verwende die POS-getaggten Dokumente als Input für das Entfernen von Stopwörtern
cleaned_documents = remove_stopwords_and_clean(pos_tagged_documents)

# Ausgabe der bereinigten Dokumente mit den Token-Informationen
for i, doc in enumerate(cleaned_documents):
    print(f"Final Token Information for Document {i}:\n")
    for token_info in doc:
        print(f"Token: {token_info[0]}, POS: {token_info[1]}, Lemma: {token_info[2]}")
    print("\n" + "="*50 + "\n")
# Out:
# Final Token Information for Document 0:
#
# Token: blaue, POS: ADJ, Lemma: blau
# Token: altglascontainer, POS: NOUN, Lemma: Altglascontainer
# Token: saubere, POS: ADJ, Lemma: sauber
# Token: flaschen, POS: NOUN, Lemma: Flasche
# Token: deckelgläser, POS: NOUN, Lemma: Deckelglas
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: weiß, POS: ADJ, Lemma: weiß
# Token: blaues, POS: ADJ, Lemma: blau
# Token: buntes, POS: ADJ, Lemma: bunt
# Token: glas, POS: NOUN, Lemma: Glas
# Token: grünglas, POS: NOUN, Lemma: Grünglas
# Token: geben, POS: VERB, Lemma: geben
# Token: aschen, POS: ADJ, Lemma: asch
# Token: konservengläser, POS: NOUN, Lemma: Konservenglas
# Token: scheiben, POS: VERB, Lemma: Scheiben
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: trinkgläser, POS: NOUN, Lemma: Trinkgläser
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: verschmutzte, POS: ADJ, Lemma: verschmutzt
# Token: gläser, POS: ADJ, Lemma: Gläser
# Token: restmüll, POS: ADJ, Lemma: Restmüll
# Token: standort, POS: NOUN, Lemma: Standort
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: sperrmüll, POS: VERB, Lemma: Sperrmüll
# Token: plätzen, POS: VERB, Lemma: plätzen
# Token: frankfurter, POS: ADJ, Lemma: Frankfurter
# Token: entsorgungs, POS: NOUN, Lemma: Entsorgung
# Token: abfall, POS: NOUN, Lemma: Abfall
# Token: trennen, POS: VERB, Lemma: trennen
# Token: service, POS: NOUN, Lemma: Service
# Token: gmbh, POS: VERB, Lemma: Gmbh
# Token: fesservicecenter, POS: NOUN, Lemma: Fesservicecenter
# Token: ecke, POS: NOUN, Lemma: Ecke
# Token: töngesgasseschärfengässchen, POS: VERB, Lemma: töngesgasseschärfengässchen
# Token: uhr, POS: NOUN, Lemma:
# Token: uhr, POS: NOUN, Lemma:
# Token: rgungsfachbetrie, POS: NOUN, Lemma: Rgungsfachbetrie
# Token: rrt, POS: VERB, Lemma: rren
# Token: trennen, POS: VERB, Lemma: trennen
# Token: haus, POS: NOUN, Lemma: Haus
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfallbehälter, POS: NOUN, Lemma: Abfallbehälter
# Token: tonnen, POS: NOUN, Lemma: Tonne
# Token: inhalt, POS: NOUN, Lemma: Inhalt
# Token: wertvoller, POS: ADJ, Lemma: Wertvoller
# Token: rohstoff, POS: NOUN, Lemma: Rohstoff
# Token: neuen, POS: ADJ, Lemma:
# Token: produkten, POS: NOUN, Lemma: Produkt
# Token: weiterverarbeitet, POS: VERB, Lemma: weiterverarbeiten
# Token: graue, POS: ADJ, Lemma: grau
# Token: restmülltonne, POS: NOUN, Lemma: Restmülltonne
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: verpackungen, POS: NOUN, Lemma: verpackunger
# Token: grüne, POS: ADJ, Lemma: grün
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: braune, POS: ADJ, Lemma: braun
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: bioabfälle, POS: ADJ, Lemma: bioabfälle
# Token: graue, POS: ADJ, Lemma: grau
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: restlichen, POS: ADJ, Lemma: restlich
# Token: abfall, POS: NOUN, Lemma: Abfall
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: gibt, POS: VERB, Lemma: geben
# Token: folgende, POS: ADJ, Lemma: folgend
# Token: entsorgungsangebote, POS: ADJ, Lemma: entsorgungsangebot
# Token: wertstoffe, POS: NOUN, Lemma: wertstoffe
# Token: sichern, POS: VERB, Lemma: sichern
# Token: altglascontainer, POS: NOUN, Lemma: Altglascontainer
# Token: flaschen, POS: NOUN, Lemma: Flasche
# Token: deckelgläser, POS: NOUN, Lemma: Deckelglas
# Token: nden, POS: VERB, Lemma: nden
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: plätzen, POS: NOUN, Lemma: Plätz
# Token: altkleider, POS: NOUN, Lemma: altkleid
# Token: container, POS: NOUN, Lemma: Container
# Token: altkleider, POS: NOUN, Lemma: altkleider
# Token: schuhe, POS: NOUN, Lemma: schuhen
# Token: nden, POS: VERB, Lemma: nden
# Token: stadtteil, POS: NOUN, Lemma: Stadtteil
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: plätzen, POS: NOUN, Lemma: Plätz
# Token: feswertstoffhöfen, POS: NOUN, Lemma: Feswertstoffhöf
# Token: schadstoffe, POS: NOUN, Lemma: Schadstoff
# Token: abfälle, POS: NOUN, Lemma: Abfäll
# Token: gefährlichen, POS: ADJ, Lemma: gefährlich
# Token: stoffen, POS: NOUN, Lemma: Stoff
# Token: farben, POS: NOUN, Lemma: farbe
# Token: spraydosen, POS: NOUN, Lemma: Spraydos
# Token: mitteln, POS: VERB, Lemma: mitteln
# Token: fesschadstoffmobil, POS: NOUN, Lemma: Fesschadstoffmobil
# Token: abgeben, POS: VERB, Lemma: abgeben
# Token: termine, POS: NOUN, Lemma: terminen
# Token: nden, POS: VERB, Lemma: nden
# Token: jahr, POS: NOUN, Lemma: Jahr
# Token: haushalte, POS: NOUN, Lemma: Haushalt
# Token: verteilt, POS: VERB, Lemma: verteilen
# Token: sperrmüllabholung, POS: NOUN, Lemma: Sperrmüllabholung
# Token: holt, POS: VERB, Lemma: holen
# Token: fes, POS: NOUN, Lemma:
# Token: termin, POS: NOUN, Lemma: Termin
# Token: wohnsiedlungen, POS: NOUN, Lemma: Wohnsiedlung
# Token: abgeholt, POS: VERB, Lemma: abholen
# Token: termine, POS: NOUN, Lemma: termin
# Token: nden, POS: VERB, Lemma: nden
# Token: schwarzen, POS: ADJ, Lemma: schwarz
# Token: brett, POS: NOUN, Lemma: Brett
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: wertstoffe, POS: VERB, Lemma: Wertstoff
# Token: entsorgen, POS: VERB, Lemma: entsorgen
# Token: hnff, POS: VERB, Lemma: Hnff
# Token: tie, POS: NOUN, Lemma:
# Token: abfalltonnen, POS: NOUN, Lemma: Abfalltonn
# Token: haus, POS: NOUN, Lemma: Haus
# Token: dauer, POS: NOUN, Lemma: Dauer
# Token: ausreichen, POS: VERB, Lemma: ausreichen
# Token: hausbesitzer, POS: NOUN, Lemma: hausbesitz
# Token: weiteregrößere, POS: ADJ, Lemma: Weiteregrößere
# Token: bestellen, POS: VERB, Lemma: bestellen
# Token: internet, POS: NOUN, Lemma: Internet
# Token: spezialbehälter, POS: NOUN, Lemma: Spezialbehälter
# Token: besondere, POS: ADJ, Lemma: besonderer
# Token: abfälle, POS: NOUN, Lemma: abfäll
# Token: baustellenabfälle, POS: VERB, Lemma: baustellenabfälle
# Token: erfahren, POS: VERB, Lemma: erfahren
# Token: servicetelefonnummer, POS: NOUN, Lemma: Servicetelefonnummer
# Token: kosten, POS: NOUN, Lemma: Kosten
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: abfallgebühr, POS: NOUN, Lemma: Abfallgebühr
# Token: enthalten, POS: VERB, Lemma: enthalten
# Token: löse, POS: ADJ, Lemma:
# Token: standorte, POS: ADJ, Lemma: standort
# Token: fesmagazin, POS: NOUN, Lemma: Fesmagazin
# Token: erhalten, POS: VERB, Lemma: erhalten
# Token: wochen, POS: NOUN, Lemma: Woche
# Token: haus, POS: NOUN, Lemma: Haus
# Token: näheres, POS: NOUN, Lemma: Näheres
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: verpackungstonne, POS: NOUN, Lemma: Verpackungstonne
# Token: verpackungen, POS: NOUN, Lemma: Verpackunge
# Token: symbol, POS: NOUN, Lemma: Symbol
# Token: grünen, POS: NOUN, Lemma: grüne
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: glas, POS: NOUN, Lemma: Glas
# Token: bestehen, POS: VERB, Lemma: bestehen
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: gespült, POS: VERB, Lemma: spülen
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: folien, POS: NOUN, Lemma: folien
# Token: becher, POS: ADJ, Lemma: bech
# Token: verbundverpackungen, POS: NOUN, Lemma: Verbundverpackung
# Token: materialmix, POS: NOUN, Lemma: Materialmix
# Token: papier, POS: NOUN, Lemma: Papier
# Token: getränkekartons, POS: NOUN, Lemma: Getränkekarton
# Token: milchtüten, POS: VERB, Lemma: milchtüen
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: metall, POS: NOUN, Lemma: Metall
# Token: konserven, POS: NOUN, Lemma: Konserve
# Token: getränkedosen, POS: ADJ, Lemma: getränkedosen
# Token: geschäumte, POS: ADJ, Lemma: geschäumt
# Token: kunststoffe, POS: NOUN, Lemma: kunststoff
# Token: gemüseverpackungen, POS: VERB, Lemma: gemüseverpackungen
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: glas, POS: NOUN, Lemma: Glas
# Token: altglascontainer, POS: ADJ, Lemma: altglascontain
# Token: verschmutzte, POS: ADJ, Lemma: verschmutzt
# Token: fastfoodverpackungen, POS: NOUN, Lemma: Fastfoodverpackung
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: aussortiert, POS: VERB, Lemma: aussortieren
# Token: weiterverarbeitet, POS: VERB, Lemma: weiterverarbeitet
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: grüne, POS: ADJ, Lemma: grün
# Token: altpapiertonne, POS: NOUN, Lemma: Altpapiertonne
# Token: punkt, POS: NOUN, Lemma: Punkt
# Token: grüne, POS: ADJ, Lemma: grün
# Token: altpapiertonne, POS: NOUN, Lemma: altpapiertonn
# Token: gehören, POS: VERB, Lemma: gehören
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: beschichtung, POS: NOUN, Lemma: Beschichtung
# Token: pappen, POS: NOUN, Lemma: Pappe
# Token: kartonagen, POS: ADJ, Lemma: kartonag
# Token: styropor, POS: NOUN, Lemma: Styropor
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: illustrierte, POS: ADJ, Lemma: illustriert
# Token: kataloge, POS: NOUN, Lemma: Kataloge
# Token: bücher, POS: NOUN, Lemma: büch
# Token: hefte, POS: VERB, Lemma: hefen
# Token: verschmutztes, POS: ADJ, Lemma: verschmutzt
# Token: papier, POS: NOUN, Lemma: Papier
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: beschichtetes, POS: ADJ, Lemma: beschichtet
# Token: papier, POS: NOUN, Lemma: Papier
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: hygienepapiere, POS: ADJ, Lemma: hygienepapi
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: näheres, POS: NOUN, Lemma: Näheres
# Token: sichere, POS: ADJ, Lemma: sicher
# Token: aktenvernichtung, POS: NOUN, Lemma: Aktenvernichtung
# Token: erfahren, POS: VERB, Lemma: erfahren
# Token: servicetelefonnummer, POS: NOUN, Lemma: Servicetelefonnummer
# Token: wertstoffe, POS: ADJ, Lemma: wertstoff
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: braune, POS: ADJ, Lemma: braun
# Token: biotonne, POS: VERB, Lemma: biotonnen
# Token: abbaubaren, POS: ADJ, Lemma: abbaubar
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: privaten, POS: ADJ, Lemma: privat
# Token: haushalten, POS: NOUN, Lemma: Haushalt
# Token: feuchte, POS: ADJ, Lemma: feucht
# Token: bioabfälle, POS: NOUN, Lemma: Bioabfäll
# Token: salat, POS: NOUN, Lemma: Salat
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsereste, POS: VERB, Lemma: gemüseresen
# Token: zeitungs, POS: NOUN, Lemma: Zeitungs
# Token: wickeln, POS: VERB, Lemma: wickeln
# Token: schützen, POS: VERB, Lemma: schützen
# Token: tonne, POS: VERB, Lemma: tonnen
# Token: starker, POS: ADJ, Lemma: stark
# Token: verschmutzung, POS: NOUN, Lemma: Verschmutzung
# Token: gemüseabfälle, POS: NOUN, Lemma: Gemüseabfälle
# Token: zitrusfrüchte, POS: ADJ, Lemma: zitrusfrücht
# Token: bananen, POS: NOUN, Lemma: Banane
# Token: nussschalen, POS: VERB, Lemma: nussschalen
# Token: rohe, POS: ADJ, Lemma:
# Token: gekochte, POS: ADJ, Lemma: gekocht
# Token: speise, POS: NOUN, Lemma: Speise
# Token: lebensmittelreste, POS: ADJ, Lemma: lebensmittelr
# Token: kaffee, POS: NOUN, Lemma: Kaffee
# Token: teesatz, POS: NOUN, Lemma: Teesatz
# Token: filtertüten, POS: VERB, Lemma: filtertüt
# Token: eierschalen, POS: ADJ, Lemma: Eierschale
# Token: grünschnitt, POS: NOUN, Lemma: Grünschnitt
# Token: plastiktüten, POS: VERB, Lemma: plastiktüt
# Token: verpackungen, POS: NOUN, Lemma: Verpackunge
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: metall, POS: NOUN, Lemma: Metall
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: verpackungstonne, POS: NOUN, Lemma: Verpackungstonne
# Token: kehricht, POS: VERB, Lemma: Kehricht
# Token: windeln, POS: VERB, Lemma: windeln
# Token: andere, POS: ADJ, Lemma: anderer
# Token: gebrauchte, POS: NOUN, Lemma: Gebraucht
# Token: restmüll, POS: ADJ, Lemma: Restmüll
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: graue, POS: ADJ, Lemma: grau
# Token: restmülltonne, POS: NOUN, Lemma: Restmülltonne
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verunreinigung, POS: NOUN, Lemma: Verunreinigung
# Token: vermischung, POS: NOUN, Lemma: Vermischung
# Token: anderen, POS: ADJ, Lemma: anderer
# Token: tonnen, POS: NOUN, Lemma: Tonne
# Token: entsorgt, POS: VERB, Lemma: entsorgen
# Token: schmutzte, POS: NOUN, Lemma: schmutzt
# Token: lebensmittelverpackungen, POS: NOUN, Lemma: lebensmittelverpackungen
# Token: taschentücher, POS: NOUN, Lemma: Taschentücher
# Token: damenbinden, POS: ADJ, Lemma: Damenbinden
# Token: babywindeln, POS: NOUN, Lemma: babywindeln
# Token: staub, POS: NOUN, Lemma: Staub
# Token: asche, POS: ADJ, Lemma: asch
# Token: kehricht, POS: NOUN, Lemma: Kehricht
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: küchentücher, POS: ADJ, Lemma: küchentüch
# Token: putzlappen, POS: ADJ, Lemma: Putzlapp
# Token: trinkgläser, POS: ADJ, Lemma: Trinkgläser
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: scherben, POS: VERB, Lemma: scherben
# Token: elektrogeräteschrott, POS: NOUN, Lemma: Elektrogeräteschrott
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: großgeräte, POS: NOUN, Lemma: großgeräte
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: batterien, POS: VERB, Lemma: batterien
# Token: spezielle, POS: ADJ, Lemma: speziell
# Token: sammelbehälter, POS: NOUN, Lemma: Sammelbehälter
# Token: supermärkten, POS: NOUN, Lemma: Supermärkt
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: gebäuden, POS: NOUN, Lemma: Gebäud
# Token: sonderabfallschadstoffe, POS: NOUN, Lemma: Sonderabfallschadstoffe
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: lacke, POS: NOUN, Lemma: Lack
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: ver, POS: ADJ, Lemma:
# Token: wattebäusche, POS: ADJ, Lemma: wattebäusch
# Token: spiegel, POS: NOUN, Lemma: Spiegel
#
# ==================================================
#
# Final Token Information for Document 1:
#
# Token: gehört, POS: VERB, Lemma: gehören
# Token: bioabfall, POS: NOUN, Lemma: Bioabfall
# Token: gehört, POS: VERB, Lemma: gehören
# Token: biotonne, POS: NOUN, Lemma: Biotonne
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsereste, POS: ADJ, Lemma: gemüser
# Token: kaffeesatz, POS: NOUN, Lemma: Kaffeesatz
# Token: filter, POS: ADJ, Lemma: filt
# Token: tee, POS: NOUN, Lemma:
# Token: essensreste, POS: ADJ, Lemma: essensreste
# Token: gekochte, POS: ADJ, Lemma: gekocht
# Token: alte, POS: ADJ, Lemma:
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: verpackung, POS: NOUN, Lemma: Verpackung
# Token: eierschalen, POS: ADJ, Lemma: eierschalen
# Token: blumen, POS: NOUN, Lemma: blum
# Token: gartenabfälle, POS: ADJ, Lemma: Gartenabfäll
# Token: laub, POS: NOUN, Lemma: Laub
# Token: einwickelpapier, POS: NOUN, Lemma: Einwickelpapier
# Token: biotonne, POS: NOUN, Lemma: Biotonne
# Token: plastiktüten, POS: ADJ, Lemma: plastiktüt
# Token: erde, POS: NOUN, Lemma: Erde
# Token: holz, POS: NOUN, Lemma: Holz
# Token: grassoden, POS: ADJ, Lemma: grassod
# Token: sand, POS: NOUN, Lemma: Sand
# Token: steine, POS: ADJ, Lemma: stein
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scannen
# Token: erhalten, POS: VERB, Lemma: erhalten
# Token: informationen, POS: NOUN, Lemma: Information
# Token: sprachen, POS: NOUN, Lemma: Sprache
# Token: trenne, POS: VERB, Lemma: trennen
# Token: gehört, POS: VERB, Lemma: gehören
# Token: restmülltonne, POS: ADJ, Lemma: restmülltonn
# Token: zigarettenkippen, POS: NOUN, Lemma: Zigarettenkipp
# Token: asche, POS: ADJ, Lemma: asch
# Token: kehricht, POS: NOUN, Lemma: Kehricht
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: tonteller, POS: NOUN, Lemma: Tonteller
# Token: töpfe, POS: NOUN, Lemma: Töpf
# Token: putzlappen, POS: NOUN, Lemma: Putzlapp
# Token: schwämme, POS: ADJ, Lemma: schwämm
# Token: wegwerfwindeln, POS: NOUN, Lemma: wegwerfwindeln
# Token: hygieneartikel, POS: NOUN, Lemma: Hygieneartikel
# Token: restmülltonne, POS: ADJ, Lemma: restmülltonn
# Token: schadstoffe, POS: NOUN, Lemma: Schadstoff
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: bauschutt, POS: NOUN, Lemma: Bauschutt
# Token: entsorgungsbetriebe, POS: VERB, Lemma: entsorgungsbetrieb
# Token: gehört, POS: VERB, Lemma: gehören
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: zeitschriften, POS: NOUN, Lemma: Zeitschrift
# Token: kataloge, POS: NOUN, Lemma: Kataloge
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: prospekte, POS: ADJ, Lemma: prospekt
# Token: hefte, POS: ADJ, Lemma: heft
# Token: bücher, POS: ADJ, Lemma: büch
# Token: packpapier, POS: NOUN, Lemma: Packpapier
# Token: unbeschichtet, POS: VERB, Lemma: unbeschichten
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: telefonbücher, POS: NOUN, Lemma: Telefonbücher
# Token: papiertonne, POS: ADJ, Lemma: papiertonn
# Token: holz, POS: NOUN, Lemma: Holz
# Token: schmutziges, POS: ADJ, Lemma: schmutzig
# Token: fotos, POS: NOUN, Lemma: Foto
# Token: plastiktüten, POS: VERB, Lemma: plastiktüten
# Token: privathaushalt, POS: NOUN, Lemma: Privathaushalt
# Token: gelber, POS: ADJ, Lemma: Gelber
# Token: sack, POS: NOUN, Lemma: Sack
# Token: papiertonne, POS: VERB, Lemma: papiertonnen
# Token: gehört, POS: VERB, Lemma: gehören
# Token: verpackungsstyropor, POS: NOUN, Lemma: Verpackungsstyropor
# Token: kunststoffflaschen, POS: ADJ, Lemma: kunststoffflasch
# Token: plastiktüten, POS: ADJ, Lemma: plastiktüt
# Token: konservendosen, POS: NOUN, Lemma: Konservendosen
# Token: milch, POS: NOUN, Lemma: Milch
# Token: safttüten, POS: VERB, Lemma: safttüen
# Token: vakuumverpackungen, POS: NOUN, Lemma: Vakuumverpackung
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: plastikschüsseln, POS: VERB, Lemma: plastikschüsseln
# Token: beschichtetes, POS: ADJ, Lemma: beschichtet
# Token: papier, POS: NOUN, Lemma: Papier
# Token: kleiderbügel, POS: NOUN, Lemma: Kleiderbügel
# Token: kunststoffrohre, POS: VERB, Lemma: kunststoffrohren
# Token: uhr, POS: NOUN, Lemma:
# Token: uhr, POS: NOUN, Lemma:
# Token: romn, POS: ADJ, Lemma: romn
# Token: kurd, POS: NOUN, Lemma: Kurd
# Token: gelben, POS: ADJ, Lemma: gelben
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehört, POS: VERB, Lemma: gehören
# Token: glascontainer, POS: ADJ, Lemma: glascontainer
# Token: weißglas, POS: ADJ, Lemma: weißglas
# Token: buntglas, POS: NOUN, Lemma: Buntglas
# Token: einwegglasflaschen, POS: ADJ, Lemma: einwegglasflasch
# Token: sonstiges, POS: ADJ, Lemma: sonstig
# Token: hohlglas, POS: NOUN, Lemma: Hohlglas
# Token: nutzen, POS: VERB, Lemma: nutzen
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: fragen, POS: NOUN, Lemma: Frage
# Token: mülltrennung, POS: NOUN, Lemma: Mülltrennung
# Token: beraten, POS: VERB, Lemma: beraten
# Token: sack, POS: NOUN, Lemma: Sack
# Token: glascontainer, POS: ADJ, Lemma: Glascontainer
# Token: fensterscheiben, POS: VERB, Lemma: fensterscheiben
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: uhr, POS: NOUN, Lemma:
# Token: entsorgungsbetriebe, POS: VERB, Lemma: entsorgungsbetrieben
# Token: uhr, POS: NOUN, Lemma:
#
# ==================================================
#
# Final Token Information for Document 2:
#
# Token: glascontainer, POS: NOUN, Lemma: Glascontainer
# Token: gehören, POS: VERB, Lemma: gehören
# Token: restentleerte, POS: ADJ, Lemma: restentleert
# Token: glasverpackungen, POS: NOUN, Lemma: Glasverpackung
# Token: glasverpackungen, POS: NOUN, Lemma: Glasverpackung
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: weiß, POS: ADJ, Lemma: weiß
# Token: sortieren, POS: VERB, Lemma: sortieren
# Token: vorgesehenen, POS: ADJ, Lemma: vorgesehen
# Token: container, POS: NOUN, Lemma: Container
# Token: werfen, POS: VERB, Lemma: werfen
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: blaues, POS: ADJ, Lemma: blau
# Token: glas, POS: NOUN, Lemma: Glas
# Token: grünglas, POS: NOUN, Lemma: Grünglas
# Token: deckel, POS: NOUN, Lemma: Deckel
# Token: abgeschraubt, POS: VERB, Lemma: abgeschrauben
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: bepfandeten, POS: ADJ, Lemma: bepfandet
# Token: glasflaschen, POS: ADJ, Lemma: glasflasch
# Token: wein, POS: NOUN, Lemma: Wein
# Token: frucht, POS: NOUN, Lemma: fruchen
# Token: gemüse, POS: NOUN, Lemma: Gemüse
# Token: säfte, POS: NOUN, Lemma: säfen
# Token: fruchtnektare, POS: ADJ, Lemma: fruchtnektar
# Token: glas, POS: NOUN, Lemma: Glas
# Token: parfümflaschen, POS: ADJ, Lemma: parfümflasch
# Token: marmeladen, POS: ADJ, Lemma: marmelad
# Token: gurken, POS: VERB, Lemma: Gurk
# Token: senfgläser, POS: NOUN, Lemma: senfgläs
# Token: sonstiges, POS: ADJ, Lemma: sonstig
# Token: verpackungsglas, POS: NOUN, Lemma: Verpackungsglas
# Token: obst, POS: NOUN, Lemma: Obst
# Token: soßen, POS: NOUN, Lemma: Soße
# Token: suppen, POS: NOUN, Lemma: suppen
# Token: gemüse, POS: NOUN, Lemma: Gemüse
# Token: glas, POS: NOUN, Lemma: Glas
# Token: glas, POS: NOUN, Lemma: Glas
# Token: glascontainer, POS: NOUN, Lemma: Glascontainer
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: glas, POS: NOUN, Lemma: Glas
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: auflaufformen, POS: VERB, Lemma: auflaufform
# Token: hitzebeständiges, POS: ADJ, Lemma: hitzebeständig
# Token: glas, POS: NOUN, Lemma: Glas
# Token: steingutflaschen, POS: NOUN, Lemma: steingutflaschen
# Token: autolampen, POS: NOUN, Lemma: Autolamp
# Token: teller, POS: NOUN, Lemma: Teller
# Token: tassen, POS: VERB, Lemma: tassen
# Token: autoscheiben, POS: VERB, Lemma: Autoscheib
# Token: kaffeekannen, POS: VERB, Lemma: kaffeekannen
# Token: trinkgläser, POS: NOUN, Lemma: Trinkgläser
# Token: batterien, POS: NOUN, Lemma: batteri
# Token: bio, POS: NOUN, Lemma:
# Token: restabfall, POS: NOUN, Lemma: Restabfall
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: bleiglas, POS: NOUN, Lemma: Bleiglas
# Token: leuchtstoffröhren, POS: NOUN, Lemma: leuchtstoffröhren
# Token: blumentöpfe, POS: ADJ, Lemma: blumentöpf
# Token: mikrowellengeschirr, POS: NOUN, Lemma: Mikrowellengeschirr
# Token: flachglas, POS: NOUN, Lemma: Flachgla
# Token: produkte, POS: NOUN, Lemma: Produkt
# Token: verpackungsbestandteile, POS: NOUN, Lemma: verpackungsbestandteil
# Token: glaskeramik, POS: NOUN, Lemma: Glaskeramik
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: glaskochplatten, POS: NOUN, Lemma: Glaskochplatt
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: spritzen, POS: VERB, Lemma: spritzen
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Token Information for Document 3:
#
# Token: papiertonne, POS: NOUN, Lemma: Papiertonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: nichtverpackungen, POS: NOUN, Lemma: nichtverpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: anhaftung, POS: NOUN, Lemma: Anhaftung
# Token: speiseresten, POS: NOUN, Lemma: Speiserest
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: zerkleinert, POS: VERB, Lemma: zerkleinert
# Token: zusammengelegt, POS: VERB, Lemma: zusammenlegen
# Token: gefaltet, POS: VERB, Lemma: falten
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: nichtverpackungen, POS: NOUN, Lemma: Nichtverpackung
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: briefe, POS: NOUN, Lemma: Brief
# Token: brötchen, POS: ADJ, Lemma: brötch
# Token: metzger, POS: NOUN, Lemma: Metzger
# Token: briefumschläge, POS: NOUN, Lemma: briefumschlägen
# Token: obsttüten, POS: ADJ, Lemma: obsttüt
# Token: bücher, POS: ADJ, Lemma: büch
# Token: eierschachteln, POS: NOUN, Lemma: Eierschachtel
# Token: geschenkpapier, POS: NOUN, Lemma: Geschenkpapier
# Token: faltschachteln, POS: VERB, Lemma: faltschachteln
# Token: form, POS: NOUN, Lemma: Form
# Token: kataloge, POS: VERB, Lemma: Kataloge
# Token: füllmaterial, POS: NOUN, Lemma: Füllmaterial
# Token: postkarten, POS: NOUN, Lemma: Postkart
# Token: papier, POS: NOUN, Lemma: Papier
# Token: schulhefte, POS: NOUN, Lemma: schulheft
# Token: mehl, POS: NOUN, Lemma: Mehl
# Token: zuckertüten, POS: VERB, Lemma: Zuckertüte
# Token: werbeprospekte, POS: NOUN, Lemma: werbeprospekt
# Token: zeitschriften, POS: NOUN, Lemma: zeitschrift
# Token: papiertragetaschen, POS: ADJ, Lemma: papiertragetasch
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: pappummantelung, POS: NOUN, Lemma: Pappummantelung
# Token: joghurtbechern, POS: NOUN, Lemma: joghurtbechern
# Token: pralinenschachteln, POS: VERB, Lemma: Pralinenschachtel
# Token: papiertonne, POS: NOUN, Lemma: Papiertonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: bioabfall, POS: NOUN, Lemma: Bioabfall
# Token: metalle, POS: ADJ, Lemma: metall
# Token: butterfolie, POS: NOUN, Lemma: Butterfolie
# Token: milch, POS: NOUN, Lemma: Milch
# Token: dosen, POS: VERB, Lemma: dosen
# Token: suppen, POS: VERB, Lemma: suppen
# Token: soßentüten, POS: NOUN, Lemma: Soßentüte
# Token: fotos, POS: NOUN, Lemma: Foto
# Token: glas, POS: NOUN, Lemma: Glas
# Token: thermopapier, POS: NOUN, Lemma: Thermopapier
# Token: holzschachteln, POS: VERB, Lemma: holzschachteln
# Token: holzwolle, POS: ADJ, Lemma: holzwoll
# Token: tapeten, POS: NOUN, Lemma: tapeten
# Token: kontoauszüge, POS: ADJ, Lemma: kontoauszüge
# Token: erschmutzte, POS: ADJ, Lemma: erschmutzen
# Token: volle, POS: ADJ, Lemma: voll
# Token: thermopapiere, POS: ADJ, Lemma: thermopapierer
# Token: verpackungen, POS: ADJ, Lemma: verpackungen
# Token: küchenabfälle, POS: NOUN, Lemma: küchenabfällen
# Token: wein, POS: NOUN, Lemma: Wein
# Token: sektkorken, POS: VERB, Lemma: sektkorken
# Token: küchen, POS: ADJ, Lemma: küch
# Token: papiertaschentücher, POS: NOUN, Lemma: Papiertaschentücher
# Token: kunststoffe, POS: ADJ, Lemma: kunststoff
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Token Information for Document 4:
#
# Token: wertstofftonne, POS: NOUN, Lemma: Wertstofftonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: gebrauchte, POS: ADJ, Lemma: gebraucht
# Token: restlentleerte, POS: VERB, Lemma: restlentleeren
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: gegenstände, POS: NOUN, Lemma: Gegenstand
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: metall, POS: NOUN, Lemma: Metall
# Token: verpackungsbestand, POS: VERB, Lemma: Verpackungsbestand
# Token: teile, POS: NOUN, Lemma: Teil
# Token: trennen, POS: VERB, Lemma: trennen
# Token: ausspülen, POS: VERB, Lemma: Ausspül
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: saftflaschen, POS: ADJ, Lemma: saftflasch
# Token: schalen, POS: ADJ, Lemma: schal
# Token: schaumstoffe, POS: NOUN, Lemma: Schaumstoff
# Token: arzneimittelblister, POS: NOUN, Lemma: arzneimittelblist
# Token: schrauben, POS: NOUN, Lemma: Schraube
# Token: esteck, POS: NOUN, Lemma: Esteck
# Token: spielzeug, POS: NOUN, Lemma: Spielzeug
# Token: flaschenverschlüsse, POS: ADJ, Lemma: flaschenverschlüsse
# Token: töpfe, POS: NOUN, Lemma: Töpf
# Token: folien, POS: NOUN, Lemma: Folie
# Token: werkzeuge, POS: NOUN, Lemma: werkzeug
# Token: ebrauchsgegenstände, POS: ADJ, Lemma: ebrauchsgegenständen
# Token: gießkannen, POS: ADJ, Lemma: gießkann
# Token: blumentöpfe, POS: NOUN, Lemma: Blumentöpfe
# Token: plastikschüsseln, POS: VERB, Lemma: plastikschüsseln
# Token: getränkedosen, POS: NOUN, Lemma: Getränkedose
# Token: margarinebecher, POS: ADJ, Lemma: margarinebech
# Token: unststoffflaschen, POS: VERB, Lemma: unststoffflaschen
# Token: waschmittelflaschen, POS: ADJ, Lemma: waschmittelflasch
# Token: icht, POS: NOUN, Lemma: Icht
# Token: wertstofftonne, POS: NOUN, Lemma: Wertstofftonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: restabfälle, POS: NOUN, Lemma: Restabfälle
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: verpackte, POS: ADJ, Lemma: verpackt
# Token: bzw, POS: NOUN, Lemma:
# Token: alte, POS: ADJ, Lemma:
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: akkus, POS: NOUN, Lemma: Akkus
# Token: abgelagerte, POS: ADJ, Lemma: abgelagert
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: holz, POS: NOUN, Lemma: Holz
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: kfzkleinteile, POS: NOUN, Lemma: Kfzkleinteil
# Token: bauabfälle, POS: ADJ, Lemma: Bauabfälle
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: medikamentenreste, POS: ADJ, Lemma: medikamentenr
# Token: datenträger, POS: ADJ, Lemma: Datenträger
# Token: mund, POS: NOUN, Lemma: Mund
# Token: nasenschutz, POS: NOUN, Lemma: Nasenschutz
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: schuhe, POS: VERB, Lemma: schuhen
# Token: gummi, POS: NOUN, Lemma: Gummi
# Token: spritzen, POS: VERB, Lemma: spritzen
# Token: holz, POS: NOUN, Lemma: Holz
# Token: holzreste, POS: ADJ, Lemma: holzrester
# Token: strumpfhosen, POS: NOUN, Lemma: Strumpfhosen
# Token: hygieneartikel, POS: NOUN, Lemma: Hygieneartikel
# Token: windeln, POS: VERB, Lemma: windeln
# Token: styroporreste, POS: NOUN, Lemma: Styroporrest
# Token: dämmplatten, POS: ADJ, Lemma: dämmplatt
# Token: binden, POS: NOUN, Lemma: Bind
# Token: wattereste, POS: NOUN, Lemma: wattereste
# Token: tapetenreste, POS: ADJ, Lemma: tapetenrest
# Token: kondome, POS: NOUN, Lemma: kondom
# Token: textilien, POS: NOUN, Lemma: Textilie
# Token: video, POS: NOUN, Lemma: Video
# Token: audiokassetten, POS: ADJ, Lemma: audiokassett
# Token: kanülen, POS: NOUN, Lemma: Kanül
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Token Information for Document 5:
#
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonneden, POS: NOUN, Lemma: Tonnede
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehören, POS: VERB, Lemma: gehören
# Token: gebrauchte, POS: ADJ, Lemma: gebraucht
# Token: restentleerte, POS: VERB, Lemma: restentleert
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: verpackungsbestandteile, POS: NOUN, Lemma: verpackungsbestandteil
# Token: trennen, POS: VERB, Lemma: trennen
# Token: ausspülen, POS: VERB, Lemma: Ausspül
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: menüschalen, POS: NOUN, Lemma: Menüschal
# Token: kunststoffdeckel, POS: NOUN, Lemma: Kunststoffdeckel
# Token: fertiggerichten, POS: VERB, Lemma: fertiggericht
# Token: arzneimittelblister, POS: NOUN, Lemma: Arzneimittelblister
# Token: milch, POS: NOUN, Lemma: Milch
# Token: müsliriegelfolie, POS: NOUN, Lemma: Müsliriegelfolie
# Token: joghurtbecher, POS: ADJ, Lemma: joghurtbech
# Token: nudeltüten, POS: NOUN, Lemma: nudeltüter
# Token: einkaufstüten, POS: VERB, Lemma: Einkaufstüt
# Token: putz, POS: NOUN, Lemma: Putz
# Token: reinigungsmittelflaschen, POS: ADJ, Lemma: reinigungsmittelflasch
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsebeutel, POS: NOUN, Lemma: Gemüsebeutel
# Token: nachfüllbeutel, POS: NOUN, Lemma: Nachfüllbeutel
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: waschmittel, POS: NOUN, Lemma: Waschmittel
# Token: flüssigseife, POS: NOUN, Lemma: flüssigseife
# Token: eisverpackungen, POS: VERB, Lemma: eisverpackungen
# Token: üllmaterial, POS: NOUN, Lemma: Üllmaterial
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: shampooflaschen, POS: ADJ, Lemma: shampooflasch
# Token: luftpolsterfolie, POS: NOUN, Lemma: Luftpolsterfolie
# Token: spraydosen, POS: NOUN, Lemma: Spraydose
# Token: soßentüten, POS: NOUN, Lemma: soßentüen
# Token: konservendosen, POS: NOUN, Lemma: Konservendosen
# Token: tierfutterdosen, POS: VERB, Lemma: tierfutterdosen
# Token: schalen, POS: ADJ, Lemma: schal
# Token: kronkorken, POS: NOUN, Lemma: kronkork
# Token: zahnpastatuben, POS: NOUN, Lemma: Zahnpastatuben
# Token: kunststoffschalen, POS: NOUN, Lemma: kunststoffschalen
# Token: folien, POS: NOUN, Lemma: folien
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonneden, POS: NOUN, Lemma: Tonnede
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: schuhe, POS: VERB, Lemma: schuhen
# Token: altkleider, POS: NOUN, Lemma: altkleid
# Token: gummi, POS: ADJ, Lemma: Gummi
# Token: strumpfhosen, POS: NOUN, Lemma: strumpfhosen
# Token: batterien, POS: NOUN, Lemma: Batterien
# Token: akkus, POS: NOUN, Lemma: Akkus
# Token: holzwolle, POS: ADJ, Lemma: holzwoll
# Token: styroporreste, POS: NOUN, Lemma: Styroporrest
# Token: behälterglas, POS: ADJ, Lemma: Behälterglas
# Token: dämmplatten, POS: ADJ, Lemma: dämmplatt
# Token: tapetenreste, POS: ADJ, Lemma: tapetenrest
# Token: cds, POS: NOUN, Lemma:
# Token: keramikprodukte, POS: NOUN, Lemma: Keramikprodukt
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: druckerpatronen, POS: ADJ, Lemma: druckerpatron
# Token: kinderspielzeug, POS: NOUN, Lemma: Kinderspielzeug
# Token: zahnbürsten, POS: VERB, Lemma: zahnbürsen
# Token: klarsichthüllen, POS: NOUN, Lemma: Klarsichthüll
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: kugelschreiber, POS: NOUN, Lemma: Kugelschreiber
# Token: essensreste, POS: ADJ, Lemma: essensreste
# Token: restentleerte, POS: VERB, Lemma: restentleert
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: faltschachteln, POS: VERB, Lemma: faltschachteln
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: feuerzeuge, POS: VERB, Lemma: feuerzeug
# Token: ilme, POS: ADJ, Lemma:
# Token: dvds, POS: NOUN, Lemma: dvds
# Token: pflaster, POS: NOUN, Lemma: Pflaster
# Token: videokassetten, POS: VERB, Lemma: videokassett
# Token: glüh, POS: NOUN, Lemma: Glüh
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: rest, POS: NOUN, Lemma: Rest
# Token: bioabfälle, POS: ADJ, Lemma: bioabfäll
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähere
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================

# %%
# Ausgabe der bereinigten Dokumente mit den Token-Informationen
for i, doc in enumerate(cleaned_documents):
    print(f"Final Text for Document {i}:\n")
    final_text = " ".join([token_info[0] for token_info in doc])
    print(final_text)
    
    print(f"\nFinal Token Information for Document {i}:\n")
    for token_info in doc:
        print(f"Token: {token_info[0]}, POS: {token_info[1]}, Lemma: {token_info[2]}")
    print("\n" + "="*50 + "\n")
# Out:
# Final Text for Document 0:
#
# blaue altglascontainer saubere flaschen deckelgläser farben weiß blaues buntes glas grünglas geben aschen konservengläser scheiben restmüll trinkgläser porzellan keramik glühbirnen restmüll energiesparlampen wertstoffhöfe verschmutzte gläser restmüll standort öffentlichen sperrmüll plätzen frankfurter entsorgungs abfall trennen service gmbh fesservicecenter ecke töngesgasseschärfengässchen uhr uhr rgungsfachbetrie rrt trennen haus gehören abfallbehälter tonnen inhalt wertvoller rohstoff neuen produkten weiterverarbeitet graue restmülltonne gelbe tonne verpackungen grüne tonne papier pappe braune tonne bioabfälle graue tonne restlichen abfall restmüll gibt folgende entsorgungsangebote wertstoffe sichern altglascontainer flaschen deckelgläser nden öffentlichen plätzen altkleider container altkleider schuhe nden stadtteil öffentlichen plätzen feswertstoffhöfen schadstoffe abfälle gefährlichen stoffen farben spraydosen mitteln fesschadstoffmobil abgeben termine nden jahr haushalte verteilt sperrmüllabholung holt fes termin wohnsiedlungen abgeholt termine nden schwarzen brett sperrmüll wertstoffe entsorgen hnff tie abfalltonnen haus dauer ausreichen hausbesitzer weiteregrößere bestellen internet spezialbehälter besondere abfälle baustellenabfälle erfahren servicetelefonnummer kosten sperrmüll abfallgebühr enthalten löse standorte fesmagazin erhalten wochen haus näheres gelbe verpackungstonne verpackungen symbol grünen papier pappe glas bestehen verpackungen gespült verpackungen kunststoff folien becher verbundverpackungen materialmix papier getränkekartons milchtüten verpackungen metall konserven getränkedosen geschäumte kunststoffe gemüseverpackungen verpackungen papier pappe verpackungen glas altglascontainer verschmutzte fastfoodverpackungen restmüll restmüll gelben tonne aussortiert weiterverarbeitet standort wohnhaus leerung grüne altpapiertonne punkt grüne altpapiertonne gehören papier pappe beschichtung pappen kartonagen styropor zeitungen illustrierte kataloge bücher hefte verschmutztes papier restmüll beschichtetes papier restmüll hygienepapiere windeln restmüll näheres sichere aktenvernichtung erfahren servicetelefonnummer wertstoffe standort wohnhaus leerung braune biotonne abbaubaren abfälle privaten haushalten feuchte bioabfälle salat obst gemüsereste zeitungs wickeln schützen tonne starker verschmutzung gemüseabfälle zitrusfrüchte bananen nussschalen rohe gekochte speise lebensmittelreste kaffee teesatz filtertüten eierschalen grünschnitt plastiktüten verpackungen kunststoff metall gelbe verpackungstonne kehricht windeln andere gebrauchte restmüll standort wohnhaus leerung graue restmülltonne abfälle verunreinigung vermischung anderen tonnen entsorgt schmutzte lebensmittelverpackungen taschentücher damenbinden babywindeln staub asche kehricht zigarettenkippen küchentücher putzlappen trinkgläser porzellan keramik scherben elektrogeräteschrott wertstoffhöfe großgeräte sperrmüll batterien spezielle sammelbehälter supermärkten öffentlichen gebäuden sonderabfallschadstoffe farben lacke standort wohnhaus leerung ver wattebäusche spiegel
#
# Final Token Information for Document 0:
#
# Token: blaue, POS: ADJ, Lemma: blau
# Token: altglascontainer, POS: NOUN, Lemma: Altglascontainer
# Token: saubere, POS: ADJ, Lemma: sauber
# Token: flaschen, POS: NOUN, Lemma: Flasche
# Token: deckelgläser, POS: NOUN, Lemma: Deckelglas
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: weiß, POS: ADJ, Lemma: weiß
# Token: blaues, POS: ADJ, Lemma: blau
# Token: buntes, POS: ADJ, Lemma: bunt
# Token: glas, POS: NOUN, Lemma: Glas
# Token: grünglas, POS: NOUN, Lemma: Grünglas
# Token: geben, POS: VERB, Lemma: geben
# Token: aschen, POS: ADJ, Lemma: asch
# Token: konservengläser, POS: NOUN, Lemma: Konservenglas
# Token: scheiben, POS: VERB, Lemma: Scheiben
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: trinkgläser, POS: NOUN, Lemma: Trinkgläser
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: verschmutzte, POS: ADJ, Lemma: verschmutzt
# Token: gläser, POS: ADJ, Lemma: Gläser
# Token: restmüll, POS: ADJ, Lemma: Restmüll
# Token: standort, POS: NOUN, Lemma: Standort
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: sperrmüll, POS: VERB, Lemma: Sperrmüll
# Token: plätzen, POS: VERB, Lemma: plätzen
# Token: frankfurter, POS: ADJ, Lemma: Frankfurter
# Token: entsorgungs, POS: NOUN, Lemma: Entsorgung
# Token: abfall, POS: NOUN, Lemma: Abfall
# Token: trennen, POS: VERB, Lemma: trennen
# Token: service, POS: NOUN, Lemma: Service
# Token: gmbh, POS: VERB, Lemma: Gmbh
# Token: fesservicecenter, POS: NOUN, Lemma: Fesservicecenter
# Token: ecke, POS: NOUN, Lemma: Ecke
# Token: töngesgasseschärfengässchen, POS: VERB, Lemma: töngesgasseschärfengässchen
# Token: uhr, POS: NOUN, Lemma:
# Token: uhr, POS: NOUN, Lemma:
# Token: rgungsfachbetrie, POS: NOUN, Lemma: Rgungsfachbetrie
# Token: rrt, POS: VERB, Lemma: rren
# Token: trennen, POS: VERB, Lemma: trennen
# Token: haus, POS: NOUN, Lemma: Haus
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfallbehälter, POS: NOUN, Lemma: Abfallbehälter
# Token: tonnen, POS: NOUN, Lemma: Tonne
# Token: inhalt, POS: NOUN, Lemma: Inhalt
# Token: wertvoller, POS: ADJ, Lemma: Wertvoller
# Token: rohstoff, POS: NOUN, Lemma: Rohstoff
# Token: neuen, POS: ADJ, Lemma:
# Token: produkten, POS: NOUN, Lemma: Produkt
# Token: weiterverarbeitet, POS: VERB, Lemma: weiterverarbeiten
# Token: graue, POS: ADJ, Lemma: grau
# Token: restmülltonne, POS: NOUN, Lemma: Restmülltonne
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: verpackungen, POS: NOUN, Lemma: verpackunger
# Token: grüne, POS: ADJ, Lemma: grün
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: braune, POS: ADJ, Lemma: braun
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: bioabfälle, POS: ADJ, Lemma: bioabfälle
# Token: graue, POS: ADJ, Lemma: grau
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: restlichen, POS: ADJ, Lemma: restlich
# Token: abfall, POS: NOUN, Lemma: Abfall
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: gibt, POS: VERB, Lemma: geben
# Token: folgende, POS: ADJ, Lemma: folgend
# Token: entsorgungsangebote, POS: ADJ, Lemma: entsorgungsangebot
# Token: wertstoffe, POS: NOUN, Lemma: wertstoffe
# Token: sichern, POS: VERB, Lemma: sichern
# Token: altglascontainer, POS: NOUN, Lemma: Altglascontainer
# Token: flaschen, POS: NOUN, Lemma: Flasche
# Token: deckelgläser, POS: NOUN, Lemma: Deckelglas
# Token: nden, POS: VERB, Lemma: nden
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: plätzen, POS: NOUN, Lemma: Plätz
# Token: altkleider, POS: NOUN, Lemma: altkleid
# Token: container, POS: NOUN, Lemma: Container
# Token: altkleider, POS: NOUN, Lemma: altkleider
# Token: schuhe, POS: NOUN, Lemma: schuhen
# Token: nden, POS: VERB, Lemma: nden
# Token: stadtteil, POS: NOUN, Lemma: Stadtteil
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: plätzen, POS: NOUN, Lemma: Plätz
# Token: feswertstoffhöfen, POS: NOUN, Lemma: Feswertstoffhöf
# Token: schadstoffe, POS: NOUN, Lemma: Schadstoff
# Token: abfälle, POS: NOUN, Lemma: Abfäll
# Token: gefährlichen, POS: ADJ, Lemma: gefährlich
# Token: stoffen, POS: NOUN, Lemma: Stoff
# Token: farben, POS: NOUN, Lemma: farbe
# Token: spraydosen, POS: NOUN, Lemma: Spraydos
# Token: mitteln, POS: VERB, Lemma: mitteln
# Token: fesschadstoffmobil, POS: NOUN, Lemma: Fesschadstoffmobil
# Token: abgeben, POS: VERB, Lemma: abgeben
# Token: termine, POS: NOUN, Lemma: terminen
# Token: nden, POS: VERB, Lemma: nden
# Token: jahr, POS: NOUN, Lemma: Jahr
# Token: haushalte, POS: NOUN, Lemma: Haushalt
# Token: verteilt, POS: VERB, Lemma: verteilen
# Token: sperrmüllabholung, POS: NOUN, Lemma: Sperrmüllabholung
# Token: holt, POS: VERB, Lemma: holen
# Token: fes, POS: NOUN, Lemma:
# Token: termin, POS: NOUN, Lemma: Termin
# Token: wohnsiedlungen, POS: NOUN, Lemma: Wohnsiedlung
# Token: abgeholt, POS: VERB, Lemma: abholen
# Token: termine, POS: NOUN, Lemma: termin
# Token: nden, POS: VERB, Lemma: nden
# Token: schwarzen, POS: ADJ, Lemma: schwarz
# Token: brett, POS: NOUN, Lemma: Brett
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: wertstoffe, POS: VERB, Lemma: Wertstoff
# Token: entsorgen, POS: VERB, Lemma: entsorgen
# Token: hnff, POS: VERB, Lemma: Hnff
# Token: tie, POS: NOUN, Lemma:
# Token: abfalltonnen, POS: NOUN, Lemma: Abfalltonn
# Token: haus, POS: NOUN, Lemma: Haus
# Token: dauer, POS: NOUN, Lemma: Dauer
# Token: ausreichen, POS: VERB, Lemma: ausreichen
# Token: hausbesitzer, POS: NOUN, Lemma: hausbesitz
# Token: weiteregrößere, POS: ADJ, Lemma: Weiteregrößere
# Token: bestellen, POS: VERB, Lemma: bestellen
# Token: internet, POS: NOUN, Lemma: Internet
# Token: spezialbehälter, POS: NOUN, Lemma: Spezialbehälter
# Token: besondere, POS: ADJ, Lemma: besonderer
# Token: abfälle, POS: NOUN, Lemma: abfäll
# Token: baustellenabfälle, POS: VERB, Lemma: baustellenabfälle
# Token: erfahren, POS: VERB, Lemma: erfahren
# Token: servicetelefonnummer, POS: NOUN, Lemma: Servicetelefonnummer
# Token: kosten, POS: NOUN, Lemma: Kosten
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: abfallgebühr, POS: NOUN, Lemma: Abfallgebühr
# Token: enthalten, POS: VERB, Lemma: enthalten
# Token: löse, POS: ADJ, Lemma:
# Token: standorte, POS: ADJ, Lemma: standort
# Token: fesmagazin, POS: NOUN, Lemma: Fesmagazin
# Token: erhalten, POS: VERB, Lemma: erhalten
# Token: wochen, POS: NOUN, Lemma: Woche
# Token: haus, POS: NOUN, Lemma: Haus
# Token: näheres, POS: NOUN, Lemma: Näheres
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: verpackungstonne, POS: NOUN, Lemma: Verpackungstonne
# Token: verpackungen, POS: NOUN, Lemma: Verpackunge
# Token: symbol, POS: NOUN, Lemma: Symbol
# Token: grünen, POS: NOUN, Lemma: grüne
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: glas, POS: NOUN, Lemma: Glas
# Token: bestehen, POS: VERB, Lemma: bestehen
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: gespült, POS: VERB, Lemma: spülen
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: folien, POS: NOUN, Lemma: folien
# Token: becher, POS: ADJ, Lemma: bech
# Token: verbundverpackungen, POS: NOUN, Lemma: Verbundverpackung
# Token: materialmix, POS: NOUN, Lemma: Materialmix
# Token: papier, POS: NOUN, Lemma: Papier
# Token: getränkekartons, POS: NOUN, Lemma: Getränkekarton
# Token: milchtüten, POS: VERB, Lemma: milchtüen
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: metall, POS: NOUN, Lemma: Metall
# Token: konserven, POS: NOUN, Lemma: Konserve
# Token: getränkedosen, POS: ADJ, Lemma: getränkedosen
# Token: geschäumte, POS: ADJ, Lemma: geschäumt
# Token: kunststoffe, POS: NOUN, Lemma: kunststoff
# Token: gemüseverpackungen, POS: VERB, Lemma: gemüseverpackungen
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: glas, POS: NOUN, Lemma: Glas
# Token: altglascontainer, POS: ADJ, Lemma: altglascontain
# Token: verschmutzte, POS: ADJ, Lemma: verschmutzt
# Token: fastfoodverpackungen, POS: NOUN, Lemma: Fastfoodverpackung
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: tonne, POS: NOUN, Lemma: Tonne
# Token: aussortiert, POS: VERB, Lemma: aussortieren
# Token: weiterverarbeitet, POS: VERB, Lemma: weiterverarbeitet
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: grüne, POS: ADJ, Lemma: grün
# Token: altpapiertonne, POS: NOUN, Lemma: Altpapiertonne
# Token: punkt, POS: NOUN, Lemma: Punkt
# Token: grüne, POS: ADJ, Lemma: grün
# Token: altpapiertonne, POS: NOUN, Lemma: altpapiertonn
# Token: gehören, POS: VERB, Lemma: gehören
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: beschichtung, POS: NOUN, Lemma: Beschichtung
# Token: pappen, POS: NOUN, Lemma: Pappe
# Token: kartonagen, POS: ADJ, Lemma: kartonag
# Token: styropor, POS: NOUN, Lemma: Styropor
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: illustrierte, POS: ADJ, Lemma: illustriert
# Token: kataloge, POS: NOUN, Lemma: Kataloge
# Token: bücher, POS: NOUN, Lemma: büch
# Token: hefte, POS: VERB, Lemma: hefen
# Token: verschmutztes, POS: ADJ, Lemma: verschmutzt
# Token: papier, POS: NOUN, Lemma: Papier
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: beschichtetes, POS: ADJ, Lemma: beschichtet
# Token: papier, POS: NOUN, Lemma: Papier
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: hygienepapiere, POS: ADJ, Lemma: hygienepapi
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: restmüll, POS: NOUN, Lemma: Restmüll
# Token: näheres, POS: NOUN, Lemma: Näheres
# Token: sichere, POS: ADJ, Lemma: sicher
# Token: aktenvernichtung, POS: NOUN, Lemma: Aktenvernichtung
# Token: erfahren, POS: VERB, Lemma: erfahren
# Token: servicetelefonnummer, POS: NOUN, Lemma: Servicetelefonnummer
# Token: wertstoffe, POS: ADJ, Lemma: wertstoff
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: braune, POS: ADJ, Lemma: braun
# Token: biotonne, POS: VERB, Lemma: biotonnen
# Token: abbaubaren, POS: ADJ, Lemma: abbaubar
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: privaten, POS: ADJ, Lemma: privat
# Token: haushalten, POS: NOUN, Lemma: Haushalt
# Token: feuchte, POS: ADJ, Lemma: feucht
# Token: bioabfälle, POS: NOUN, Lemma: Bioabfäll
# Token: salat, POS: NOUN, Lemma: Salat
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsereste, POS: VERB, Lemma: gemüseresen
# Token: zeitungs, POS: NOUN, Lemma: Zeitungs
# Token: wickeln, POS: VERB, Lemma: wickeln
# Token: schützen, POS: VERB, Lemma: schützen
# Token: tonne, POS: VERB, Lemma: tonnen
# Token: starker, POS: ADJ, Lemma: stark
# Token: verschmutzung, POS: NOUN, Lemma: Verschmutzung
# Token: gemüseabfälle, POS: NOUN, Lemma: Gemüseabfälle
# Token: zitrusfrüchte, POS: ADJ, Lemma: zitrusfrücht
# Token: bananen, POS: NOUN, Lemma: Banane
# Token: nussschalen, POS: VERB, Lemma: nussschalen
# Token: rohe, POS: ADJ, Lemma:
# Token: gekochte, POS: ADJ, Lemma: gekocht
# Token: speise, POS: NOUN, Lemma: Speise
# Token: lebensmittelreste, POS: ADJ, Lemma: lebensmittelr
# Token: kaffee, POS: NOUN, Lemma: Kaffee
# Token: teesatz, POS: NOUN, Lemma: Teesatz
# Token: filtertüten, POS: VERB, Lemma: filtertüt
# Token: eierschalen, POS: ADJ, Lemma: Eierschale
# Token: grünschnitt, POS: NOUN, Lemma: Grünschnitt
# Token: plastiktüten, POS: VERB, Lemma: plastiktüt
# Token: verpackungen, POS: NOUN, Lemma: Verpackunge
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: metall, POS: NOUN, Lemma: Metall
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: verpackungstonne, POS: NOUN, Lemma: Verpackungstonne
# Token: kehricht, POS: VERB, Lemma: Kehricht
# Token: windeln, POS: VERB, Lemma: windeln
# Token: andere, POS: ADJ, Lemma: anderer
# Token: gebrauchte, POS: NOUN, Lemma: Gebraucht
# Token: restmüll, POS: ADJ, Lemma: Restmüll
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: graue, POS: ADJ, Lemma: grau
# Token: restmülltonne, POS: NOUN, Lemma: Restmülltonne
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verunreinigung, POS: NOUN, Lemma: Verunreinigung
# Token: vermischung, POS: NOUN, Lemma: Vermischung
# Token: anderen, POS: ADJ, Lemma: anderer
# Token: tonnen, POS: NOUN, Lemma: Tonne
# Token: entsorgt, POS: VERB, Lemma: entsorgen
# Token: schmutzte, POS: NOUN, Lemma: schmutzt
# Token: lebensmittelverpackungen, POS: NOUN, Lemma: lebensmittelverpackungen
# Token: taschentücher, POS: NOUN, Lemma: Taschentücher
# Token: damenbinden, POS: ADJ, Lemma: Damenbinden
# Token: babywindeln, POS: NOUN, Lemma: babywindeln
# Token: staub, POS: NOUN, Lemma: Staub
# Token: asche, POS: ADJ, Lemma: asch
# Token: kehricht, POS: NOUN, Lemma: Kehricht
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: küchentücher, POS: ADJ, Lemma: küchentüch
# Token: putzlappen, POS: ADJ, Lemma: Putzlapp
# Token: trinkgläser, POS: ADJ, Lemma: Trinkgläser
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: scherben, POS: VERB, Lemma: scherben
# Token: elektrogeräteschrott, POS: NOUN, Lemma: Elektrogeräteschrott
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: großgeräte, POS: NOUN, Lemma: großgeräte
# Token: sperrmüll, POS: NOUN, Lemma: Sperrmüll
# Token: batterien, POS: VERB, Lemma: batterien
# Token: spezielle, POS: ADJ, Lemma: speziell
# Token: sammelbehälter, POS: NOUN, Lemma: Sammelbehälter
# Token: supermärkten, POS: NOUN, Lemma: Supermärkt
# Token: öffentlichen, POS: ADJ, Lemma: öffentlich
# Token: gebäuden, POS: NOUN, Lemma: Gebäud
# Token: sonderabfallschadstoffe, POS: NOUN, Lemma: Sonderabfallschadstoffe
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: lacke, POS: NOUN, Lemma: Lack
# Token: standort, POS: NOUN, Lemma: Standort
# Token: wohnhaus, POS: NOUN, Lemma: Wohnhaus
# Token: leerung, POS: NOUN, Lemma: Leerung
# Token: ver, POS: ADJ, Lemma:
# Token: wattebäusche, POS: ADJ, Lemma: wattebäusch
# Token: spiegel, POS: NOUN, Lemma: Spiegel
#
# ==================================================
#
# Final Text for Document 1:
#
# gehört bioabfall gehört biotonne obst gemüsereste kaffeesatz filter tee essensreste gekochte alte lebensmittel verpackung eierschalen blumen gartenabfälle laub einwickelpapier biotonne plastiktüten erde holz grassoden sand steine qrcode scannen erhalten informationen sprachen trenne gehört restmülltonne zigarettenkippen asche kehricht keramik tonteller töpfe putzlappen schwämme wegwerfwindeln hygieneartikel restmülltonne schadstoffe batterien elektrogeräte bauschutt entsorgungsbetriebe gehört zeitungen zeitschriften kataloge pappe prospekte hefte bücher packpapier unbeschichtet pappe telefonbücher papiertonne holz schmutziges fotos plastiktüten privathaushalt gelber sack papiertonne gehört verpackungsstyropor kunststoffflaschen plastiktüten konservendosen milch safttüten vakuumverpackungen gelben plastikschüsseln beschichtetes papier kleiderbügel kunststoffrohre uhr uhr romn kurd gelben sack gehört glascontainer weißglas buntglas einwegglasflaschen sonstiges hohlglas nutzen wertstoffhöfe fragen mülltrennung beraten sack glascontainer fensterscheiben porzellan keramik glühbirnen uhr entsorgungsbetriebe uhr
#
# Final Token Information for Document 1:
#
# Token: gehört, POS: VERB, Lemma: gehören
# Token: bioabfall, POS: NOUN, Lemma: Bioabfall
# Token: gehört, POS: VERB, Lemma: gehören
# Token: biotonne, POS: NOUN, Lemma: Biotonne
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsereste, POS: ADJ, Lemma: gemüser
# Token: kaffeesatz, POS: NOUN, Lemma: Kaffeesatz
# Token: filter, POS: ADJ, Lemma: filt
# Token: tee, POS: NOUN, Lemma:
# Token: essensreste, POS: ADJ, Lemma: essensreste
# Token: gekochte, POS: ADJ, Lemma: gekocht
# Token: alte, POS: ADJ, Lemma:
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: verpackung, POS: NOUN, Lemma: Verpackung
# Token: eierschalen, POS: ADJ, Lemma: eierschalen
# Token: blumen, POS: NOUN, Lemma: blum
# Token: gartenabfälle, POS: ADJ, Lemma: Gartenabfäll
# Token: laub, POS: NOUN, Lemma: Laub
# Token: einwickelpapier, POS: NOUN, Lemma: Einwickelpapier
# Token: biotonne, POS: NOUN, Lemma: Biotonne
# Token: plastiktüten, POS: ADJ, Lemma: plastiktüt
# Token: erde, POS: NOUN, Lemma: Erde
# Token: holz, POS: NOUN, Lemma: Holz
# Token: grassoden, POS: ADJ, Lemma: grassod
# Token: sand, POS: NOUN, Lemma: Sand
# Token: steine, POS: ADJ, Lemma: stein
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scannen
# Token: erhalten, POS: VERB, Lemma: erhalten
# Token: informationen, POS: NOUN, Lemma: Information
# Token: sprachen, POS: NOUN, Lemma: Sprache
# Token: trenne, POS: VERB, Lemma: trennen
# Token: gehört, POS: VERB, Lemma: gehören
# Token: restmülltonne, POS: ADJ, Lemma: restmülltonn
# Token: zigarettenkippen, POS: NOUN, Lemma: Zigarettenkipp
# Token: asche, POS: ADJ, Lemma: asch
# Token: kehricht, POS: NOUN, Lemma: Kehricht
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: tonteller, POS: NOUN, Lemma: Tonteller
# Token: töpfe, POS: NOUN, Lemma: Töpf
# Token: putzlappen, POS: NOUN, Lemma: Putzlapp
# Token: schwämme, POS: ADJ, Lemma: schwämm
# Token: wegwerfwindeln, POS: NOUN, Lemma: wegwerfwindeln
# Token: hygieneartikel, POS: NOUN, Lemma: Hygieneartikel
# Token: restmülltonne, POS: ADJ, Lemma: restmülltonn
# Token: schadstoffe, POS: NOUN, Lemma: Schadstoff
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: bauschutt, POS: NOUN, Lemma: Bauschutt
# Token: entsorgungsbetriebe, POS: VERB, Lemma: entsorgungsbetrieb
# Token: gehört, POS: VERB, Lemma: gehören
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: zeitschriften, POS: NOUN, Lemma: Zeitschrift
# Token: kataloge, POS: NOUN, Lemma: Kataloge
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: prospekte, POS: ADJ, Lemma: prospekt
# Token: hefte, POS: ADJ, Lemma: heft
# Token: bücher, POS: ADJ, Lemma: büch
# Token: packpapier, POS: NOUN, Lemma: Packpapier
# Token: unbeschichtet, POS: VERB, Lemma: unbeschichten
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: telefonbücher, POS: NOUN, Lemma: Telefonbücher
# Token: papiertonne, POS: ADJ, Lemma: papiertonn
# Token: holz, POS: NOUN, Lemma: Holz
# Token: schmutziges, POS: ADJ, Lemma: schmutzig
# Token: fotos, POS: NOUN, Lemma: Foto
# Token: plastiktüten, POS: VERB, Lemma: plastiktüten
# Token: privathaushalt, POS: NOUN, Lemma: Privathaushalt
# Token: gelber, POS: ADJ, Lemma: Gelber
# Token: sack, POS: NOUN, Lemma: Sack
# Token: papiertonne, POS: VERB, Lemma: papiertonnen
# Token: gehört, POS: VERB, Lemma: gehören
# Token: verpackungsstyropor, POS: NOUN, Lemma: Verpackungsstyropor
# Token: kunststoffflaschen, POS: ADJ, Lemma: kunststoffflasch
# Token: plastiktüten, POS: ADJ, Lemma: plastiktüt
# Token: konservendosen, POS: NOUN, Lemma: Konservendosen
# Token: milch, POS: NOUN, Lemma: Milch
# Token: safttüten, POS: VERB, Lemma: safttüen
# Token: vakuumverpackungen, POS: NOUN, Lemma: Vakuumverpackung
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: plastikschüsseln, POS: VERB, Lemma: plastikschüsseln
# Token: beschichtetes, POS: ADJ, Lemma: beschichtet
# Token: papier, POS: NOUN, Lemma: Papier
# Token: kleiderbügel, POS: NOUN, Lemma: Kleiderbügel
# Token: kunststoffrohre, POS: VERB, Lemma: kunststoffrohren
# Token: uhr, POS: NOUN, Lemma:
# Token: uhr, POS: NOUN, Lemma:
# Token: romn, POS: ADJ, Lemma: romn
# Token: kurd, POS: NOUN, Lemma: Kurd
# Token: gelben, POS: ADJ, Lemma: gelben
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehört, POS: VERB, Lemma: gehören
# Token: glascontainer, POS: ADJ, Lemma: glascontainer
# Token: weißglas, POS: ADJ, Lemma: weißglas
# Token: buntglas, POS: NOUN, Lemma: Buntglas
# Token: einwegglasflaschen, POS: ADJ, Lemma: einwegglasflasch
# Token: sonstiges, POS: ADJ, Lemma: sonstig
# Token: hohlglas, POS: NOUN, Lemma: Hohlglas
# Token: nutzen, POS: VERB, Lemma: nutzen
# Token: wertstoffhöfe, POS: NOUN, Lemma: Wertstoffhof
# Token: fragen, POS: NOUN, Lemma: Frage
# Token: mülltrennung, POS: NOUN, Lemma: Mülltrennung
# Token: beraten, POS: VERB, Lemma: beraten
# Token: sack, POS: NOUN, Lemma: Sack
# Token: glascontainer, POS: ADJ, Lemma: Glascontainer
# Token: fensterscheiben, POS: VERB, Lemma: fensterscheiben
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: uhr, POS: NOUN, Lemma:
# Token: entsorgungsbetriebe, POS: VERB, Lemma: entsorgungsbetrieben
# Token: uhr, POS: NOUN, Lemma:
#
# ==================================================
#
# Final Text for Document 2:
#
# glascontainer gehören restentleerte glasverpackungen glasverpackungen farben weiß sortieren vorgesehenen container werfen farben blaues glas grünglas deckel abgeschraubt beispiel bepfandeten glasflaschen wein frucht gemüse säfte fruchtnektare glas parfümflaschen marmeladen gurken senfgläser sonstiges verpackungsglas obst soßen suppen gemüse glas glas glascontainer gehören abfälle glas verpackungen beispiel auflaufformen hitzebeständiges glas steingutflaschen autolampen teller tassen autoscheiben kaffeekannen trinkgläser batterien bio restabfall keramik bleiglas leuchtstoffröhren blumentöpfe mikrowellengeschirr flachglas produkte verpackungsbestandteile glaskeramik kunststoff glaskochplatten glühbirnen spritzen regionale ausnahmen nähere infos kommune qrcode scannen klicken zuständigen ansprechpartnerin
#
# Final Token Information for Document 2:
#
# Token: glascontainer, POS: NOUN, Lemma: Glascontainer
# Token: gehören, POS: VERB, Lemma: gehören
# Token: restentleerte, POS: ADJ, Lemma: restentleert
# Token: glasverpackungen, POS: NOUN, Lemma: Glasverpackung
# Token: glasverpackungen, POS: NOUN, Lemma: Glasverpackung
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: weiß, POS: ADJ, Lemma: weiß
# Token: sortieren, POS: VERB, Lemma: sortieren
# Token: vorgesehenen, POS: ADJ, Lemma: vorgesehen
# Token: container, POS: NOUN, Lemma: Container
# Token: werfen, POS: VERB, Lemma: werfen
# Token: farben, POS: NOUN, Lemma: Farbe
# Token: blaues, POS: ADJ, Lemma: blau
# Token: glas, POS: NOUN, Lemma: Glas
# Token: grünglas, POS: NOUN, Lemma: Grünglas
# Token: deckel, POS: NOUN, Lemma: Deckel
# Token: abgeschraubt, POS: VERB, Lemma: abgeschrauben
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: bepfandeten, POS: ADJ, Lemma: bepfandet
# Token: glasflaschen, POS: ADJ, Lemma: glasflasch
# Token: wein, POS: NOUN, Lemma: Wein
# Token: frucht, POS: NOUN, Lemma: fruchen
# Token: gemüse, POS: NOUN, Lemma: Gemüse
# Token: säfte, POS: NOUN, Lemma: säfen
# Token: fruchtnektare, POS: ADJ, Lemma: fruchtnektar
# Token: glas, POS: NOUN, Lemma: Glas
# Token: parfümflaschen, POS: ADJ, Lemma: parfümflasch
# Token: marmeladen, POS: ADJ, Lemma: marmelad
# Token: gurken, POS: VERB, Lemma: Gurk
# Token: senfgläser, POS: NOUN, Lemma: senfgläs
# Token: sonstiges, POS: ADJ, Lemma: sonstig
# Token: verpackungsglas, POS: NOUN, Lemma: Verpackungsglas
# Token: obst, POS: NOUN, Lemma: Obst
# Token: soßen, POS: NOUN, Lemma: Soße
# Token: suppen, POS: NOUN, Lemma: suppen
# Token: gemüse, POS: NOUN, Lemma: Gemüse
# Token: glas, POS: NOUN, Lemma: Glas
# Token: glas, POS: NOUN, Lemma: Glas
# Token: glascontainer, POS: NOUN, Lemma: Glascontainer
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: glas, POS: NOUN, Lemma: Glas
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: auflaufformen, POS: VERB, Lemma: auflaufform
# Token: hitzebeständiges, POS: ADJ, Lemma: hitzebeständig
# Token: glas, POS: NOUN, Lemma: Glas
# Token: steingutflaschen, POS: NOUN, Lemma: steingutflaschen
# Token: autolampen, POS: NOUN, Lemma: Autolamp
# Token: teller, POS: NOUN, Lemma: Teller
# Token: tassen, POS: VERB, Lemma: tassen
# Token: autoscheiben, POS: VERB, Lemma: Autoscheib
# Token: kaffeekannen, POS: VERB, Lemma: kaffeekannen
# Token: trinkgläser, POS: NOUN, Lemma: Trinkgläser
# Token: batterien, POS: NOUN, Lemma: batteri
# Token: bio, POS: NOUN, Lemma:
# Token: restabfall, POS: NOUN, Lemma: Restabfall
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: bleiglas, POS: NOUN, Lemma: Bleiglas
# Token: leuchtstoffröhren, POS: NOUN, Lemma: leuchtstoffröhren
# Token: blumentöpfe, POS: ADJ, Lemma: blumentöpf
# Token: mikrowellengeschirr, POS: NOUN, Lemma: Mikrowellengeschirr
# Token: flachglas, POS: NOUN, Lemma: Flachgla
# Token: produkte, POS: NOUN, Lemma: Produkt
# Token: verpackungsbestandteile, POS: NOUN, Lemma: verpackungsbestandteil
# Token: glaskeramik, POS: NOUN, Lemma: Glaskeramik
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: glaskochplatten, POS: NOUN, Lemma: Glaskochplatt
# Token: glühbirnen, POS: NOUN, Lemma: Glühbirne
# Token: spritzen, POS: VERB, Lemma: spritzen
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Text for Document 3:
#
# papiertonne gehören verpackungen nichtverpackungen papier anhaftung speiseresten verpackungen zerkleinert zusammengelegt gefaltet beispiel beispiel nichtverpackungen verpackungen briefe brötchen metzger briefumschläge obsttüten bücher eierschachteln geschenkpapier faltschachteln form kataloge füllmaterial postkarten papier schulhefte mehl zuckertüten werbeprospekte zeitschriften papiertragetaschen zeitungen pappummantelung joghurtbechern pralinenschachteln papiertonne gehören abfälle verpackungen papier pappe beispiel batterien bioabfall metalle butterfolie milch dosen suppen soßentüten fotos glas thermopapier holzschachteln holzwolle tapeten kontoauszüge erschmutzte volle thermopapiere verpackungen küchenabfälle wein sektkorken küchen papiertaschentücher kunststoffe regionale ausnahmen nähere infos kommune qrcode scannen klicken zuständigen ansprechpartnerin
#
# Final Token Information for Document 3:
#
# Token: papiertonne, POS: NOUN, Lemma: Papiertonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: nichtverpackungen, POS: NOUN, Lemma: nichtverpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: anhaftung, POS: NOUN, Lemma: Anhaftung
# Token: speiseresten, POS: NOUN, Lemma: Speiserest
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: zerkleinert, POS: VERB, Lemma: zerkleinert
# Token: zusammengelegt, POS: VERB, Lemma: zusammenlegen
# Token: gefaltet, POS: VERB, Lemma: falten
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: nichtverpackungen, POS: NOUN, Lemma: Nichtverpackung
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: briefe, POS: NOUN, Lemma: Brief
# Token: brötchen, POS: ADJ, Lemma: brötch
# Token: metzger, POS: NOUN, Lemma: Metzger
# Token: briefumschläge, POS: NOUN, Lemma: briefumschlägen
# Token: obsttüten, POS: ADJ, Lemma: obsttüt
# Token: bücher, POS: ADJ, Lemma: büch
# Token: eierschachteln, POS: NOUN, Lemma: Eierschachtel
# Token: geschenkpapier, POS: NOUN, Lemma: Geschenkpapier
# Token: faltschachteln, POS: VERB, Lemma: faltschachteln
# Token: form, POS: NOUN, Lemma: Form
# Token: kataloge, POS: VERB, Lemma: Kataloge
# Token: füllmaterial, POS: NOUN, Lemma: Füllmaterial
# Token: postkarten, POS: NOUN, Lemma: Postkart
# Token: papier, POS: NOUN, Lemma: Papier
# Token: schulhefte, POS: NOUN, Lemma: schulheft
# Token: mehl, POS: NOUN, Lemma: Mehl
# Token: zuckertüten, POS: VERB, Lemma: Zuckertüte
# Token: werbeprospekte, POS: NOUN, Lemma: werbeprospekt
# Token: zeitschriften, POS: NOUN, Lemma: zeitschrift
# Token: papiertragetaschen, POS: ADJ, Lemma: papiertragetasch
# Token: zeitungen, POS: NOUN, Lemma: Zeitung
# Token: pappummantelung, POS: NOUN, Lemma: Pappummantelung
# Token: joghurtbechern, POS: NOUN, Lemma: joghurtbechern
# Token: pralinenschachteln, POS: VERB, Lemma: Pralinenschachtel
# Token: papiertonne, POS: NOUN, Lemma: Papiertonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: bioabfall, POS: NOUN, Lemma: Bioabfall
# Token: metalle, POS: ADJ, Lemma: metall
# Token: butterfolie, POS: NOUN, Lemma: Butterfolie
# Token: milch, POS: NOUN, Lemma: Milch
# Token: dosen, POS: VERB, Lemma: dosen
# Token: suppen, POS: VERB, Lemma: suppen
# Token: soßentüten, POS: NOUN, Lemma: Soßentüte
# Token: fotos, POS: NOUN, Lemma: Foto
# Token: glas, POS: NOUN, Lemma: Glas
# Token: thermopapier, POS: NOUN, Lemma: Thermopapier
# Token: holzschachteln, POS: VERB, Lemma: holzschachteln
# Token: holzwolle, POS: ADJ, Lemma: holzwoll
# Token: tapeten, POS: NOUN, Lemma: tapeten
# Token: kontoauszüge, POS: ADJ, Lemma: kontoauszüge
# Token: erschmutzte, POS: ADJ, Lemma: erschmutzen
# Token: volle, POS: ADJ, Lemma: voll
# Token: thermopapiere, POS: ADJ, Lemma: thermopapierer
# Token: verpackungen, POS: ADJ, Lemma: verpackungen
# Token: küchenabfälle, POS: NOUN, Lemma: küchenabfällen
# Token: wein, POS: NOUN, Lemma: Wein
# Token: sektkorken, POS: VERB, Lemma: sektkorken
# Token: küchen, POS: ADJ, Lemma: küch
# Token: papiertaschentücher, POS: NOUN, Lemma: Papiertaschentücher
# Token: kunststoffe, POS: ADJ, Lemma: kunststoff
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Text for Document 4:
#
# wertstofftonne gehören gebrauchte restlentleerte verpackungen papier glas gegenstände kunststoff metall verpackungsbestand teile trennen ausspülen beispiel saftflaschen schalen schaumstoffe arzneimittelblister schrauben esteck spielzeug flaschenverschlüsse töpfe folien werkzeuge ebrauchsgegenstände gießkannen blumentöpfe plastikschüsseln getränkedosen margarinebecher unststoffflaschen waschmittelflaschen icht wertstofftonne gehören verpackungen papier glas restabfälle beispiel verpackte bzw alte keramik akkus abgelagerte lebensmittel holz batterien windeln kfzkleinteile bauabfälle zigarettenkippen medikamentenreste datenträger mund nasenschutz elektrogeräte porzellan energiesparlampen schuhe gummi spritzen holz holzreste strumpfhosen hygieneartikel windeln styroporreste dämmplatten binden wattereste tapetenreste kondome textilien video audiokassetten kanülen regionale ausnahmen nähere infos kommune qrcode scannen klicken zuständigen ansprechpartnerin
#
# Final Token Information for Document 4:
#
# Token: wertstofftonne, POS: NOUN, Lemma: Wertstofftonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: gebrauchte, POS: ADJ, Lemma: gebraucht
# Token: restlentleerte, POS: VERB, Lemma: restlentleeren
# Token: verpackungen, POS: VERB, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: gegenstände, POS: NOUN, Lemma: Gegenstand
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: metall, POS: NOUN, Lemma: Metall
# Token: verpackungsbestand, POS: VERB, Lemma: Verpackungsbestand
# Token: teile, POS: NOUN, Lemma: Teil
# Token: trennen, POS: VERB, Lemma: trennen
# Token: ausspülen, POS: VERB, Lemma: Ausspül
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: saftflaschen, POS: ADJ, Lemma: saftflasch
# Token: schalen, POS: ADJ, Lemma: schal
# Token: schaumstoffe, POS: NOUN, Lemma: Schaumstoff
# Token: arzneimittelblister, POS: NOUN, Lemma: arzneimittelblist
# Token: schrauben, POS: NOUN, Lemma: Schraube
# Token: esteck, POS: NOUN, Lemma: Esteck
# Token: spielzeug, POS: NOUN, Lemma: Spielzeug
# Token: flaschenverschlüsse, POS: ADJ, Lemma: flaschenverschlüsse
# Token: töpfe, POS: NOUN, Lemma: Töpf
# Token: folien, POS: NOUN, Lemma: Folie
# Token: werkzeuge, POS: NOUN, Lemma: werkzeug
# Token: ebrauchsgegenstände, POS: ADJ, Lemma: ebrauchsgegenständen
# Token: gießkannen, POS: ADJ, Lemma: gießkann
# Token: blumentöpfe, POS: NOUN, Lemma: Blumentöpfe
# Token: plastikschüsseln, POS: VERB, Lemma: plastikschüsseln
# Token: getränkedosen, POS: NOUN, Lemma: Getränkedose
# Token: margarinebecher, POS: ADJ, Lemma: margarinebech
# Token: unststoffflaschen, POS: VERB, Lemma: unststoffflaschen
# Token: waschmittelflaschen, POS: ADJ, Lemma: waschmittelflasch
# Token: icht, POS: NOUN, Lemma: Icht
# Token: wertstofftonne, POS: NOUN, Lemma: Wertstofftonne
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: restabfälle, POS: NOUN, Lemma: Restabfälle
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: verpackte, POS: ADJ, Lemma: verpackt
# Token: bzw, POS: NOUN, Lemma:
# Token: alte, POS: ADJ, Lemma:
# Token: keramik, POS: NOUN, Lemma: Keramik
# Token: akkus, POS: NOUN, Lemma: Akkus
# Token: abgelagerte, POS: ADJ, Lemma: abgelagert
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: holz, POS: NOUN, Lemma: Holz
# Token: batterien, POS: NOUN, Lemma: Batteri
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: kfzkleinteile, POS: NOUN, Lemma: Kfzkleinteil
# Token: bauabfälle, POS: ADJ, Lemma: Bauabfälle
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: medikamentenreste, POS: ADJ, Lemma: medikamentenr
# Token: datenträger, POS: ADJ, Lemma: Datenträger
# Token: mund, POS: NOUN, Lemma: Mund
# Token: nasenschutz, POS: NOUN, Lemma: Nasenschutz
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: porzellan, POS: NOUN, Lemma: Porzellan
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: schuhe, POS: VERB, Lemma: schuhen
# Token: gummi, POS: NOUN, Lemma: Gummi
# Token: spritzen, POS: VERB, Lemma: spritzen
# Token: holz, POS: NOUN, Lemma: Holz
# Token: holzreste, POS: ADJ, Lemma: holzrester
# Token: strumpfhosen, POS: NOUN, Lemma: Strumpfhosen
# Token: hygieneartikel, POS: NOUN, Lemma: Hygieneartikel
# Token: windeln, POS: VERB, Lemma: windeln
# Token: styroporreste, POS: NOUN, Lemma: Styroporrest
# Token: dämmplatten, POS: ADJ, Lemma: dämmplatt
# Token: binden, POS: NOUN, Lemma: Bind
# Token: wattereste, POS: NOUN, Lemma: wattereste
# Token: tapetenreste, POS: ADJ, Lemma: tapetenrest
# Token: kondome, POS: NOUN, Lemma: kondom
# Token: textilien, POS: NOUN, Lemma: Textilie
# Token: video, POS: NOUN, Lemma: Video
# Token: audiokassetten, POS: ADJ, Lemma: audiokassett
# Token: kanülen, POS: NOUN, Lemma: Kanül
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähern
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================
#
# Final Text for Document 5:
#
# gelbe tonneden gelben sack gehören gebrauchte restentleerte verpackungen papier glas verpackungsbestandteile trennen ausspülen beispiel menüschalen kunststoffdeckel fertiggerichten arzneimittelblister milch müsliriegelfolie joghurtbecher nudeltüten einkaufstüten putz reinigungsmittelflaschen obst gemüsebeutel nachfüllbeutel kunststoff waschmittel flüssigseife eisverpackungen üllmaterial verpackungen kunststoff shampooflaschen luftpolsterfolie spraydosen soßentüten konservendosen tierfutterdosen schalen kronkorken zahnpastatuben kunststoffschalen folien lebensmittel gelbe tonneden gelben sack gehören verpackungen papier glas abfälle verpackungen beispiel schuhe altkleider gummi strumpfhosen batterien akkus holzwolle styroporreste behälterglas dämmplatten tapetenreste cds keramikprodukte windeln druckerpatronen kinderspielzeug zahnbürsten klarsichthüllen zigarettenkippen elektrogeräte kugelschreiber essensreste restentleerte verpackungen faltschachteln papier pappe feuerzeuge ilme dvds pflaster videokassetten glüh energiesparlampen rest bioabfälle regionale ausnahmen nähere infos kommune qrcode scannen klicken zuständigen ansprechpartnerin
#
# Final Token Information for Document 5:
#
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonneden, POS: NOUN, Lemma: Tonnede
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehören, POS: VERB, Lemma: gehören
# Token: gebrauchte, POS: ADJ, Lemma: gebraucht
# Token: restentleerte, POS: VERB, Lemma: restentleert
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: verpackungsbestandteile, POS: NOUN, Lemma: verpackungsbestandteil
# Token: trennen, POS: VERB, Lemma: trennen
# Token: ausspülen, POS: VERB, Lemma: Ausspül
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: menüschalen, POS: NOUN, Lemma: Menüschal
# Token: kunststoffdeckel, POS: NOUN, Lemma: Kunststoffdeckel
# Token: fertiggerichten, POS: VERB, Lemma: fertiggericht
# Token: arzneimittelblister, POS: NOUN, Lemma: Arzneimittelblister
# Token: milch, POS: NOUN, Lemma: Milch
# Token: müsliriegelfolie, POS: NOUN, Lemma: Müsliriegelfolie
# Token: joghurtbecher, POS: ADJ, Lemma: joghurtbech
# Token: nudeltüten, POS: NOUN, Lemma: nudeltüter
# Token: einkaufstüten, POS: VERB, Lemma: Einkaufstüt
# Token: putz, POS: NOUN, Lemma: Putz
# Token: reinigungsmittelflaschen, POS: ADJ, Lemma: reinigungsmittelflasch
# Token: obst, POS: NOUN, Lemma: Obst
# Token: gemüsebeutel, POS: NOUN, Lemma: Gemüsebeutel
# Token: nachfüllbeutel, POS: NOUN, Lemma: Nachfüllbeutel
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: waschmittel, POS: NOUN, Lemma: Waschmittel
# Token: flüssigseife, POS: NOUN, Lemma: flüssigseife
# Token: eisverpackungen, POS: VERB, Lemma: eisverpackungen
# Token: üllmaterial, POS: NOUN, Lemma: Üllmaterial
# Token: verpackungen, POS: NOUN, Lemma: verpackungen
# Token: kunststoff, POS: NOUN, Lemma: Kunststoff
# Token: shampooflaschen, POS: ADJ, Lemma: shampooflasch
# Token: luftpolsterfolie, POS: NOUN, Lemma: Luftpolsterfolie
# Token: spraydosen, POS: NOUN, Lemma: Spraydose
# Token: soßentüten, POS: NOUN, Lemma: soßentüen
# Token: konservendosen, POS: NOUN, Lemma: Konservendosen
# Token: tierfutterdosen, POS: VERB, Lemma: tierfutterdosen
# Token: schalen, POS: ADJ, Lemma: schal
# Token: kronkorken, POS: NOUN, Lemma: kronkork
# Token: zahnpastatuben, POS: NOUN, Lemma: Zahnpastatuben
# Token: kunststoffschalen, POS: NOUN, Lemma: kunststoffschalen
# Token: folien, POS: NOUN, Lemma: folien
# Token: lebensmittel, POS: NOUN, Lemma: Lebensmittel
# Token: gelbe, POS: ADJ, Lemma: gelb
# Token: tonneden, POS: NOUN, Lemma: Tonnede
# Token: gelben, POS: ADJ, Lemma: gelb
# Token: sack, POS: NOUN, Lemma: Sack
# Token: gehören, POS: VERB, Lemma: gehören
# Token: verpackungen, POS: NOUN, Lemma: verpackunge
# Token: papier, POS: NOUN, Lemma: Papier
# Token: glas, POS: NOUN, Lemma: Glas
# Token: abfälle, POS: NOUN, Lemma: Abfall
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: beispiel, POS: NOUN, Lemma: Beispiel
# Token: schuhe, POS: VERB, Lemma: schuhen
# Token: altkleider, POS: NOUN, Lemma: altkleid
# Token: gummi, POS: ADJ, Lemma: Gummi
# Token: strumpfhosen, POS: NOUN, Lemma: strumpfhosen
# Token: batterien, POS: NOUN, Lemma: Batterien
# Token: akkus, POS: NOUN, Lemma: Akkus
# Token: holzwolle, POS: ADJ, Lemma: holzwoll
# Token: styroporreste, POS: NOUN, Lemma: Styroporrest
# Token: behälterglas, POS: ADJ, Lemma: Behälterglas
# Token: dämmplatten, POS: ADJ, Lemma: dämmplatt
# Token: tapetenreste, POS: ADJ, Lemma: tapetenrest
# Token: cds, POS: NOUN, Lemma:
# Token: keramikprodukte, POS: NOUN, Lemma: Keramikprodukt
# Token: windeln, POS: NOUN, Lemma: windeln
# Token: druckerpatronen, POS: ADJ, Lemma: druckerpatron
# Token: kinderspielzeug, POS: NOUN, Lemma: Kinderspielzeug
# Token: zahnbürsten, POS: VERB, Lemma: zahnbürsen
# Token: klarsichthüllen, POS: NOUN, Lemma: Klarsichthüll
# Token: zigarettenkippen, POS: NOUN, Lemma: zigarettenkippen
# Token: elektrogeräte, POS: VERB, Lemma: elektrogeräten
# Token: kugelschreiber, POS: NOUN, Lemma: Kugelschreiber
# Token: essensreste, POS: ADJ, Lemma: essensreste
# Token: restentleerte, POS: VERB, Lemma: restentleert
# Token: verpackungen, POS: NOUN, Lemma: Verpackung
# Token: faltschachteln, POS: VERB, Lemma: faltschachteln
# Token: papier, POS: NOUN, Lemma: Papier
# Token: pappe, POS: NOUN, Lemma: Pappe
# Token: feuerzeuge, POS: VERB, Lemma: feuerzeug
# Token: ilme, POS: ADJ, Lemma:
# Token: dvds, POS: NOUN, Lemma: dvds
# Token: pflaster, POS: NOUN, Lemma: Pflaster
# Token: videokassetten, POS: VERB, Lemma: videokassett
# Token: glüh, POS: NOUN, Lemma: Glüh
# Token: energiesparlampen, POS: NOUN, Lemma: Energiesparlampe
# Token: rest, POS: NOUN, Lemma: Rest
# Token: bioabfälle, POS: ADJ, Lemma: bioabfäll
# Token: regionale, POS: ADJ, Lemma: regional
# Token: ausnahmen, POS: NOUN, Lemma: Ausnahme
# Token: nähere, POS: ADJ, Lemma: nähere
# Token: infos, POS: NOUN, Lemma: infos
# Token: kommune, POS: NOUN, Lemma: kommun
# Token: qrcode, POS: NOUN, Lemma: Qrcode
# Token: scannen, POS: VERB, Lemma: scann
# Token: klicken, POS: VERB, Lemma: klicken
# Token: zuständigen, POS: ADJ, Lemma: zuständig
# Token: ansprechpartnerin, POS: NOUN, Lemma: Ansprechpartnerin
#
# ==================================================

# %%
import os
import pickle

def save_new_documents(documents, filename="new_processed_documents.pkl"):
    # Sicherstellen, dass der Ordner, in dem die Datei gespeichert wird, existiert
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    
    # Speichern der Dokumente im angegebenen Pfad
    with open(filename, "wb") as file:
        pickle.dump(documents, file)
    
    print(f"Die Datei '{filename}' wurde erfolgreich gespeichert.")

# Beispielnutzung:
save_new_documents(cleaned_documents, filename="data/pickle/new_processed_documents.pkl")
# Out:
# Die Datei 'data/pickle/new_processed_documents.pkl' wurde erfolgreich gespeichert.

# %%
import re

def chunk_documents_with_context(cleaned_documents, max_chunk_size=100):
    """
    Teilt Dokumente in sinnvolle Chunks, um den Kontext nicht zu verlieren und druckt die Chunks.
    
    Args:
    - cleaned_documents: Eine Liste von Listen, wobei jede innere Liste ein Dokument darstellt.
    - max_chunk_size: Maximale Anzahl von Tokens pro Chunk.
    
    Returns:
    - Eine Liste von Chunks.
    """
    chunks = []
    for i, document in enumerate(cleaned_documents):
        print(f"\nDokument {i+1}:")
        current_chunk = []
        current_size = 0

        for j, (token, pos, lemma) in enumerate(document):
            current_chunk.append((token, pos, lemma))
            current_size += 1

            # Kontextlogik für die Trennung von Chunks
            if current_size >= max_chunk_size:
                # Überprüfe, ob der nächste Token ein Noun (NOUN) oder ein Adjektiv (ADJ) ist,
                # um den Zusammenhang zu erhalten
                if j+1 < len(document) and document[j+1][1] in {'NOUN', 'ADJ'}:
                    continue  # Warte mit dem Chunking, um den Zusammenhang nicht zu trennen
                
                # Füge das aktuelle Chunk der Chunks-Liste hinzu
                chunks.append(current_chunk)
                
                # Print das aktuelle Chunk
                print("Chunk:", current_chunk)
                
                # Setze das aktuelle Chunk und die Größe zurück
                current_chunk = []
                current_size = 0
        
        # Füge das letzte Chunk hinzu, wenn es nicht leer ist
        if current_chunk:
            chunks.append(current_chunk)
            print("Chunk:", current_chunk)

    return chunks

# Beispielaufruf
# cleaned_documents ist deine Liste von Dokumenten
chunks = chunk_documents_with_context(cleaned_documents, max_chunk_size=100)
# Out:
# Dokument 1:
# Chunk: [('blaue', 'ADJ', 'blau'), ('altglascontainer', 'NOUN', 'Altglascontainer'), ('saubere', 'ADJ', 'sauber'), ('flaschen', 'NOUN', 'Flasche'), ('deckelgläser', 'NOUN', 'Deckelglas'), ('farben', 'NOUN', 'Farbe'), ('weiß', 'ADJ', 'weiß'), ('blaues', 'ADJ', 'blau'), ('buntes', 'ADJ', 'bunt'), ('glas', 'NOUN', 'Glas'), ('grünglas', 'NOUN', 'Grünglas'), ('geben', 'VERB', 'geben'), ('aschen', 'ADJ', 'asch'), ('konservengläser', 'NOUN', 'Konservenglas'), ('scheiben', 'VERB', 'Scheiben'), ('restmüll', 'NOUN', 'Restmüll'), ('trinkgläser', 'NOUN', 'Trinkgläser'), ('porzellan', 'NOUN', 'Porzellan'), ('keramik', 'NOUN', 'Keramik'), ('glühbirnen', 'NOUN', 'Glühbirne'), ('restmüll', 'NOUN', 'Restmüll'), ('energiesparlampen', 'NOUN', 'Energiesparlampe'), ('wertstoffhöfe', 'NOUN', 'Wertstoffhof'), ('verschmutzte', 'ADJ', 'verschmutzt'), ('gläser', 'ADJ', 'Gläser'), ('restmüll', 'ADJ', 'Restmüll'), ('standort', 'NOUN', 'Standort'), ('öffentlichen', 'ADJ', 'öffentlich'), ('sperrmüll', 'VERB', 'Sperrmüll'), ('plätzen', 'VERB', 'plätzen'), ('frankfurter', 'ADJ', 'Frankfurter'), ('entsorgungs', 'NOUN', 'Entsorgung'), ('abfall', 'NOUN', 'Abfall'), ('trennen', 'VERB', 'trennen'), ('service', 'NOUN', 'Service'), ('gmbh', 'VERB', 'Gmbh'), ('fesservicecenter', 'NOUN', 'Fesservicecenter'), ('ecke', 'NOUN', 'Ecke'), ('töngesgasseschärfengässchen', 'VERB', 'töngesgasseschärfengässchen'), ('uhr', 'NOUN', ''), ('uhr', 'NOUN', ''), ('rgungsfachbetrie', 'NOUN', 'Rgungsfachbetrie'), ('rrt', 'VERB', 'rren'), ('trennen', 'VERB', 'trennen'), ('haus', 'NOUN', 'Haus'), ('gehören', 'VERB', 'gehören'), ('abfallbehälter', 'NOUN', 'Abfallbehälter'), ('tonnen', 'NOUN', 'Tonne'), ('inhalt', 'NOUN', 'Inhalt'), ('wertvoller', 'ADJ', 'Wertvoller'), ('rohstoff', 'NOUN', 'Rohstoff'), ('neuen', 'ADJ', ''), ('produkten', 'NOUN', 'Produkt'), ('weiterverarbeitet', 'VERB', 'weiterverarbeiten'), ('graue', 'ADJ', 'grau'), ('restmülltonne', 'NOUN', 'Restmülltonne'), ('gelbe', 'ADJ', 'gelb'), ('tonne', 'NOUN', 'Tonne'), ('verpackungen', 'NOUN', 'verpackunger'), ('grüne', 'ADJ', 'grün'), ('tonne', 'NOUN', 'Tonne'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('braune', 'ADJ', 'braun'), ('tonne', 'NOUN', 'Tonne'), ('bioabfälle', 'ADJ', 'bioabfälle'), ('graue', 'ADJ', 'grau'), ('tonne', 'NOUN', 'Tonne'), ('restlichen', 'ADJ', 'restlich'), ('abfall', 'NOUN', 'Abfall'), ('restmüll', 'NOUN', 'Restmüll'), ('gibt', 'VERB', 'geben'), ('folgende', 'ADJ', 'folgend'), ('entsorgungsangebote', 'ADJ', 'entsorgungsangebot'), ('wertstoffe', 'NOUN', 'wertstoffe'), ('sichern', 'VERB', 'sichern'), ('altglascontainer', 'NOUN', 'Altglascontainer'), ('flaschen', 'NOUN', 'Flasche'), ('deckelgläser', 'NOUN', 'Deckelglas'), ('nden', 'VERB', 'nden'), ('öffentlichen', 'ADJ', 'öffentlich'), ('plätzen', 'NOUN', 'Plätz'), ('altkleider', 'NOUN', 'altkleid'), ('container', 'NOUN', 'Container'), ('altkleider', 'NOUN', 'altkleider'), ('schuhe', 'NOUN', 'schuhen'), ('nden', 'VERB', 'nden'), ('stadtteil', 'NOUN', 'Stadtteil'), ('öffentlichen', 'ADJ', 'öffentlich'), ('plätzen', 'NOUN', 'Plätz'), ('feswertstoffhöfen', 'NOUN', 'Feswertstoffhöf'), ('schadstoffe', 'NOUN', 'Schadstoff'), ('abfälle', 'NOUN', 'Abfäll'), ('gefährlichen', 'ADJ', 'gefährlich'), ('stoffen', 'NOUN', 'Stoff'), ('farben', 'NOUN', 'farbe'), ('spraydosen', 'NOUN', 'Spraydos'), ('mitteln', 'VERB', 'mitteln'), ('fesschadstoffmobil', 'NOUN', 'Fesschadstoffmobil'), ('abgeben', 'VERB', 'abgeben'), ('termine', 'NOUN', 'terminen')]
# Chunk: [('nden', 'VERB', 'nden'), ('jahr', 'NOUN', 'Jahr'), ('haushalte', 'NOUN', 'Haushalt'), ('verteilt', 'VERB', 'verteilen'), ('sperrmüllabholung', 'NOUN', 'Sperrmüllabholung'), ('holt', 'VERB', 'holen'), ('fes', 'NOUN', ''), ('termin', 'NOUN', 'Termin'), ('wohnsiedlungen', 'NOUN', 'Wohnsiedlung'), ('abgeholt', 'VERB', 'abholen'), ('termine', 'NOUN', 'termin'), ('nden', 'VERB', 'nden'), ('schwarzen', 'ADJ', 'schwarz'), ('brett', 'NOUN', 'Brett'), ('sperrmüll', 'NOUN', 'Sperrmüll'), ('wertstoffe', 'VERB', 'Wertstoff'), ('entsorgen', 'VERB', 'entsorgen'), ('hnff', 'VERB', 'Hnff'), ('tie', 'NOUN', ''), ('abfalltonnen', 'NOUN', 'Abfalltonn'), ('haus', 'NOUN', 'Haus'), ('dauer', 'NOUN', 'Dauer'), ('ausreichen', 'VERB', 'ausreichen'), ('hausbesitzer', 'NOUN', 'hausbesitz'), ('weiteregrößere', 'ADJ', 'Weiteregrößere'), ('bestellen', 'VERB', 'bestellen'), ('internet', 'NOUN', 'Internet'), ('spezialbehälter', 'NOUN', 'Spezialbehälter'), ('besondere', 'ADJ', 'besonderer'), ('abfälle', 'NOUN', 'abfäll'), ('baustellenabfälle', 'VERB', 'baustellenabfälle'), ('erfahren', 'VERB', 'erfahren'), ('servicetelefonnummer', 'NOUN', 'Servicetelefonnummer'), ('kosten', 'NOUN', 'Kosten'), ('sperrmüll', 'NOUN', 'Sperrmüll'), ('abfallgebühr', 'NOUN', 'Abfallgebühr'), ('enthalten', 'VERB', 'enthalten'), ('löse', 'ADJ', ''), ('standorte', 'ADJ', 'standort'), ('fesmagazin', 'NOUN', 'Fesmagazin'), ('erhalten', 'VERB', 'erhalten'), ('wochen', 'NOUN', 'Woche'), ('haus', 'NOUN', 'Haus'), ('näheres', 'NOUN', 'Näheres'), ('gelbe', 'ADJ', 'gelb'), ('verpackungstonne', 'NOUN', 'Verpackungstonne'), ('verpackungen', 'NOUN', 'Verpackunge'), ('symbol', 'NOUN', 'Symbol'), ('grünen', 'NOUN', 'grüne'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('glas', 'NOUN', 'Glas'), ('bestehen', 'VERB', 'bestehen'), ('verpackungen', 'NOUN', 'verpackunge'), ('gespült', 'VERB', 'spülen'), ('verpackungen', 'NOUN', 'verpackungen'), ('kunststoff', 'NOUN', 'Kunststoff'), ('folien', 'NOUN', 'folien'), ('becher', 'ADJ', 'bech'), ('verbundverpackungen', 'NOUN', 'Verbundverpackung'), ('materialmix', 'NOUN', 'Materialmix'), ('papier', 'NOUN', 'Papier'), ('getränkekartons', 'NOUN', 'Getränkekarton'), ('milchtüten', 'VERB', 'milchtüen'), ('verpackungen', 'NOUN', 'Verpackung'), ('metall', 'NOUN', 'Metall'), ('konserven', 'NOUN', 'Konserve'), ('getränkedosen', 'ADJ', 'getränkedosen'), ('geschäumte', 'ADJ', 'geschäumt'), ('kunststoffe', 'NOUN', 'kunststoff'), ('gemüseverpackungen', 'VERB', 'gemüseverpackungen'), ('verpackungen', 'NOUN', 'verpackungen'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('verpackungen', 'NOUN', 'verpackungen'), ('glas', 'NOUN', 'Glas'), ('altglascontainer', 'ADJ', 'altglascontain'), ('verschmutzte', 'ADJ', 'verschmutzt'), ('fastfoodverpackungen', 'NOUN', 'Fastfoodverpackung'), ('restmüll', 'NOUN', 'Restmüll'), ('restmüll', 'NOUN', 'Restmüll'), ('gelben', 'ADJ', 'gelb'), ('tonne', 'NOUN', 'Tonne'), ('aussortiert', 'VERB', 'aussortieren'), ('weiterverarbeitet', 'VERB', 'weiterverarbeitet'), ('standort', 'NOUN', 'Standort'), ('wohnhaus', 'NOUN', 'Wohnhaus'), ('leerung', 'NOUN', 'Leerung'), ('grüne', 'ADJ', 'grün'), ('altpapiertonne', 'NOUN', 'Altpapiertonne'), ('punkt', 'NOUN', 'Punkt'), ('grüne', 'ADJ', 'grün'), ('altpapiertonne', 'NOUN', 'altpapiertonn'), ('gehören', 'VERB', 'gehören'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('beschichtung', 'NOUN', 'Beschichtung'), ('pappen', 'NOUN', 'Pappe'), ('kartonagen', 'ADJ', 'kartonag'), ('styropor', 'NOUN', 'Styropor'), ('zeitungen', 'NOUN', 'Zeitung'), ('illustrierte', 'ADJ', 'illustriert'), ('kataloge', 'NOUN', 'Kataloge'), ('bücher', 'NOUN', 'büch')]
# Chunk: [('hefte', 'VERB', 'hefen'), ('verschmutztes', 'ADJ', 'verschmutzt'), ('papier', 'NOUN', 'Papier'), ('restmüll', 'NOUN', 'Restmüll'), ('beschichtetes', 'ADJ', 'beschichtet'), ('papier', 'NOUN', 'Papier'), ('restmüll', 'NOUN', 'Restmüll'), ('hygienepapiere', 'ADJ', 'hygienepapi'), ('windeln', 'NOUN', 'windeln'), ('restmüll', 'NOUN', 'Restmüll'), ('näheres', 'NOUN', 'Näheres'), ('sichere', 'ADJ', 'sicher'), ('aktenvernichtung', 'NOUN', 'Aktenvernichtung'), ('erfahren', 'VERB', 'erfahren'), ('servicetelefonnummer', 'NOUN', 'Servicetelefonnummer'), ('wertstoffe', 'ADJ', 'wertstoff'), ('standort', 'NOUN', 'Standort'), ('wohnhaus', 'NOUN', 'Wohnhaus'), ('leerung', 'NOUN', 'Leerung'), ('braune', 'ADJ', 'braun'), ('biotonne', 'VERB', 'biotonnen'), ('abbaubaren', 'ADJ', 'abbaubar'), ('abfälle', 'NOUN', 'Abfall'), ('privaten', 'ADJ', 'privat'), ('haushalten', 'NOUN', 'Haushalt'), ('feuchte', 'ADJ', 'feucht'), ('bioabfälle', 'NOUN', 'Bioabfäll'), ('salat', 'NOUN', 'Salat'), ('obst', 'NOUN', 'Obst'), ('gemüsereste', 'VERB', 'gemüseresen'), ('zeitungs', 'NOUN', 'Zeitungs'), ('wickeln', 'VERB', 'wickeln'), ('schützen', 'VERB', 'schützen'), ('tonne', 'VERB', 'tonnen'), ('starker', 'ADJ', 'stark'), ('verschmutzung', 'NOUN', 'Verschmutzung'), ('gemüseabfälle', 'NOUN', 'Gemüseabfälle'), ('zitrusfrüchte', 'ADJ', 'zitrusfrücht'), ('bananen', 'NOUN', 'Banane'), ('nussschalen', 'VERB', 'nussschalen'), ('rohe', 'ADJ', ''), ('gekochte', 'ADJ', 'gekocht'), ('speise', 'NOUN', 'Speise'), ('lebensmittelreste', 'ADJ', 'lebensmittelr'), ('kaffee', 'NOUN', 'Kaffee'), ('teesatz', 'NOUN', 'Teesatz'), ('filtertüten', 'VERB', 'filtertüt'), ('eierschalen', 'ADJ', 'Eierschale'), ('grünschnitt', 'NOUN', 'Grünschnitt'), ('plastiktüten', 'VERB', 'plastiktüt'), ('verpackungen', 'NOUN', 'Verpackunge'), ('kunststoff', 'NOUN', 'Kunststoff'), ('metall', 'NOUN', 'Metall'), ('gelbe', 'ADJ', 'gelb'), ('verpackungstonne', 'NOUN', 'Verpackungstonne'), ('kehricht', 'VERB', 'Kehricht'), ('windeln', 'VERB', 'windeln'), ('andere', 'ADJ', 'anderer'), ('gebrauchte', 'NOUN', 'Gebraucht'), ('restmüll', 'ADJ', 'Restmüll'), ('standort', 'NOUN', 'Standort'), ('wohnhaus', 'NOUN', 'Wohnhaus'), ('leerung', 'NOUN', 'Leerung'), ('graue', 'ADJ', 'grau'), ('restmülltonne', 'NOUN', 'Restmülltonne'), ('abfälle', 'NOUN', 'Abfall'), ('verunreinigung', 'NOUN', 'Verunreinigung'), ('vermischung', 'NOUN', 'Vermischung'), ('anderen', 'ADJ', 'anderer'), ('tonnen', 'NOUN', 'Tonne'), ('entsorgt', 'VERB', 'entsorgen'), ('schmutzte', 'NOUN', 'schmutzt'), ('lebensmittelverpackungen', 'NOUN', 'lebensmittelverpackungen'), ('taschentücher', 'NOUN', 'Taschentücher'), ('damenbinden', 'ADJ', 'Damenbinden'), ('babywindeln', 'NOUN', 'babywindeln'), ('staub', 'NOUN', 'Staub'), ('asche', 'ADJ', 'asch'), ('kehricht', 'NOUN', 'Kehricht'), ('zigarettenkippen', 'NOUN', 'zigarettenkippen'), ('küchentücher', 'ADJ', 'küchentüch'), ('putzlappen', 'ADJ', 'Putzlapp'), ('trinkgläser', 'ADJ', 'Trinkgläser'), ('porzellan', 'NOUN', 'Porzellan'), ('keramik', 'NOUN', 'Keramik'), ('scherben', 'VERB', 'scherben'), ('elektrogeräteschrott', 'NOUN', 'Elektrogeräteschrott'), ('wertstoffhöfe', 'NOUN', 'Wertstoffhof'), ('großgeräte', 'NOUN', 'großgeräte'), ('sperrmüll', 'NOUN', 'Sperrmüll'), ('batterien', 'VERB', 'batterien'), ('spezielle', 'ADJ', 'speziell'), ('sammelbehälter', 'NOUN', 'Sammelbehälter'), ('supermärkten', 'NOUN', 'Supermärkt'), ('öffentlichen', 'ADJ', 'öffentlich'), ('gebäuden', 'NOUN', 'Gebäud'), ('sonderabfallschadstoffe', 'NOUN', 'Sonderabfallschadstoffe'), ('farben', 'NOUN', 'Farbe'), ('lacke', 'NOUN', 'Lack'), ('standort', 'NOUN', 'Standort'), ('wohnhaus', 'NOUN', 'Wohnhaus'), ('leerung', 'NOUN', 'Leerung'), ('ver', 'ADJ', ''), ('wattebäusche', 'ADJ', 'wattebäusch'), ('spiegel', 'NOUN', 'Spiegel')]
#
# Dokument 2:
# Chunk: [('gehört', 'VERB', 'gehören'), ('bioabfall', 'NOUN', 'Bioabfall'), ('gehört', 'VERB', 'gehören'), ('biotonne', 'NOUN', 'Biotonne'), ('obst', 'NOUN', 'Obst'), ('gemüsereste', 'ADJ', 'gemüser'), ('kaffeesatz', 'NOUN', 'Kaffeesatz'), ('filter', 'ADJ', 'filt'), ('tee', 'NOUN', ''), ('essensreste', 'ADJ', 'essensreste'), ('gekochte', 'ADJ', 'gekocht'), ('alte', 'ADJ', ''), ('lebensmittel', 'NOUN', 'Lebensmittel'), ('verpackung', 'NOUN', 'Verpackung'), ('eierschalen', 'ADJ', 'eierschalen'), ('blumen', 'NOUN', 'blum'), ('gartenabfälle', 'ADJ', 'Gartenabfäll'), ('laub', 'NOUN', 'Laub'), ('einwickelpapier', 'NOUN', 'Einwickelpapier'), ('biotonne', 'NOUN', 'Biotonne'), ('plastiktüten', 'ADJ', 'plastiktüt'), ('erde', 'NOUN', 'Erde'), ('holz', 'NOUN', 'Holz'), ('grassoden', 'ADJ', 'grassod'), ('sand', 'NOUN', 'Sand'), ('steine', 'ADJ', 'stein'), ('qrcode', 'NOUN', 'Qrcode'), ('scannen', 'VERB', 'scannen'), ('erhalten', 'VERB', 'erhalten'), ('informationen', 'NOUN', 'Information'), ('sprachen', 'NOUN', 'Sprache'), ('trenne', 'VERB', 'trennen'), ('gehört', 'VERB', 'gehören'), ('restmülltonne', 'ADJ', 'restmülltonn'), ('zigarettenkippen', 'NOUN', 'Zigarettenkipp'), ('asche', 'ADJ', 'asch'), ('kehricht', 'NOUN', 'Kehricht'), ('keramik', 'NOUN', 'Keramik'), ('tonteller', 'NOUN', 'Tonteller'), ('töpfe', 'NOUN', 'Töpf'), ('putzlappen', 'NOUN', 'Putzlapp'), ('schwämme', 'ADJ', 'schwämm'), ('wegwerfwindeln', 'NOUN', 'wegwerfwindeln'), ('hygieneartikel', 'NOUN', 'Hygieneartikel'), ('restmülltonne', 'ADJ', 'restmülltonn'), ('schadstoffe', 'NOUN', 'Schadstoff'), ('batterien', 'NOUN', 'Batteri'), ('elektrogeräte', 'VERB', 'elektrogeräten'), ('bauschutt', 'NOUN', 'Bauschutt'), ('entsorgungsbetriebe', 'VERB', 'entsorgungsbetrieb'), ('gehört', 'VERB', 'gehören'), ('zeitungen', 'NOUN', 'Zeitung'), ('zeitschriften', 'NOUN', 'Zeitschrift'), ('kataloge', 'NOUN', 'Kataloge'), ('pappe', 'NOUN', 'Pappe'), ('prospekte', 'ADJ', 'prospekt'), ('hefte', 'ADJ', 'heft'), ('bücher', 'ADJ', 'büch'), ('packpapier', 'NOUN', 'Packpapier'), ('unbeschichtet', 'VERB', 'unbeschichten'), ('pappe', 'NOUN', 'Pappe'), ('telefonbücher', 'NOUN', 'Telefonbücher'), ('papiertonne', 'ADJ', 'papiertonn'), ('holz', 'NOUN', 'Holz'), ('schmutziges', 'ADJ', 'schmutzig'), ('fotos', 'NOUN', 'Foto'), ('plastiktüten', 'VERB', 'plastiktüten'), ('privathaushalt', 'NOUN', 'Privathaushalt'), ('gelber', 'ADJ', 'Gelber'), ('sack', 'NOUN', 'Sack'), ('papiertonne', 'VERB', 'papiertonnen'), ('gehört', 'VERB', 'gehören'), ('verpackungsstyropor', 'NOUN', 'Verpackungsstyropor'), ('kunststoffflaschen', 'ADJ', 'kunststoffflasch'), ('plastiktüten', 'ADJ', 'plastiktüt'), ('konservendosen', 'NOUN', 'Konservendosen'), ('milch', 'NOUN', 'Milch'), ('safttüten', 'VERB', 'safttüen'), ('vakuumverpackungen', 'NOUN', 'Vakuumverpackung'), ('gelben', 'ADJ', 'gelb'), ('plastikschüsseln', 'VERB', 'plastikschüsseln'), ('beschichtetes', 'ADJ', 'beschichtet'), ('papier', 'NOUN', 'Papier'), ('kleiderbügel', 'NOUN', 'Kleiderbügel'), ('kunststoffrohre', 'VERB', 'kunststoffrohren'), ('uhr', 'NOUN', ''), ('uhr', 'NOUN', ''), ('romn', 'ADJ', 'romn'), ('kurd', 'NOUN', 'Kurd'), ('gelben', 'ADJ', 'gelben'), ('sack', 'NOUN', 'Sack'), ('gehört', 'VERB', 'gehören'), ('glascontainer', 'ADJ', 'glascontainer'), ('weißglas', 'ADJ', 'weißglas'), ('buntglas', 'NOUN', 'Buntglas'), ('einwegglasflaschen', 'ADJ', 'einwegglasflasch'), ('sonstiges', 'ADJ', 'sonstig'), ('hohlglas', 'NOUN', 'Hohlglas'), ('nutzen', 'VERB', 'nutzen'), ('wertstoffhöfe', 'NOUN', 'Wertstoffhof'), ('fragen', 'NOUN', 'Frage'), ('mülltrennung', 'NOUN', 'Mülltrennung')]
# Chunk: [('beraten', 'VERB', 'beraten'), ('sack', 'NOUN', 'Sack'), ('glascontainer', 'ADJ', 'Glascontainer'), ('fensterscheiben', 'VERB', 'fensterscheiben'), ('porzellan', 'NOUN', 'Porzellan'), ('keramik', 'NOUN', 'Keramik'), ('glühbirnen', 'NOUN', 'Glühbirne'), ('uhr', 'NOUN', ''), ('entsorgungsbetriebe', 'VERB', 'entsorgungsbetrieben'), ('uhr', 'NOUN', '')]
#
# Dokument 3:
# Chunk: [('glascontainer', 'NOUN', 'Glascontainer'), ('gehören', 'VERB', 'gehören'), ('restentleerte', 'ADJ', 'restentleert'), ('glasverpackungen', 'NOUN', 'Glasverpackung'), ('glasverpackungen', 'NOUN', 'Glasverpackung'), ('farben', 'NOUN', 'Farbe'), ('weiß', 'ADJ', 'weiß'), ('sortieren', 'VERB', 'sortieren'), ('vorgesehenen', 'ADJ', 'vorgesehen'), ('container', 'NOUN', 'Container'), ('werfen', 'VERB', 'werfen'), ('farben', 'NOUN', 'Farbe'), ('blaues', 'ADJ', 'blau'), ('glas', 'NOUN', 'Glas'), ('grünglas', 'NOUN', 'Grünglas'), ('deckel', 'NOUN', 'Deckel'), ('abgeschraubt', 'VERB', 'abgeschrauben'), ('beispiel', 'NOUN', 'Beispiel'), ('bepfandeten', 'ADJ', 'bepfandet'), ('glasflaschen', 'ADJ', 'glasflasch'), ('wein', 'NOUN', 'Wein'), ('frucht', 'NOUN', 'fruchen'), ('gemüse', 'NOUN', 'Gemüse'), ('säfte', 'NOUN', 'säfen'), ('fruchtnektare', 'ADJ', 'fruchtnektar'), ('glas', 'NOUN', 'Glas'), ('parfümflaschen', 'ADJ', 'parfümflasch'), ('marmeladen', 'ADJ', 'marmelad'), ('gurken', 'VERB', 'Gurk'), ('senfgläser', 'NOUN', 'senfgläs'), ('sonstiges', 'ADJ', 'sonstig'), ('verpackungsglas', 'NOUN', 'Verpackungsglas'), ('obst', 'NOUN', 'Obst'), ('soßen', 'NOUN', 'Soße'), ('suppen', 'NOUN', 'suppen'), ('gemüse', 'NOUN', 'Gemüse'), ('glas', 'NOUN', 'Glas'), ('glas', 'NOUN', 'Glas'), ('glascontainer', 'NOUN', 'Glascontainer'), ('gehören', 'VERB', 'gehören'), ('abfälle', 'NOUN', 'Abfall'), ('glas', 'NOUN', 'Glas'), ('verpackungen', 'NOUN', 'Verpackung'), ('beispiel', 'NOUN', 'Beispiel'), ('auflaufformen', 'VERB', 'auflaufform'), ('hitzebeständiges', 'ADJ', 'hitzebeständig'), ('glas', 'NOUN', 'Glas'), ('steingutflaschen', 'NOUN', 'steingutflaschen'), ('autolampen', 'NOUN', 'Autolamp'), ('teller', 'NOUN', 'Teller'), ('tassen', 'VERB', 'tassen'), ('autoscheiben', 'VERB', 'Autoscheib'), ('kaffeekannen', 'VERB', 'kaffeekannen'), ('trinkgläser', 'NOUN', 'Trinkgläser'), ('batterien', 'NOUN', 'batteri'), ('bio', 'NOUN', ''), ('restabfall', 'NOUN', 'Restabfall'), ('keramik', 'NOUN', 'Keramik'), ('bleiglas', 'NOUN', 'Bleiglas'), ('leuchtstoffröhren', 'NOUN', 'leuchtstoffröhren'), ('blumentöpfe', 'ADJ', 'blumentöpf'), ('mikrowellengeschirr', 'NOUN', 'Mikrowellengeschirr'), ('flachglas', 'NOUN', 'Flachgla'), ('produkte', 'NOUN', 'Produkt'), ('verpackungsbestandteile', 'NOUN', 'verpackungsbestandteil'), ('glaskeramik', 'NOUN', 'Glaskeramik'), ('kunststoff', 'NOUN', 'Kunststoff'), ('glaskochplatten', 'NOUN', 'Glaskochplatt'), ('glühbirnen', 'NOUN', 'Glühbirne'), ('spritzen', 'VERB', 'spritzen'), ('regionale', 'ADJ', 'regional'), ('ausnahmen', 'NOUN', 'Ausnahme'), ('nähere', 'ADJ', 'nähern'), ('infos', 'NOUN', 'infos'), ('kommune', 'NOUN', 'kommun'), ('qrcode', 'NOUN', 'Qrcode'), ('scannen', 'VERB', 'scann'), ('klicken', 'VERB', 'klicken'), ('zuständigen', 'ADJ', 'zuständig'), ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')]
#
# Dokument 4:
# Chunk: [('papiertonne', 'NOUN', 'Papiertonne'), ('gehören', 'VERB', 'gehören'), ('verpackungen', 'NOUN', 'Verpackung'), ('nichtverpackungen', 'NOUN', 'nichtverpackungen'), ('papier', 'NOUN', 'Papier'), ('anhaftung', 'NOUN', 'Anhaftung'), ('speiseresten', 'NOUN', 'Speiserest'), ('verpackungen', 'VERB', 'verpackungen'), ('zerkleinert', 'VERB', 'zerkleinert'), ('zusammengelegt', 'VERB', 'zusammenlegen'), ('gefaltet', 'VERB', 'falten'), ('beispiel', 'NOUN', 'Beispiel'), ('beispiel', 'NOUN', 'Beispiel'), ('nichtverpackungen', 'NOUN', 'Nichtverpackung'), ('verpackungen', 'NOUN', 'Verpackung'), ('briefe', 'NOUN', 'Brief'), ('brötchen', 'ADJ', 'brötch'), ('metzger', 'NOUN', 'Metzger'), ('briefumschläge', 'NOUN', 'briefumschlägen'), ('obsttüten', 'ADJ', 'obsttüt'), ('bücher', 'ADJ', 'büch'), ('eierschachteln', 'NOUN', 'Eierschachtel'), ('geschenkpapier', 'NOUN', 'Geschenkpapier'), ('faltschachteln', 'VERB', 'faltschachteln'), ('form', 'NOUN', 'Form'), ('kataloge', 'VERB', 'Kataloge'), ('füllmaterial', 'NOUN', 'Füllmaterial'), ('postkarten', 'NOUN', 'Postkart'), ('papier', 'NOUN', 'Papier'), ('schulhefte', 'NOUN', 'schulheft'), ('mehl', 'NOUN', 'Mehl'), ('zuckertüten', 'VERB', 'Zuckertüte'), ('werbeprospekte', 'NOUN', 'werbeprospekt'), ('zeitschriften', 'NOUN', 'zeitschrift'), ('papiertragetaschen', 'ADJ', 'papiertragetasch'), ('zeitungen', 'NOUN', 'Zeitung'), ('pappummantelung', 'NOUN', 'Pappummantelung'), ('joghurtbechern', 'NOUN', 'joghurtbechern'), ('pralinenschachteln', 'VERB', 'Pralinenschachtel'), ('papiertonne', 'NOUN', 'Papiertonne'), ('gehören', 'VERB', 'gehören'), ('abfälle', 'NOUN', 'Abfall'), ('verpackungen', 'VERB', 'verpackungen'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('beispiel', 'NOUN', 'Beispiel'), ('batterien', 'NOUN', 'Batteri'), ('bioabfall', 'NOUN', 'Bioabfall'), ('metalle', 'ADJ', 'metall'), ('butterfolie', 'NOUN', 'Butterfolie'), ('milch', 'NOUN', 'Milch'), ('dosen', 'VERB', 'dosen'), ('suppen', 'VERB', 'suppen'), ('soßentüten', 'NOUN', 'Soßentüte'), ('fotos', 'NOUN', 'Foto'), ('glas', 'NOUN', 'Glas'), ('thermopapier', 'NOUN', 'Thermopapier'), ('holzschachteln', 'VERB', 'holzschachteln'), ('holzwolle', 'ADJ', 'holzwoll'), ('tapeten', 'NOUN', 'tapeten'), ('kontoauszüge', 'ADJ', 'kontoauszüge'), ('erschmutzte', 'ADJ', 'erschmutzen'), ('volle', 'ADJ', 'voll'), ('thermopapiere', 'ADJ', 'thermopapierer'), ('verpackungen', 'ADJ', 'verpackungen'), ('küchenabfälle', 'NOUN', 'küchenabfällen'), ('wein', 'NOUN', 'Wein'), ('sektkorken', 'VERB', 'sektkorken'), ('küchen', 'ADJ', 'küch'), ('papiertaschentücher', 'NOUN', 'Papiertaschentücher'), ('kunststoffe', 'ADJ', 'kunststoff'), ('regionale', 'ADJ', 'regional'), ('ausnahmen', 'NOUN', 'Ausnahme'), ('nähere', 'ADJ', 'nähern'), ('infos', 'NOUN', 'infos'), ('kommune', 'NOUN', 'kommun'), ('qrcode', 'NOUN', 'Qrcode'), ('scannen', 'VERB', 'scann'), ('klicken', 'VERB', 'klicken'), ('zuständigen', 'ADJ', 'zuständig'), ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')]
#
# Dokument 5:
# Chunk: [('wertstofftonne', 'NOUN', 'Wertstofftonne'), ('gehören', 'VERB', 'gehören'), ('gebrauchte', 'ADJ', 'gebraucht'), ('restlentleerte', 'VERB', 'restlentleeren'), ('verpackungen', 'VERB', 'verpackungen'), ('papier', 'NOUN', 'Papier'), ('glas', 'NOUN', 'Glas'), ('gegenstände', 'NOUN', 'Gegenstand'), ('kunststoff', 'NOUN', 'Kunststoff'), ('metall', 'NOUN', 'Metall'), ('verpackungsbestand', 'VERB', 'Verpackungsbestand'), ('teile', 'NOUN', 'Teil'), ('trennen', 'VERB', 'trennen'), ('ausspülen', 'VERB', 'Ausspül'), ('beispiel', 'NOUN', 'Beispiel'), ('saftflaschen', 'ADJ', 'saftflasch'), ('schalen', 'ADJ', 'schal'), ('schaumstoffe', 'NOUN', 'Schaumstoff'), ('arzneimittelblister', 'NOUN', 'arzneimittelblist'), ('schrauben', 'NOUN', 'Schraube'), ('esteck', 'NOUN', 'Esteck'), ('spielzeug', 'NOUN', 'Spielzeug'), ('flaschenverschlüsse', 'ADJ', 'flaschenverschlüsse'), ('töpfe', 'NOUN', 'Töpf'), ('folien', 'NOUN', 'Folie'), ('werkzeuge', 'NOUN', 'werkzeug'), ('ebrauchsgegenstände', 'ADJ', 'ebrauchsgegenständen'), ('gießkannen', 'ADJ', 'gießkann'), ('blumentöpfe', 'NOUN', 'Blumentöpfe'), ('plastikschüsseln', 'VERB', 'plastikschüsseln'), ('getränkedosen', 'NOUN', 'Getränkedose'), ('margarinebecher', 'ADJ', 'margarinebech'), ('unststoffflaschen', 'VERB', 'unststoffflaschen'), ('waschmittelflaschen', 'ADJ', 'waschmittelflasch'), ('icht', 'NOUN', 'Icht'), ('wertstofftonne', 'NOUN', 'Wertstofftonne'), ('gehören', 'VERB', 'gehören'), ('verpackungen', 'NOUN', 'verpackunge'), ('papier', 'NOUN', 'Papier'), ('glas', 'NOUN', 'Glas'), ('restabfälle', 'NOUN', 'Restabfälle'), ('beispiel', 'NOUN', 'Beispiel'), ('verpackte', 'ADJ', 'verpackt'), ('bzw', 'NOUN', ''), ('alte', 'ADJ', ''), ('keramik', 'NOUN', 'Keramik'), ('akkus', 'NOUN', 'Akkus'), ('abgelagerte', 'ADJ', 'abgelagert'), ('lebensmittel', 'NOUN', 'Lebensmittel'), ('holz', 'NOUN', 'Holz'), ('batterien', 'NOUN', 'Batteri'), ('windeln', 'NOUN', 'windeln'), ('kfzkleinteile', 'NOUN', 'Kfzkleinteil'), ('bauabfälle', 'ADJ', 'Bauabfälle'), ('zigarettenkippen', 'NOUN', 'zigarettenkippen'), ('medikamentenreste', 'ADJ', 'medikamentenr'), ('datenträger', 'ADJ', 'Datenträger'), ('mund', 'NOUN', 'Mund'), ('nasenschutz', 'NOUN', 'Nasenschutz'), ('elektrogeräte', 'VERB', 'elektrogeräten'), ('porzellan', 'NOUN', 'Porzellan'), ('energiesparlampen', 'NOUN', 'Energiesparlampe'), ('schuhe', 'VERB', 'schuhen'), ('gummi', 'NOUN', 'Gummi'), ('spritzen', 'VERB', 'spritzen'), ('holz', 'NOUN', 'Holz'), ('holzreste', 'ADJ', 'holzrester'), ('strumpfhosen', 'NOUN', 'Strumpfhosen'), ('hygieneartikel', 'NOUN', 'Hygieneartikel'), ('windeln', 'VERB', 'windeln'), ('styroporreste', 'NOUN', 'Styroporrest'), ('dämmplatten', 'ADJ', 'dämmplatt'), ('binden', 'NOUN', 'Bind'), ('wattereste', 'NOUN', 'wattereste'), ('tapetenreste', 'ADJ', 'tapetenrest'), ('kondome', 'NOUN', 'kondom'), ('textilien', 'NOUN', 'Textilie'), ('video', 'NOUN', 'Video'), ('audiokassetten', 'ADJ', 'audiokassett'), ('kanülen', 'NOUN', 'Kanül'), ('regionale', 'ADJ', 'regional'), ('ausnahmen', 'NOUN', 'Ausnahme'), ('nähere', 'ADJ', 'nähern'), ('infos', 'NOUN', 'infos'), ('kommune', 'NOUN', 'kommun'), ('qrcode', 'NOUN', 'Qrcode'), ('scannen', 'VERB', 'scann'), ('klicken', 'VERB', 'klicken'), ('zuständigen', 'ADJ', 'zuständig'), ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')]
#
# Dokument 6:
# Chunk: [('gelbe', 'ADJ', 'gelb'), ('tonneden', 'NOUN', 'Tonnede'), ('gelben', 'ADJ', 'gelb'), ('sack', 'NOUN', 'Sack'), ('gehören', 'VERB', 'gehören'), ('gebrauchte', 'ADJ', 'gebraucht'), ('restentleerte', 'VERB', 'restentleert'), ('verpackungen', 'NOUN', 'verpackungen'), ('papier', 'NOUN', 'Papier'), ('glas', 'NOUN', 'Glas'), ('verpackungsbestandteile', 'NOUN', 'verpackungsbestandteil'), ('trennen', 'VERB', 'trennen'), ('ausspülen', 'VERB', 'Ausspül'), ('beispiel', 'NOUN', 'Beispiel'), ('menüschalen', 'NOUN', 'Menüschal'), ('kunststoffdeckel', 'NOUN', 'Kunststoffdeckel'), ('fertiggerichten', 'VERB', 'fertiggericht'), ('arzneimittelblister', 'NOUN', 'Arzneimittelblister'), ('milch', 'NOUN', 'Milch'), ('müsliriegelfolie', 'NOUN', 'Müsliriegelfolie'), ('joghurtbecher', 'ADJ', 'joghurtbech'), ('nudeltüten', 'NOUN', 'nudeltüter'), ('einkaufstüten', 'VERB', 'Einkaufstüt'), ('putz', 'NOUN', 'Putz'), ('reinigungsmittelflaschen', 'ADJ', 'reinigungsmittelflasch'), ('obst', 'NOUN', 'Obst'), ('gemüsebeutel', 'NOUN', 'Gemüsebeutel'), ('nachfüllbeutel', 'NOUN', 'Nachfüllbeutel'), ('kunststoff', 'NOUN', 'Kunststoff'), ('waschmittel', 'NOUN', 'Waschmittel'), ('flüssigseife', 'NOUN', 'flüssigseife'), ('eisverpackungen', 'VERB', 'eisverpackungen'), ('üllmaterial', 'NOUN', 'Üllmaterial'), ('verpackungen', 'NOUN', 'verpackungen'), ('kunststoff', 'NOUN', 'Kunststoff'), ('shampooflaschen', 'ADJ', 'shampooflasch'), ('luftpolsterfolie', 'NOUN', 'Luftpolsterfolie'), ('spraydosen', 'NOUN', 'Spraydose'), ('soßentüten', 'NOUN', 'soßentüen'), ('konservendosen', 'NOUN', 'Konservendosen'), ('tierfutterdosen', 'VERB', 'tierfutterdosen'), ('schalen', 'ADJ', 'schal'), ('kronkorken', 'NOUN', 'kronkork'), ('zahnpastatuben', 'NOUN', 'Zahnpastatuben'), ('kunststoffschalen', 'NOUN', 'kunststoffschalen'), ('folien', 'NOUN', 'folien'), ('lebensmittel', 'NOUN', 'Lebensmittel'), ('gelbe', 'ADJ', 'gelb'), ('tonneden', 'NOUN', 'Tonnede'), ('gelben', 'ADJ', 'gelb'), ('sack', 'NOUN', 'Sack'), ('gehören', 'VERB', 'gehören'), ('verpackungen', 'NOUN', 'verpackunge'), ('papier', 'NOUN', 'Papier'), ('glas', 'NOUN', 'Glas'), ('abfälle', 'NOUN', 'Abfall'), ('verpackungen', 'NOUN', 'Verpackung'), ('beispiel', 'NOUN', 'Beispiel'), ('schuhe', 'VERB', 'schuhen'), ('altkleider', 'NOUN', 'altkleid'), ('gummi', 'ADJ', 'Gummi'), ('strumpfhosen', 'NOUN', 'strumpfhosen'), ('batterien', 'NOUN', 'Batterien'), ('akkus', 'NOUN', 'Akkus'), ('holzwolle', 'ADJ', 'holzwoll'), ('styroporreste', 'NOUN', 'Styroporrest'), ('behälterglas', 'ADJ', 'Behälterglas'), ('dämmplatten', 'ADJ', 'dämmplatt'), ('tapetenreste', 'ADJ', 'tapetenrest'), ('cds', 'NOUN', ''), ('keramikprodukte', 'NOUN', 'Keramikprodukt'), ('windeln', 'NOUN', 'windeln'), ('druckerpatronen', 'ADJ', 'druckerpatron'), ('kinderspielzeug', 'NOUN', 'Kinderspielzeug'), ('zahnbürsten', 'VERB', 'zahnbürsen'), ('klarsichthüllen', 'NOUN', 'Klarsichthüll'), ('zigarettenkippen', 'NOUN', 'zigarettenkippen'), ('elektrogeräte', 'VERB', 'elektrogeräten'), ('kugelschreiber', 'NOUN', 'Kugelschreiber'), ('essensreste', 'ADJ', 'essensreste'), ('restentleerte', 'VERB', 'restentleert'), ('verpackungen', 'NOUN', 'Verpackung'), ('faltschachteln', 'VERB', 'faltschachteln'), ('papier', 'NOUN', 'Papier'), ('pappe', 'NOUN', 'Pappe'), ('feuerzeuge', 'VERB', 'feuerzeug'), ('ilme', 'ADJ', ''), ('dvds', 'NOUN', 'dvds'), ('pflaster', 'NOUN', 'Pflaster'), ('videokassetten', 'VERB', 'videokassett'), ('glüh', 'NOUN', 'Glüh'), ('energiesparlampen', 'NOUN', 'Energiesparlampe'), ('rest', 'NOUN', 'Rest'), ('bioabfälle', 'ADJ', 'bioabfäll'), ('regionale', 'ADJ', 'regional'), ('ausnahmen', 'NOUN', 'Ausnahme'), ('nähere', 'ADJ', 'nähere'), ('infos', 'NOUN', 'infos'), ('kommune', 'NOUN', 'kommun'), ('qrcode', 'NOUN', 'Qrcode')]
# Chunk: [('scannen', 'VERB', 'scann'), ('klicken', 'VERB', 'klicken'), ('zuständigen', 'ADJ', 'zuständig'), ('ansprechpartnerin', 'NOUN', 'Ansprechpartnerin')]

# %%
import os
import pickle

def save_new_documents(documents, filename="chunks.pkl"):
    # Sicherstellen, dass der Ordner, in dem die Datei gespeichert wird, existiert
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    
    # Speichern der Dokumente im angegebenen Pfad
    with open(filename, "wb") as file:
        pickle.dump(documents, file)
    
    print(f"Die Datei '{filename}' wurde erfolgreich gespeichert.")

# Beispielnutzung:
save_new_documents(chunks, filename="data/pickle/chunks.pkl")
# Out:
# Die Datei 'data/pickle/chunks.pkl' wurde erfolgreich gespeichert.
